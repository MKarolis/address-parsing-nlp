# %%
import pandas as pd

def read_DataFrame_from_file(filename: str, numberOfRows: int = None):
    return pd.read_excel(filename, nrows = numberOfRows, keep_default_na=False)

# %%
DATA_INPUT_FILENAME = 'training_data.xlsx'
NUMBER_OF_PARSABLE_RECORDS = 999

def preprocess_data(data: pd.DataFrame):
    data['person_address'] = data.apply(lambda row: re.sub(r'([^\s])(,)([^\s])', r'\1, \3', row['person_address']), axis=1)
    print(data)

raw_data: pd.DataFrame = read_DataFrame_from_file(DATA_INPUT_FILENAME, NUMBER_OF_PARSABLE_RECORDS)
preprocess_data(raw_data)
# Out:
#      person_id                                        person_name  \
# 0         3540                                   PURAC Biochem BV
# 1        28753                               Tinti, Maria Ornella
# 2        35108  Isobe, Shin-ichi, c/o Int. Prop. Dpt., NTT DoC...
# 3        89830                                      Hata, Yoshiki
# 4        94063                                       Kim, Se-Jong
# ..         ...                                                ...
# 994   67732461                                          ZHANG, Ou
# 995   68271080                                  HIGUCHI, Shinichi
# 996   68607095                                      WANG, Zhiyong
# 997   68861617                                 GRIJO Patrik Nolan
# 998   69712319  VSEROSSIISKII GOSUDARSTVENNOI NAUTUNO-ISSLEDOV...
#
#                                         person_address  \
# 0                    Arkelsedijk 46, 4206 AC Gorinchem
# 1    SIGMA-TAU Industrie Farmaceutiche Riunite S.p....
# 2    Sanno Park Tower, 11-1, Nagatacho 2-chome, Chi...
# 3    c/o Hitachi Appliances, Inc. 390 Muramatsu, Sh...
# 4    Legal & IP Team, Samsung SDI Co., Ltd., 428-5,...
# ..                                                 ...
# 994  NO. 16 MEIHUA ROAD, ZHONGLOU ECONOMIC DEVELOPM...
# 995  C/O ALPS ELECTRIC CO., LTD., 1-7, YUKIGAYA-OTS...
# 996  C/O ZTE CORPORATION ZTE PLAZA, KEJI ROAD SOUTH...
# 997  129090, Moskva, ul. B. Spasskaja, 25, stroenie...
# 998  Standartizatsii i Sertifikatsii Veterinarnôh P...
#
#                                                   cln1                cln2  \
# 0                     Arkelsedijk 46 4206 AC Gorinchem             46 4206
# 1    SIGMA-TAU Industrie Farmaceutiche Riunite S.p....        30 400 00040
# 2    Sanno Park Tower 11-1 Nagatacho 2-chome Chiyod...               111 2
# 3    c/o Hitachi Appliances Inc. 390 Muramatsu Shim...         390 4240926
# 4    Legal & IP Team Samsung SDI Co. Ltd. 428-5 Gon...                4285
# ..                                                 ...                 ...
# 994  NO. 16 MEIHUA ROAD ZHONGLOU ECONOMIC DEVELOPME...           16 213023
# 995  C/O ALPS ELECTRIC CO. LTD. 1-7 YUKIGAYA-OTSUKA...  17 1458501 1458501
# 996  C/O ZTE CORPORATION ZTE PLAZA KEJI ROAD SOUTH ...              518057
# 997  129090 Moskva ul. B. Spasskaja 25 stroenie 3 O...         129090 25 3
# 998  Standartizatsii i Sertifikatsii Veterinarnôh P...                   5
#
#      cln3 person_ctry_code  cnt  chr_len  chr_len_label  ...  \
# 0      46               NL    1       32              2  ...
# 1      30               IT    1       86              1  ...
# 2     11-               JP    1       59              1  ...
# 3     390               JP    1       90              1  ...
# 4    428-               KR    1       92              1  ...
# ..    ...              ...  ...      ...            ...  ...
# 994    16               CN    1       84              1  ...
# 995    1-               JP    1       86              1  ...
# 996                     CN    1      106              1  ...
# 997    25               US    1       99              1  ...
# 998     5               RU    1      106              1  ...
#
#                      street     nr                                    area  \
# 0               Arkelsedijk     46
# 1               Via Pontina  km 30
# 2    Nagatacho 2-chome 11-1                                     Chiyoda-ku
# 3                                                             Shizuoka-ken
# 4                     428-5               Gongse-ri; Kiheung-eup; Yongin-s
# ..                      ...    ...                                     ...
# 994                                 ZHONGLOU ECONOMIC DEVELOPMENT DISTRICT
# 995    YUKIGAYA-OTSUKAMACHI    1-7                                  OTA-KU
# 996         KEJI ROAD SOUTH                HI-TECH INDUSTRIAL PARK NANSHAN
# 997        ul. B. Spasskaja     25                              stroenie 3
# 998         Zvenigorodskoje      5                                  Movska
#
#         postal                       city     region             country  \
# 0      4206 AC                  Gorinchem
# 1    400 00040                    Pomezia
# 2                                   Tokyo
# 3     424-0926   Shizuoka-shi, Shimizu-ku  Muramatsu
# 4                             Gyeonggi-do
# ..         ...                        ...        ...                 ...
# 994     213023                  CHANGZHOU    JIANGSU
# 995    1458501                      Tokyo
# 996     518057                   SHENZHEN  GUANGDONG
# 997     129090                     Moskva
# 998                                                   RUSSIAN FEDERATION
#
#     unclear status label
# 0                      1
# 1                      1
# 2                      1
# 3                      0
# 4                      1
# ..      ...    ...   ...
# 994                    1
# 995                    1
# 996                    1
# 997                    1
# 998                    1
#
# [999 rows x 31 columns]

# %%
import re
token_types: set = {'co', 'building', 'street', 'nr', 'area', 'postal', 'city', 'region', 'country'}


def get_entity_list(entry: dict, address: str):
    entities: list = []
    present_tokens = filter(lambda item: item[0] in token_types and item[1] and str(item[1]).strip(), entry.items())

    for item in present_tokens:
        token_value = str(item[1]).strip()
        match = re.search(re.escape(token_value), address)
        if match:
            span = match.span()
            entities.append((span[0], span[1], item[0]))
        else:
            # Try and resolve multiple tokens separated by ';'
            split_items = map(lambda token: token.strip(), token_value.split(';'))
            for token in split_items:
                split_match = re.search(re.escape(token), address)
                if split_match:
                    span = split_match.span()
                    entities.append((span[0], span[1], item[0]))
                else:
                    print('WARNING: could not find token "{}" in address "{}"'.format(token, address))
    
    return entities


def map_to_training_entry(entry: dict):
    address = entry['person_address']
    print(address, {
        'entities': get_entity_list(entry, address)
    })
    return (address, {
        'entities': get_entity_list(entry, address)
    })

train_data = list(
    map(map_to_training_entry, raw_data.to_dict('records'))
)
# print(train_data)
# Out:
# Arkelsedijk 46, 4206 AC Gorinchem {'entities': [(0, 11, 'street'), (12, 14, 'nr'), (16, 23, 'postal'), (24, 33, 'city')]}
# SIGMA-TAU Industrie Farmaceutiche Riunite S.p.A., Via Pontina, km 30, 400 00040, Pomezia {'entities': [(0, 48, 'co'), (50, 61, 'street'), (63, 68, 'nr'), (70, 79, 'postal'), (81, 88, 'city')]}
# WARNING: could not find token "Nagatacho 2-chome 11-1" in address "Sanno Park Tower, 11-1, Nagatacho 2-chome, Chiyoda-ku, Tokyo"
# Sanno Park Tower, 11-1, Nagatacho 2-chome, Chiyoda-ku, Tokyo {'entities': [(0, 16, 'building'), (43, 53, 'area'), (55, 60, 'city')]}
# WARNING: could not find token "Nagatacho 2-chome 11-1" in address "Sanno Park Tower, 11-1, Nagatacho 2-chome, Chiyoda-ku, Tokyo"
# WARNING: could not find token "Shizuoka-shi, Shimizu-ku" in address "c/o Hitachi Appliances, Inc. 390 Muramatsu, Shimizu-ku, Shizuoka-shi, Shizuoka-ken 424-0926"
# c/o Hitachi Appliances, Inc. 390 Muramatsu, Shimizu-ku, Shizuoka-shi, Shizuoka-ken 424-0926 {'entities': [(0, 27, 'co'), (70, 82, 'area'), (83, 91, 'postal'), (33, 42, 'region')]}
# WARNING: could not find token "Shizuoka-shi, Shimizu-ku" in address "c/o Hitachi Appliances, Inc. 390 Muramatsu, Shimizu-ku, Shizuoka-shi, Shizuoka-ken 424-0926"
# Legal & IP Team, Samsung SDI Co., Ltd., 428-5, Gongse-ri, Kiheung-eup, Yongin-si, Gyeonggi-do {'entities': [(40, 45, 'street'), (47, 56, 'area'), (58, 69, 'area'), (71, 79, 'area'), (82, 93, 'city')]}
# Pappelweg 9, 15809 Gross Machnow {'entities': [(0, 9, 'street'), (10, 11, 'nr'), (13, 18, 'postal'), (19, 32, 'city')]}
# 1 Gwihyun-dong, Changwon, Kyungsangnam-do {'entities': [(2, 14, 'street'), (0, 1, 'nr'), (16, 24, 'city'), (26, 41, 'region')]}
# WARNING: could not find token "Sanno Park Tower 11-1" in address "NTT DoCoMo, Inc., Sanno Park Tower, 11-1, Nagata-, cho 2-chome, Chiyoda-ku, Tokyo 100-6150"
# WARNING: could not find token "nagata-" in address "NTT DoCoMo, Inc., Sanno Park Tower, 11-1, Nagata-, cho 2-chome, Chiyoda-ku, Tokyo 100-6150"
# NTT DoCoMo, Inc., Sanno Park Tower, 11-1, Nagata-, cho 2-chome, Chiyoda-ku, Tokyo 100-6150 {'entities': [(0, 16, 'co'), (82, 90, 'postal'), (76, 81, 'city')]}
# WARNING: could not find token "Sanno Park Tower 11-1" in address "NTT DoCoMo, Inc., Sanno Park Tower, 11-1, Nagata-, cho 2-chome, Chiyoda-ku, Tokyo 100-6150"
# WARNING: could not find token "nagata-" in address "NTT DoCoMo, Inc., Sanno Park Tower, 11-1, Nagata-, cho 2-chome, Chiyoda-ku, Tokyo 100-6150"
# Kampstrasse 97, 45772 Marl {'entities': [(0, 11, 'street'), (12, 14, 'nr'), (16, 21, 'postal'), (22, 26, 'city')]}
# Paseo San Gervasio 32, 08022 Barcelona {'entities': [(0, 18, 'street'), (19, 21, 'nr'), (23, 28, 'postal'), (29, 38, 'city')]}
# 11937 Basswood Avenue, Uniontown, OH 44685 {'entities': [(6, 21, 'street'), (0, 5, 'nr'), (37, 42, 'postal'), (23, 32, 'city'), (34, 36, 'region')]}
# 8200 116 Avenue S.E., NewCastle, Washington 98056 {'entities': [(5, 20, 'street'), (0, 4, 'nr'), (44, 49, 'postal'), (22, 31, 'city'), (33, 43, 'region')]}
# Ludwigstr. 73, 67678 Mehlingen {'entities': [(0, 10, 'street'), (11, 13, 'nr'), (15, 20, 'postal'), (21, 30, 'city')]}
# 1800 Mill Creek Road, No. 14-B, Mill-Creek, Washington 98012 {'entities': [(5, 20, 'street'), (0, 4, 'nr'), (55, 60, 'postal'), (32, 42, 'city'), (44, 54, 'region')]}
# Apartment 77 1245 East California Avenue, Glendale, CA 91206 {'entities': [(0, 12, 'building'), (18, 40, 'street'), (13, 17, 'nr'), (55, 60, 'postal'), (42, 50, 'city'), (52, 54, 'region')]}
# 2711 Centerville Road 400, Wilmington, DE 19808 {'entities': [(5, 21, 'street'), (22, 25, 'nr'), (42, 47, 'postal'), (27, 37, 'city'), (39, 41, 'region')]}
# 409 Seville Drive, Red Lion, PA 17356 {'entities': [(4, 17, 'street'), (0, 3, 'nr'), (32, 37, 'postal'), (19, 27, 'city'), (29, 31, 'region')]}
# 234 Route de Sesigny, 74350 Cruseilles {'entities': [(4, 20, 'street'), (0, 3, 'nr'), (22, 27, 'postal'), (28, 38, 'city')]}
# Ottweilerstr. 12, 51375 Leverkusen {'entities': [(0, 13, 'street'), (14, 16, 'nr'), (18, 23, 'postal'), (24, 34, 'city')]}
# Landgrabenstrasse 94, 90443 Nürnberg {'entities': [(0, 17, 'street'), (18, 20, 'nr'), (22, 27, 'postal'), (28, 36, 'city')]}
# 13886 Camino Del Suleo, San Diego, CA 92129 {'entities': [(6, 22, 'street'), (0, 5, 'nr'), (38, 43, 'postal'), (24, 33, 'city'), (35, 37, 'region')]}
# c/o Sony Corporation 1-7-1 Konan Minato-ku, Tokyo {'entities': [(0, 20, 'co'), (21, 26, 'street'), (27, 32, 'area'), (33, 42, 'area'), (44, 49, 'city')]}
# Gas Chemical Company, Inc., 4-16-2, Hinagahigashi, Yokkaichi-shi MIE 510-0886 {'entities': [(0, 26, 'co'), (36, 49, 'area'), (51, 64, 'city'), (69, 77, 'region')]}
# 2-3, Marunouchi 2-chome, Chiyoda-ku, Tokyo 100-8310 {'entities': [(5, 23, 'co'), (0, 3, 'nr'), (25, 35, 'area'), (43, 51, 'postal'), (37, 42, 'city')]}
# WARNING: could not find token "kleine stadenstraat" in address "Kleine Stadenstraat 97c, 8830 Hooglede/Gits"
# Kleine Stadenstraat 97c, 8830 Hooglede/Gits {'entities': [(20, 23, 'nr'), (25, 29, 'postal'), (30, 43, 'city')]}
# WARNING: could not find token "kleine stadenstraat" in address "Kleine Stadenstraat 97c, 8830 Hooglede/Gits"
# Heinrich-Hertz-Strasse 1, 70327 Stuttgart {'entities': [(0, 22, 'street'), (23, 24, 'nr'), (26, 31, 'postal'), (32, 41, 'city')]}
# 11 Hamitzpe Street, P.O. Box 4467, Shoham 73142 {'entities': [(20, 33, 'building'), (3, 18, 'street'), (0, 2, 'nr'), (42, 47, 'postal'), (35, 41, 'city')]}
# 10, rue Saint-Jean, CH-1260 Nyon {'entities': [(4, 18, 'street'), (0, 2, 'nr'), (20, 27, 'postal'), (28, 32, 'city')]}
# 238 S Eagle Glen Trail, Columbia City, IN 46725 {'entities': [(4, 22, 'street'), (0, 3, 'nr'), (42, 47, 'postal'), (24, 37, 'city'), (39, 41, 'region')]}
# Broomhaugh House Riding Mill, Northumberland NE44 6EG {'entities': [(0, 16, 'building'), (45, 53, 'postal'), (17, 28, 'city'), (30, 44, 'region')]}
# 1708 Bluff Court, Garden City, KS 67846 {'entities': [(5, 16, 'street'), (0, 4, 'nr'), (34, 39, 'postal'), (18, 29, 'city'), (31, 33, 'region')]}
# WARNING: could not find token "kimball court" in address "1 Kimball Court, 504, Woburn, MA 01801"
# WARNING: could not find token "kimball court" in address "1 Kimball Court, 504, Woburn, MA 01801"
# WARNING: could not find token "woburn" in address "1 Kimball Court, 504, Woburn, MA 01801"
# 1 Kimball Court, 504, Woburn, MA 01801 {'entities': [(17, 20, 'nr'), (33, 38, 'postal'), (30, 32, 'region')]}
# WARNING: could not find token "kimball court" in address "1 Kimball Court, 504, Woburn, MA 01801"
# WARNING: could not find token "kimball court" in address "1 Kimball Court, 504, Woburn, MA 01801"
# WARNING: could not find token "woburn" in address "1 Kimball Court, 504, Woburn, MA 01801"
# WARNING: could not find token "Korea" in address "183-2, 5/5 Bokcheon-dong Dongrae-gu, Busan 607-020"
# 183-2, 5/5 Bokcheon-dong Dongrae-gu, Busan 607-020 {'entities': [(0, 5, 'street'), (7, 10, 'nr'), (11, 24, 'area'), (43, 50, 'postal'), (25, 35, 'city'), (37, 42, 'region')]}
# WARNING: could not find token "Korea" in address "183-2, 5/5 Bokcheon-dong Dongrae-gu, Busan 607-020"
# 21-1102 Sampoong Apt. 1685 Seocho-dong Seocho-ku, Seoul 137-070 {'entities': [(8, 20, 'building'), (27, 38, 'street'), (22, 26, 'nr'), (39, 48, 'area'), (56, 63, 'postal'), (50, 55, 'city')]}
# 2-12-1 Oogi-cho, Odawara-shi, Kanagawa-ken {'entities': [(0, 6, 'street'), (7, 15, 'street'), (17, 28, 'city'), (30, 42, 'region')]}
# Samsung Electronics Co., Ltd. 416, Maetan-dong, Yeongtong-gu Suwon-si Gyeonggi-do {'entities': [(0, 29, 'co'), (30, 33, 'street'), (35, 46, 'area'), (48, 60, 'area'), (61, 69, 'city'), (70, 81, 'region')]}
# Kawasaki Steel Corporation 1, Kawasakicho Chuo-ku, Chiba-shi Chiba, 260-0835 {'entities': [(0, 26, 'co'), (27, 28, 'nr'), (30, 49, 'area'), (68, 76, 'postal'), (51, 66, 'city')]}
# 1-27, Hirakata-cho Kanazawa-ku, Yokohama-shi Kanagawa 236-0023 {'entities': [(0, 18, 'street'), (19, 30, 'area'), (54, 62, 'postal'), (45, 53, 'city'), (32, 44, 'region')]}
# Disco Corporation 13-11, Omori-Kita 2-chome Ota-ku, Tokyo 143-8580 {'entities': []}
# 81N. Park Avenue, Fond du Lac WI 54935 {'entities': [(2, 16, 'street'), (0, 2, 'nr'), (33, 38, 'postal'), (18, 29, 'city'), (30, 32, 'region')]}
# WARNING: could not find token "Toyo 5-chome 14-11" in address "14-11, Toyo 5-chome, Kudamatsu-shi, Yamaguchi-ken"
# 14-11, Toyo 5-chome, Kudamatsu-shi, Yamaguchi-ken {'entities': [(21, 34, 'area'), (36, 49, 'region')]}
# WARNING: could not find token "Toyo 5-chome 14-11" in address "14-11, Toyo 5-chome, Kudamatsu-shi, Yamaguchi-ken"
# WARNING: could not find token "Minami-ashigara-shi" in address "210, Nakanuma, Minami-Ashigara-shi, Kanagawa"
# 210, Nakanuma, Minami-Ashigara-shi, Kanagawa {'entities': [(0, 3, 'street'), (5, 13, 'area'), (36, 44, 'region')]}
# WARNING: could not find token "Minami-ashigara-shi" in address "210, Nakanuma, Minami-Ashigara-shi, Kanagawa"
# WARNING: could not find token "21-1-507, Kamiooka-higashi" in address "21-1-507 Kamiooka-higashi 1-chome, Yokohama city, Kanagawa"
# 21-1-507 Kamiooka-higashi 1-chome, Yokohama city, Kanagawa {'entities': [(26, 33, 'street'), (35, 48, 'city'), (50, 58, 'region')]}
# WARNING: could not find token "21-1-507, Kamiooka-higashi" in address "21-1-507 Kamiooka-higashi 1-chome, Yokohama city, Kanagawa"
# 2000-1 Iwai, Iwata-Shi, Shizuoka-ken {'entities': [(7, 11, 'street'), (0, 6, 'nr'), (13, 22, 'city'), (24, 36, 'region')]}
# 2-15, Meiwadori 3-chome, Hyogo-ku, Kobe-shi, Hyogo 652-0882 {'entities': [(0, 4, 'street'), (6, 23, 'street'), (25, 33, 'area'), (51, 59, 'postal'), (35, 43, 'city'), (25, 30, 'region')]}
# La Priauraz, 1807 Blonay, Vaud {'entities': [(0, 11, 'street'), (13, 17, 'nr'), (18, 24, 'city'), (26, 30, 'region')]}
# WARNING: could not find token "Nahoya-shi" in address "2-56, Suda-cho, Mizuho-ku, Nagoya-shi, Aichi 467-8530"
# 2-56, Suda-cho, Mizuho-ku, Nagoya-shi, Aichi 467-8530 {'entities': [(0, 4, 'street'), (6, 14, 'area'), (16, 25, 'area'), (45, 53, 'postal'), (39, 44, 'region')]}
# WARNING: could not find token "Nahoya-shi" in address "2-56, Suda-cho, Mizuho-ku, Nagoya-shi, Aichi 467-8530"
# 1077 Kamitoyoura, Azuchi cho, Gamougun, Shiga {'entities': [(5, 16, 'street'), (0, 4, 'nr'), (30, 38, 'area'), (40, 45, 'city')]}
# Bahnhofstrasse 1, 35745 Herborn {'entities': [(0, 14, 'street'), (15, 16, 'nr'), (18, 23, 'postal'), (24, 31, 'city')]}
# Les Raffards, 42600 Precieux {'entities': [(0, 12, 'street'), (14, 19, 'postal'), (20, 28, 'city')]}
# Else-Lang-Strasse 14, 50858 Köln {'entities': [(0, 17, 'street'), (18, 20, 'nr'), (22, 27, 'postal'), (28, 32, 'city')]}
# Kurt-Schumacher-Ring 140, Leverkusen 51377 {'entities': [(0, 20, 'street'), (21, 24, 'nr'), (37, 42, 'postal'), (26, 36, 'city')]}
# 1-201, Fukuzaki 3-chome, Minato-ku Osaka-shi, Osaka 552-0013 {'entities': [(0, 5, 'nr'), (35, 44, 'area'), (52, 60, 'postal'), (35, 40, 'city')]}
# 3-30-2, Shimomaruko, Ohta-ku, Tokyo {'entities': [(0, 6, 'street'), (8, 19, 'area'), (21, 28, 'area'), (30, 35, 'city')]}
# Vlitingerbank 6, NL-6213KB Maastricht {'entities': [(0, 13, 'street'), (14, 15, 'nr'), (20, 26, 'postal'), (27, 37, 'city')]}
# WARNING: could not find token "Missouri" in address "5601 Paris Road, Columbia, MO 65201"
# 5601 Paris Road, Columbia, MO 65201 {'entities': [(5, 15, 'street'), (0, 4, 'nr'), (30, 35, 'postal'), (17, 25, 'city')]}
# WARNING: could not find token "Missouri" in address "5601 Paris Road, Columbia, MO 65201"
# Grand Soleil A202, 1526-1, Mitsujima, Kadomashi, Osaka 571-0015 {'entities': [(0, 12, 'co'), (13, 17, 'building'), (19, 25, 'street'), (27, 36, 'area'), (55, 63, 'postal'), (38, 47, 'city'), (49, 54, 'region')]}
# 27284 Avenida de la Plata, Laguna Niguel CA 92670 {'entities': [(6, 25, 'street'), (0, 5, 'nr'), (27, 40, 'city'), (44, 49, 'region')]}
# Yamaha Corporation, 10-1, Nakazawa-cho, Hamamatsu-shi, Shizuoka-ken {'entities': [(0, 18, 'co'), (26, 38, 'street'), (20, 24, 'nr'), (26, 38, 'area'), (40, 53, 'city'), (55, 67, 'region')]}
# 13 Harrier Park, Didcot, Oxfordshire OX11 7PL {'entities': [(3, 15, 'street'), (0, 2, 'nr'), (17, 23, 'area'), (37, 45, 'postal'), (25, 36, 'city')]}
# c/o Toshiba Corporation, Intellectual Prop. Div., 1-1-1 Shibaura Minato-ku Tokyo 105 {'entities': [(0, 48, 'co'), (50, 55, 'street'), (81, 84, 'nr'), (56, 64, 'area'), (65, 74, 'area'), (81, 84, 'postal'), (75, 80, 'city')]}
# 1370, Onna, Atsugi-shi, Kanagawa 243-8510 {'entities': [(0, 4, 'street'), (6, 10, 'area'), (33, 41, 'postal'), (12, 22, 'city'), (24, 32, 'region')]}
# Patentabteilung, Eisenhüttenstrasse 22, 57074 Siegen {'entities': [(17, 35, 'street'), (36, 38, 'nr'), (40, 45, 'postal'), (46, 52, 'city')]}
# WARNING: could not find token "53-12-713 Itabashi 1-chome" in address "53-12-713, Itabashi 1-chome, Itabashi-ku, Tokyo 173-0004"
# 53-12-713, Itabashi 1-chome, Itabashi-ku, Tokyo 173-0004 {'entities': [(29, 40, 'area'), (42, 47, 'city')]}
# WARNING: could not find token "53-12-713 Itabashi 1-chome" in address "53-12-713, Itabashi 1-chome, Itabashi-ku, Tokyo 173-0004"
# 109-604, Geonyoung APT., 1094, Jisan-dong, Pyeongtaek, Kyunggi-do, 459-110, Korea {'entities': [(9, 23, 'building'), (0, 7, 'street'), (25, 29, 'nr'), (31, 41, 'area'), (67, 74, 'postal'), (43, 53, 'city'), (55, 65, 'region'), (76, 81, 'country')]}
# 6837 S. Fredericksburg, Sylvania, OH 43560 {'entities': [(5, 22, 'street'), (0, 4, 'nr'), (37, 42, 'postal'), (24, 32, 'city'), (34, 36, 'region')]}
# Lindenstrasse 47, 14548 Caputh {'entities': [(0, 13, 'street'), (14, 16, 'nr'), (18, 23, 'postal'), (24, 30, 'city')]}
# 11, rue Amédée Dailly, F-78220 Viroflay {'entities': [(4, 21, 'street'), (0, 2, 'nr'), (23, 30, 'postal'), (31, 39, 'city')]}
# 3105 Honey Tree Lane, Austin, TX 78746 {'entities': [(5, 20, 'street'), (0, 4, 'nr'), (33, 38, 'postal'), (22, 28, 'city'), (30, 32, 'region')]}
# 15bis, rue Eitel, F-49300 Cholet {'entities': [(7, 16, 'street'), (0, 5, 'nr'), (18, 25, 'postal'), (26, 32, 'city')]}
# Steinkamp 3a, 48165 Münster {'entities': [(0, 9, 'street'), (10, 12, 'nr'), (14, 19, 'postal'), (20, 27, 'city')]}
# 2, Annette's Croft, Church Crookham, Fleet, Hampshire GU13 OXN {'entities': [(3, 18, 'street'), (0, 1, 'nr'), (54, 62, 'postal'), (20, 35, 'city'), (44, 53, 'region')]}
# 16 Skehan Street, Somerville, MA 02143 {'entities': [(3, 16, 'street'), (0, 2, 'nr'), (33, 38, 'postal'), (18, 28, 'city'), (30, 32, 'region')]}
# WARNING: could not find token "Winbourne" in address "87 Sopwith Crescent Merley, Wimbourne, Dorset BH21 35W"
# 87 Sopwith Crescent Merley, Wimbourne, Dorset BH21 35W {'entities': [(3, 19, 'street'), (0, 2, 'nr'), (20, 26, 'area'), (46, 54, 'postal'), (39, 45, 'city')]}
# WARNING: could not find token "Winbourne" in address "87 Sopwith Crescent Merley, Wimbourne, Dorset BH21 35W"
# WARNING: could not find token "Saint-Laurent-du-Tencement" in address "La Houssaye, 27390 Saint Laurent du Tencement"
# La Houssaye, 27390 Saint Laurent du Tencement {'entities': [(0, 11, 'area'), (13, 18, 'postal')]}
# WARNING: could not find token "Saint-Laurent-du-Tencement" in address "La Houssaye, 27390 Saint Laurent du Tencement"
# 72, route de Bellegarde, 1284 Chancy {'entities': [(4, 23, 'street'), (0, 2, 'nr'), (25, 29, 'postal'), (30, 36, 'city')]}
# Schillerstr. 18, 85139 Wettstetten {'entities': [(0, 11, 'street'), (13, 15, 'nr'), (17, 22, 'postal'), (23, 34, 'city')]}
# Vingalandsgatan 8, 417 63 Göteborg {'entities': [(0, 15, 'street'), (16, 17, 'nr'), (19, 25, 'postal'), (26, 34, 'city')]}
# Grote Maatweg 13, 7642 VN Wierden {'entities': [(0, 13, 'street'), (14, 16, 'nr'), (18, 22, 'postal'), (26, 33, 'city')]}
# Five Moore Drive, P.O. Box 13398, Research Triangle Park, NC 27708 {'entities': [(0, 16, 'street'), (18, 32, 'nr'), (61, 66, 'postal'), (34, 56, 'city'), (58, 60, 'region')]}
# 8808 Watlington Road, Richmond, VA 23229 {'entities': [(5, 20, 'street'), (0, 4, 'nr'), (35, 40, 'postal'), (22, 30, 'city'), (32, 34, 'region')]}
# B.P. 204, F-76053 Le Havre Cedex {'entities': [(0, 8, 'street'), (10, 17, 'postal'), (18, 26, 'city')]}
# Harbitzalleen 18B, N-0275 Oslo {'entities': [(0, 13, 'street'), (14, 17, 'nr'), (19, 25, 'postal'), (26, 30, 'city')]}
# 1000 Holland Drive, Crete, IL 60417-2120 {'entities': [(5, 18, 'street'), (0, 4, 'nr'), (30, 40, 'postal'), (20, 25, 'city'), (27, 29, 'region')]}
# Postiljooninkatu 3, FIN-05800 Hyvinkää {'entities': [(0, 16, 'street'), (17, 18, 'nr'), (24, 29, 'postal'), (30, 38, 'city')]}
# Winkel 11, 91572 Bechhofen {'entities': [(0, 6, 'street'), (7, 9, 'nr'), (11, 16, 'postal'), (17, 26, 'city')]}
# c/o Mani, Inc., 743, Naka Akutsu, Takanezawa-machi, Shioya-gun, Tochigi-ken {'entities': [(0, 14, 'building'), (16, 19, 'nr'), (21, 32, 'area'), (34, 50, 'city'), (52, 62, 'city'), (64, 75, 'region')]}
# 803 Kirts Blvd., Troy, MI 48084 {'entities': [(4, 15, 'street'), (0, 3, 'nr'), (23, 31, 'postal'), (17, 21, 'city'), (23, 25, 'region')]}
# WARNING: could not find token "New Marunouchi bldg." in address "Hitachi Ltd., New Marunouchi Bldg., 5-1, Marunouchi, 1-chome, Chiyoda-ku, Tokyo 100-8220"
# WARNING: could not find token "1-chome 5-1" in address "Hitachi Ltd., New Marunouchi Bldg., 5-1, Marunouchi, 1-chome, Chiyoda-ku, Tokyo 100-8220"
# Hitachi Ltd., New Marunouchi Bldg., 5-1, Marunouchi, 1-chome, Chiyoda-ku, Tokyo 100-8220 {'entities': [(0, 12, 'co'), (18, 28, 'area'), (62, 72, 'area'), (80, 88, 'postal'), (74, 79, 'city')]}
# WARNING: could not find token "New Marunouchi bldg." in address "Hitachi Ltd., New Marunouchi Bldg., 5-1, Marunouchi, 1-chome, Chiyoda-ku, Tokyo 100-8220"
# WARNING: could not find token "1-chome 5-1" in address "Hitachi Ltd., New Marunouchi Bldg., 5-1, Marunouchi, 1-chome, Chiyoda-ku, Tokyo 100-8220"
# No. 5, Wen Hua Lane, Shan Ying Road, Guei Shan Shiang, Taoyuan, Taiwan 333 {'entities': [(21, 35, 'street'), (4, 5, 'nr'), (55, 62, 'city'), (64, 70, 'region')]}
# 1917 Trixie Lane, Houston, Texas 77042 {'entities': [(5, 16, 'street'), (0, 4, 'nr'), (33, 38, 'postal'), (18, 25, 'city'), (27, 32, 'region')]}
# Prof. Holstlaan 6, NL-5656 AA Eindhoven {'entities': [(0, 15, 'street'), (16, 17, 'nr'), (22, 29, 'postal'), (30, 39, 'city')]}
# Ebersteinstrasse 35, 75177 Pforzheim {'entities': [(0, 16, 'street'), (17, 19, 'nr'), (21, 26, 'postal'), (27, 36, 'city')]}
# c/o Mitsui Chemicals, Inc. 1144, Togo, Mobara-shi, Chiba 297-0017 {'entities': [(0, 26, 'co'), (33, 37, 'area'), (57, 65, 'postal'), (39, 49, 'city'), (51, 56, 'region')]}
# 50 Pinsker Street, 46490 Herzelia {'entities': [(3, 17, 'street'), (0, 2, 'nr'), (19, 24, 'postal'), (25, 33, 'city')]}
# Frauenhoferstrasse 5, 84524 Neuötting {'entities': [(0, 18, 'street'), (19, 20, 'nr'), (22, 27, 'postal'), (28, 37, 'city')]}
# P.O. Box 826, Unionville, PA 19375 {'entities': [(0, 12, 'street'), (29, 34, 'postal'), (14, 24, 'city'), (26, 28, 'region')]}
# c/o Mitsubishi Denki Kabushiki Kaisha, 2-3, Marunouchi 2-chome, Chiyoda-ku Tokyo 100-8310 {'entities': [(0, 37, 'co'), (44, 62, 'street'), (39, 42, 'nr'), (64, 74, 'area'), (81, 89, 'postal'), (75, 80, 'city')]}
# 1 Thew Parade, Dee Why, Sydney NSW 2099 {'entities': [(2, 13, 'street'), (0, 1, 'nr'), (15, 22, 'area'), (35, 39, 'postal'), (24, 30, 'city'), (31, 34, 'region')]}
# Keilaranta 6, 02150 Espoo {'entities': [(0, 10, 'street'), (11, 12, 'nr'), (14, 19, 'postal'), (20, 25, 'city')]}
# 422B West Street, Fort Lee, NJ 07024 {'entities': [(5, 16, 'street'), (0, 4, 'nr'), (31, 36, 'postal'), (18, 26, 'city'), (28, 30, 'region')]}
# 45 Harrison Avenue, apt. 1B, Branford, CT 06405 {'entities': [(3, 18, 'street'), (0, 2, 'nr'), (42, 47, 'postal'), (29, 37, 'city'), (39, 41, 'region')]}
# WARNING: could not find token "280 Madison Avenue" in address "280, Madison Avenue, Suite 110, New York, N.Y. 10016"
# WARNING: could not find token "NY" in address "280, Madison Avenue, Suite 110, New York, N.Y. 10016"
# 280, Madison Avenue, Suite 110, New York, N.Y. 10016 {'entities': [(27, 30, 'nr'), (47, 52, 'postal'), (32, 40, 'city')]}
# WARNING: could not find token "280 Madison Avenue" in address "280, Madison Avenue, Suite 110, New York, N.Y. 10016"
# WARNING: could not find token "NY" in address "280, Madison Avenue, Suite 110, New York, N.Y. 10016"
# WARNING: could not find token "2-chome 2-3" in address "Mitsubishi Denki K.K. 2-3 Marunouchi 2-chome, Chiyoda-ku Tokyo 100"
# Mitsubishi Denki K.K. 2-3 Marunouchi 2-chome, Chiyoda-ku Tokyo 100 {'entities': [(0, 21, 'co'), (26, 36, 'area'), (46, 56, 'area'), (63, 66, 'postal'), (57, 62, 'city')]}
# WARNING: could not find token "2-chome 2-3" in address "Mitsubishi Denki K.K. 2-3 Marunouchi 2-chome, Chiyoda-ku Tokyo 100"
# Mokryun Apt. 1241-1005 1091-1, Sanbon-Dong, Gunpo Gyeonggi-Do {'entities': [(0, 7, 'co'), (8, 22, 'building'), (23, 29, 'nr'), (31, 42, 'area'), (44, 49, 'city'), (50, 61, 'region')]}
# 300-18, Aza Toyohara, Oaza Motohara, Kamikawamachi, ,Kodama-gun Saitama {'entities': [(0, 6, 'street'), (8, 20, 'area'), (53, 63, 'city'), (37, 50, 'city'), (64, 71, 'region')]}
# WARNING: could not find token "PO box 6321" in address "PO Box 6321, Loughborough LE11 3XZ"
# PO Box 6321, Loughborough LE11 3XZ {'entities': [(26, 34, 'postal'), (13, 25, 'city')]}
# WARNING: could not find token "PO box 6321" in address "PO Box 6321, Loughborough LE11 3XZ"
# 2 Sconsett Bluff, Avon, CT 06001 {'entities': [(2, 16, 'street'), (0, 1, 'nr'), (24, 32, 'postal'), (18, 22, 'city'), (24, 26, 'region')]}
# 14, rue des Hauts Pâturages, 67210 Obernai {'entities': [(4, 27, 'street'), (0, 2, 'nr'), (29, 34, 'postal'), (35, 42, 'city')]}
# Werk Gendorf, 84508 Burgkirchen {'entities': [(0, 12, 'area'), (14, 19, 'postal'), (20, 31, 'city')]}
# 8332 Querbes, Montréal, Québec H3N 2C5 {'entities': [(0, 4, 'building'), (5, 12, 'street'), (31, 38, 'postal'), (14, 22, 'city'), (24, 30, 'region')]}
# 7041 East Edgemont Street, Tucson, AZ 85710 {'entities': [(5, 25, 'street'), (0, 4, 'nr'), (38, 43, 'postal'), (27, 33, 'city'), (35, 37, 'region')]}
# 3, rue de l'Isly, F-75008 PARIS {'entities': [(3, 16, 'street'), (0, 1, 'nr'), (18, 25, 'postal'), (26, 31, 'city')]}
# Shibukawa Kojo, 1135 Nakamura, Shibukawa-shi, Gunma 377-0002 {'entities': [(0, 14, 'building'), (16, 20, 'street'), (21, 29, 'area'), (52, 60, 'postal'), (31, 44, 'city'), (46, 51, 'region')]}
# Kilianstrasse 18, 33142 Büren {'entities': [(0, 13, 'street'), (14, 16, 'nr'), (18, 23, 'postal'), (24, 29, 'city')]}
# Am Breitenberg 14, 37534 Badenhaussen {'entities': [(0, 14, 'street'), (15, 17, 'nr'), (19, 24, 'postal'), (25, 37, 'city')]}
# Im Schaffner 3, 69123 Heidelberg {'entities': [(0, 12, 'street'), (13, 14, 'nr'), (16, 21, 'postal'), (22, 32, 'city')]}
# 735 Braewood Drive, Algonquin, Illinois 60102 {'entities': [(4, 18, 'street'), (0, 3, 'nr'), (40, 45, 'postal'), (20, 29, 'city'), (31, 39, 'region')]}
# 2207 Pine Ridge Court, Niskayuna New York 12309 {'entities': [(5, 21, 'street'), (0, 4, 'nr'), (23, 32, 'area'), (42, 47, 'postal'), (33, 41, 'city')]}
# 61 rue de Roth, 57910 Neufgrange {'entities': [(3, 14, 'street'), (0, 2, 'nr'), (16, 21, 'postal'), (22, 32, 'city')]}
# 34 bis, rue Edouard Ruy, 27200 Vernon {'entities': [(8, 23, 'street'), (0, 6, 'nr'), (25, 30, 'postal'), (31, 37, 'city')]}
# Lerchtensternstrasse 6A, 50937 Köln {'entities': [(0, 20, 'street'), (21, 23, 'nr'), (25, 30, 'postal'), (31, 35, 'city')]}
# 1 Bioscience Park Drive, Farmingdale, NY 11735 {'entities': [(2, 23, 'street'), (0, 1, 'nr'), (25, 36, 'area'), (41, 46, 'postal'), (38, 40, 'region')]}
# Asveien 21, N-4817 HIS {'entities': [(0, 7, 'street'), (8, 10, 'nr'), (12, 18, 'postal'), (19, 22, 'city')]}
# 1514 Titania Road, Tobyhanna, PA 18466 {'entities': [(5, 17, 'street'), (0, 4, 'nr'), (19, 28, 'area'), (33, 38, 'postal'), (30, 32, 'region')]}
# Bringetoften 3, DK-3400 Vaerlose {'entities': [(0, 12, 'street'), (13, 14, 'nr'), (16, 23, 'postal'), (24, 32, 'city')]}
# 4140 S.W. Greenhills Way, Portland, OR 97221 {'entities': [(5, 24, 'street'), (0, 4, 'nr'), (39, 44, 'postal'), (26, 34, 'city'), (36, 38, 'region')]}
# WARNING: could not find token "Florida" in address "3040 Malcolm Drive, Deltona, FL 32738"
# 3040 Malcolm Drive, Deltona, FL 32738 {'entities': [(5, 18, 'street'), (0, 4, 'nr'), (29, 37, 'postal'), (20, 27, 'city')]}
# WARNING: could not find token "Florida" in address "3040 Malcolm Drive, Deltona, FL 32738"
# c/o Prof.Holstlaan 6, NL-5656 AA Eindhoven {'entities': [(4, 18, 'street'), (19, 20, 'nr'), (33, 42, 'city'), (22, 32, 'region')]}
# Am Dornenbusch 12, B-4700 Eupen {'entities': [(0, 14, 'street'), (15, 17, 'nr'), (19, 25, 'postal'), (26, 31, 'city')]}
# Dälavägen 87, S-437 36 Torslanda {'entities': [(0, 9, 'street'), (10, 12, 'nr'), (14, 22, 'postal'), (23, 32, 'city')]}
# Langhusallén 2, SE-30250 Halmstad {'entities': [(0, 12, 'street'), (13, 14, 'nr'), (16, 24, 'postal'), (25, 33, 'city')]}
# 11527 Gallant Ridge Lane, Houston 77082 {'entities': [(6, 24, 'street'), (0, 5, 'nr'), (34, 39, 'postal'), (26, 33, 'city')]}
# 1, rue Henri Dunant, 1340 Aubagne {'entities': [(3, 19, 'street'), (0, 1, 'nr'), (21, 25, 'postal'), (26, 33, 'city')]}
# Pfizer Global Research & Development, 201 Tabor Road Morris Plains, NJ 07950 {'entities': [(0, 6, 'co'), (7, 36, 'building'), (42, 52, 'street'), (38, 41, 'nr'), (53, 66, 'area'), (71, 76, 'postal'), (68, 70, 'region')]}
# 8906 Hialeah Drive, West Chester, OH 45069 {'entities': [(5, 18, 'street'), (0, 4, 'nr'), (20, 32, 'city')]}
# 180 Michael Drive, Campbell, CA 95008 {'entities': [(4, 17, 'street'), (0, 3, 'nr'), (32, 37, 'postal'), (19, 27, 'city'), (29, 31, 'region')]}
# 195-16, Kamitomii, Kurashiki-shi, Okayama, 7100846 {'entities': [(0, 6, 'nr'), (19, 32, 'area'), (8, 17, 'area'), (43, 50, 'postal'), (34, 41, 'city')]}
# 109, 103-156 Sillim 2-dong, Gwanak-gu, Seoul 151-856 {'entities': [(0, 3, 'building'), (5, 26, 'street'), (28, 37, 'area'), (45, 52, 'postal'), (39, 44, 'city')]}
# 12-4, Sagisu 5-chome, Fukushima-ku, Osaka-shi, Osaka; 5530 002 {'entities': [(0, 4, 'street'), (6, 20, 'street'), (22, 34, 'area'), (54, 62, 'postal'), (36, 45, 'city'), (36, 41, 'region')]}
# 55 Littleton Road, Unit 29b, Ayer, Massachusetts 01432 {'entities': [(19, 27, 'building'), (3, 17, 'street'), (0, 2, 'nr'), (49, 54, 'postal'), (29, 33, 'city'), (35, 48, 'region')]}
# Pre Marétan 4, 1274 Grens {'entities': [(0, 11, 'street'), (12, 13, 'nr'), (15, 19, 'postal'), (20, 25, 'city')]}
# WARNING: could not find token "2-1816-201 Ohashi-cho" in address "2-1816-201, Ohashi-cho, Ashikaga-shi, Tochigi 326-0051"
# 2-1816-201, Ohashi-cho, Ashikaga-shi, Tochigi 326-0051 {'entities': [(46, 54, 'postal'), (24, 36, 'city'), (38, 45, 'region')]}
# WARNING: could not find token "2-1816-201 Ohashi-cho" in address "2-1816-201, Ohashi-cho, Ashikaga-shi, Tochigi 326-0051"
# WARNING: could not find token "Nonhyeon-dong" in address "111-201, Nonhyun-dong, Gangnam-gu, Seoul"
# 111-201, Nonhyun-dong, Gangnam-gu, Seoul {'entities': [(0, 7, 'nr'), (23, 33, 'area'), (35, 40, 'city')]}
# WARNING: could not find token "Nonhyeon-dong" in address "111-201, Nonhyun-dong, Gangnam-gu, Seoul"
# 9, Coronation Drive, 269564, Singapore {'entities': [(0, 1, 'nr'), (3, 19, 'area'), (21, 27, 'postal'), (29, 38, 'city')]}
# 36 Wildcat Branch Road, Sicklerville, NJ 08081 {'entities': [(3, 22, 'street'), (0, 2, 'nr'), (24, 36, 'area'), (41, 46, 'postal'), (38, 40, 'region')]}
# Iglauer Strasse 21, 93197 Zeitlarn {'entities': [(0, 15, 'street'), (16, 18, 'nr'), (20, 25, 'postal'), (26, 34, 'city')]}
# c/o Shinko El. Ind. Co., Ltd. 80, Oshimada-machi, Nagano-shi Nagano 381-2287 {'entities': [(0, 23, 'co'), (25, 29, 'building'), (34, 48, 'street'), (30, 32, 'nr'), (68, 76, 'postal'), (50, 60, 'city'), (50, 56, 'region')]}
# 129 Blay Ridge Parkway, Apt. 3, Brooklyn, NY 11209 {'entities': [(24, 30, 'building'), (4, 22, 'street'), (0, 3, 'nr'), (32, 40, 'area'), (45, 50, 'postal'), (42, 44, 'region')]}
# Via L. Russo, 7, 93012 Gela (CL) {'entities': [(0, 12, 'street'), (14, 15, 'nr'), (17, 22, 'postal'), (23, 27, 'city'), (28, 32, 'region')]}
# WARNING: could not find token "MN" in address "12999 Mississippi Rd., Elk River, Minnesota 55330"
# 12999 Mississippi Rd., Elk River, Minnesota 55330 {'entities': [(6, 21, 'street'), (0, 5, 'nr'), (44, 49, 'postal'), (23, 32, 'city')]}
# WARNING: could not find token "MN" in address "12999 Mississippi Rd., Elk River, Minnesota 55330"
# 1715 North Umberland Way, Monmouth Junction, New Jersey 08852 {'entities': [(5, 24, 'street'), (0, 4, 'nr'), (56, 61, 'postal'), (26, 43, 'city'), (45, 55, 'region')]}
# 109 Monticello Avenue, Durham, North Carolina 27707 {'entities': [(4, 21, 'street'), (0, 3, 'nr'), (46, 51, 'postal'), (23, 29, 'city'), (31, 45, 'region')]}
# 3451 E. Remington Drive, Gilbert, Arizone 85297 {'entities': [(5, 23, 'street'), (0, 4, 'nr'), (42, 47, 'postal'), (25, 32, 'city'), (34, 41, 'region')]}
# WARNING: could not find token "FI-255570" in address "Merikulmantie 553, FI-25570 Teijo"
# Merikulmantie 553, FI-25570 Teijo {'entities': [(0, 13, 'street'), (14, 17, 'nr'), (28, 33, 'city')]}
# WARNING: could not find token "FI-255570" in address "Merikulmantie 553, FI-25570 Teijo"
# 409 SW 348th Ct, Federal Way, WA 98023 {'entities': [(4, 15, 'street'), (0, 3, 'nr'), (33, 38, 'postal'), (17, 28, 'city'), (30, 32, 'region')]}
# Endgrube 18, 97616 Bad Neustadt {'entities': [(0, 8, 'street'), (9, 11, 'nr'), (13, 18, 'postal'), (19, 31, 'city')]}
# c/o Qualcomm Incorporated T-160D 5775 Morehouse Drive, San Diego CA 92121-1714 {'entities': [(0, 32, 'co'), (38, 53, 'street'), (33, 37, 'nr'), (68, 78, 'postal'), (55, 64, 'city'), (65, 67, 'region')]}
# Norra Skeppspromenaden 6, 41763 Göteborg {'entities': [(0, 22, 'street'), (23, 24, 'nr'), (26, 31, 'postal'), (32, 40, 'city')]}
# Goldshöfe im Forst, D-7095 Rainau/Württ {'entities': [(0, 9, 'building'), (10, 18, 'street'), (27, 33, 'city'), (34, 39, 'region')]}
# 2167 Parkplace Drive, Walled Lake Michigan 48088 {'entities': [(5, 20, 'street'), (0, 4, 'nr'), (43, 48, 'postal'), (22, 33, 'city')]}
# WARNING: could not find token "Turbizestrasse" in address "Tubizerstrasse 62, D-7015 Korntal"
# Tubizerstrasse 62, D-7015 Korntal {'entities': [(15, 17, 'nr'), (19, 25, 'postal'), (26, 33, 'city')]}
# WARNING: could not find token "Turbizestrasse" in address "Tubizerstrasse 62, D-7015 Korntal"
# Emslandstrasse 3, D-4370 Marl {'entities': [(0, 14, 'street'), (15, 16, 'nr'), (18, 24, 'postal'), (25, 29, 'city')]}
# Nachtigallenweg 1a, D-6233 Kalkheim (Taunus) {'entities': [(0, 15, 'street'), (16, 18, 'nr'), (20, 26, 'postal'), (27, 44, 'city')]}
# 79-19 269th Street, New Hyde Park New York {'entities': [(6, 18, 'street'), (0, 5, 'nr'), (20, 33, 'area'), (34, 42, 'city')]}
# Via Garibaldi, 29, Zola Predosa I-40069 Bologna {'entities': [(0, 12, 'street'), (15, 17, 'nr'), (19, 31, 'area'), (32, 39, 'postal'), (40, 47, 'city')]}
# WARNING: could not find token "TOKYA" in address "1-21-2, Dohgenzaka Shibuya-ku, Tokyo 150"
# 1-21-2, Dohgenzaka Shibuya-ku, Tokyo 150 {'entities': [(37, 40, 'building'), (0, 6, 'street'), (8, 29, 'area')]}
# WARNING: could not find token "TOKYA" in address "1-21-2, Dohgenzaka Shibuya-ku, Tokyo 150"
# 2-21-13, Uragamidai, Yokusuka-Shi Kanagawa-Ken {'entities': [(0, 7, 'street'), (9, 19, 'area'), (21, 33, 'city'), (34, 46, 'region')]}
# Bensberger Strasse 224 f, D-5064 Forsbach {'entities': [(0, 18, 'street'), (19, 24, 'nr'), (26, 32, 'postal'), (33, 41, 'city')]}
# Brucknerstrasse 27, D-6103 Griesheim {'entities': [(0, 15, 'street'), (16, 18, 'nr'), (20, 26, 'postal'), (27, 36, 'city')]}
# Les Escouradières, F-83230 Le Beausset {'entities': [(0, 17, 'street'), (19, 26, 'postal'), (27, 38, 'city')]}
# Route de Thouars, F-79700 Mauleon {'entities': [(0, 16, 'street'), (18, 25, 'postal'), (26, 33, 'city')]}
# WARNING: could not find token "Riviera-Pays-d'Enhaut" in address "Route du Monteliza, CH-1806 St-Légier"
# WARNING: could not find token "Saint-Légier-La Chiésaz" in address "Route du Monteliza, CH-1806 St-Légier"
# Route du Monteliza, CH-1806 St-Légier {'entities': [(0, 18, 'street'), (23, 27, 'postal')]}
# WARNING: could not find token "Riviera-Pays-d'Enhaut" in address "Route du Monteliza, CH-1806 St-Légier"
# WARNING: could not find token "Saint-Légier-La Chiésaz" in address "Route du Monteliza, CH-1806 St-Légier"
# Alvinci u. 27, H-1022 Budapest {'entities': [(0, 10, 'street'), (11, 13, 'nr'), (15, 21, 'postal'), (22, 30, 'city')]}
# THOMSON-CSF SCPI 173, bld Haussmann, F-75379 Paris Cedex 08 {'entities': [(0, 16, 'co'), (22, 35, 'street'), (17, 20, 'nr'), (37, 44, 'postal'), (45, 59, 'city')]}
# 4-105 City House, 3440-1, Nishikata, Koshigaya-shi Saitama-ken {'entities': [(0, 16, 'street'), (26, 35, 'area'), (18, 24, 'postal'), (37, 50, 'city'), (51, 62, 'region')]}
# Strada Statale, 26, I-11010 Sarre (Aosta) {'entities': [(0, 14, 'street'), (16, 18, 'nr'), (20, 27, 'postal'), (28, 33, 'city'), (35, 40, 'region')]}
# P.O. Box 34244 Station D Vancouver, British Columbia V6J 4N8 {'entities': [(15, 24, 'building'), (0, 14, 'street'), (53, 60, 'postal'), (25, 34, 'city'), (36, 52, 'region')]}
# 5141 South Kimbark, Chicago, IL 60615 {'entities': [(0, 4, 'nr'), (5, 18, 'area'), (32, 37, 'postal'), (20, 27, 'city'), (29, 31, 'region')]}
# WARNING: could not find token "GA" in address "101 Gould Street, St. Simons Island Georgia 31522"
# 101 Gould Street, St. Simons Island Georgia 31522 {'entities': [(4, 16, 'street'), (0, 3, 'nr'), (18, 35, 'area'), (44, 49, 'postal')]}
# WARNING: could not find token "GA" in address "101 Gould Street, St. Simons Island Georgia 31522"
# 30 Robinhood Road, Nashua, NH 03062 {'entities': [(3, 17, 'street'), (0, 2, 'nr'), (30, 35, 'postal'), (19, 25, 'city'), (27, 29, 'region')]}
# 6 New Chester Road, New Ferry, Wirral L62 5AA {'entities': [(2, 18, 'street'), (0, 1, 'nr'), (38, 45, 'postal'), (20, 29, 'region'), (31, 37, 'region')]}
# Krottnaurer Str. 24a, D-1000 Berlin 38 {'entities': [(0, 16, 'street'), (17, 20, 'nr'), (29, 35, 'city')]}
# Templergraben 55, D-5100 Aachen {'entities': [(0, 13, 'street'), (14, 16, 'nr'), (18, 24, 'postal'), (25, 31, 'city')]}
# 50-6, Ipponmatsu, Menjyo, Yamato-cho, Ichinomiya-shi Aichi-pref.491 {'entities': [(6, 16, 'street'), (0, 4, 'nr'), (18, 24, 'area'), (26, 36, 'area'), (38, 52, 'area'), (64, 67, 'postal'), (53, 58, 'city')]}
# Verseny u.21c, H-8360 Keszthely {'entities': [(0, 10, 'street'), (10, 13, 'nr'), (15, 21, 'postal'), (22, 31, 'city')]}
# Baltrumstrasse 12, D-4000 Düsseldorf 30 {'entities': []}
# WARNING: could not find token "1–1 Shibaura, 1-chome" in address "Kabushiki Kaisha Toshiba 1-1, Shibaura 1-chome, Minato-ku Tokyo"
# Kabushiki Kaisha Toshiba 1-1, Shibaura 1-chome, Minato-ku Tokyo {'entities': [(0, 24, 'co'), (48, 57, 'area'), (58, 63, 'city')]}
# WARNING: could not find token "1–1 Shibaura, 1-chome" in address "Kabushiki Kaisha Toshiba 1-1, Shibaura 1-chome, Minato-ku Tokyo"
# WARNING: could not find token "8-chome 1-1" in address "Itami Seisakusho 1-1, Tsukaguchihonmachi 8-chome, Amagasaki-shi Hyogo 661"
# Itami Seisakusho 1-1, Tsukaguchihonmachi 8-chome, Amagasaki-shi Hyogo 661 {'entities': [(0, 16, 'co'), (22, 40, 'area'), (70, 73, 'postal'), (50, 63, 'city'), (64, 69, 'region')]}
# WARNING: could not find token "8-chome 1-1" in address "Itami Seisakusho 1-1, Tsukaguchihonmachi 8-chome, Amagasaki-shi Hyogo 661"
# Via Trinita 17/A, I-10026 Santena Torino {'entities': [(0, 11, 'street'), (12, 16, 'nr'), (18, 25, 'postal'), (26, 40, 'city')]}
# 42, Via Trieste, I-20051 Limbiate Milano {'entities': [(4, 15, 'street'), (0, 2, 'nr'), (17, 24, 'postal'), (25, 40, 'city')]}
# 1-28-5-302, Ozu-cho, Iwakuni-shi Yamaguchi-ken {'entities': [(0, 10, 'street'), (12, 19, 'area'), (21, 32, 'city'), (33, 46, 'region')]}
# WARNING: could not find token "5-chome 1-1" in address "Kabushiki Kaisha Communication Systems Dev. Lab., 1-1, Ofuna 5-chome Kamakura-shi Kanagawa"
# Kabushiki Kaisha Communication Systems Dev. Lab., 1-1, Ofuna 5-chome Kamakura-shi Kanagawa {'entities': [(0, 48, 'co'), (55, 60, 'area'), (69, 81, 'city'), (82, 90, 'region')]}
# WARNING: could not find token "5-chome 1-1" in address "Kabushiki Kaisha Communication Systems Dev. Lab., 1-1, Ofuna 5-chome Kamakura-shi Kanagawa"
# 14 Duntrune Terrace West Ferry, Dundee DD5 1LF Scotland {'entities': [(0, 19, 'street'), (0, 2, 'nr'), (20, 30, 'area'), (39, 46, 'postal'), (32, 38, 'city'), (47, 55, 'country')]}
# 419 Buchanan Avenue, Staten Island, NY 10314 {'entities': [(4, 19, 'street'), (0, 3, 'nr'), (39, 44, 'postal'), (21, 34, 'city'), (36, 38, 'region')]}
# 26 W. Torrence Road, Columbus, OH 43214 {'entities': [(3, 19, 'street'), (0, 2, 'nr'), (34, 39, 'postal'), (21, 29, 'city'), (31, 33, 'region')]}
# Kabushiki Kaisha Toshiba, 1-1 Shibaura 1-chome, Minato-ku, Tokyo 105 {'entities': []}
# WARNING: could not find token "Avenue slegers" in address "Avenue Slegers, 207, B-1200 Bruxelles"
# Avenue Slegers, 207, B-1200 Bruxelles {'entities': [(16, 19, 'nr'), (23, 27, 'postal'), (28, 37, 'city')]}
# WARNING: could not find token "Avenue slegers" in address "Avenue Slegers, 207, B-1200 Bruxelles"
# WARNING: could not find token "Minamisemba" in address "4-8, Minamisenba 2-chome, Chuo-ku, Osaka"
# 4-8, Minamisenba 2-chome, Chuo-ku, Osaka {'entities': [(0, 3, 'street'), (26, 33, 'area'), (17, 24, 'area'), (35, 40, 'city')]}
# WARNING: could not find token "Minamisemba" in address "4-8, Minamisenba 2-chome, Chuo-ku, Osaka"
# SOCIETE CIVILE S.P.I.D., 156 Bd Haussmann, F-75008 Paris {'entities': [(0, 23, 'co'), (29, 41, 'street'), (25, 28, 'nr'), (43, 50, 'postal'), (51, 56, 'city')]}
# 15, rue Gambetta, F-95330 La Frette-sur-Seine {'entities': [(4, 16, 'street'), (0, 2, 'nr'), (18, 25, 'postal'), (26, 45, 'city')]}
# Maisstrasse 3 D, W-8900 Augsburg 21 {'entities': [(0, 11, 'street'), (12, 15, 'nr'), (17, 23, 'postal'), (24, 32, 'city')]}
# c/o Canon K.K., 3-30-2 Shimomaruko, Ohta-ku, Tokyo {'entities': [(4, 13, 'co'), (16, 34, 'street'), (36, 43, 'area'), (45, 50, 'city')]}
# Peter-Henlein-Stra e 24, D-8562 Hersbruck {'entities': [(0, 18, 'street'), (21, 23, 'nr'), (32, 41, 'area'), (25, 31, 'postal')]}
# Intell. Prop. Center, 20, Igadera, Shimo-Kaiinji, Nagaokakyo-City, Kyoto 617 {'entities': [(0, 20, 'building'), (22, 48, 'street'), (73, 76, 'postal'), (50, 65, 'city'), (67, 72, 'region')]}
# 3-4-8, Suehiro-cho, Kawagoe-shi, Saitama-ken {'entities': [(0, 5, 'street'), (7, 18, 'area'), (20, 31, 'city'), (33, 44, 'region')]}
# Port Sunlight Lab., Quarry Road East, Bebington, Wirral, Merseyside L63 3JW {'entities': [(0, 18, 'building'), (20, 36, 'street'), (68, 75, 'postal'), (38, 47, 'city'), (49, 55, 'region'), (57, 67, 'region')]}
# WARNING: could not find token "Fienemann road" in address "1118 Fienemann Road, Farmington, CT. 06032"
# WARNING: could not find token "farmington" in address "1118 Fienemann Road, Farmington, CT. 06032"
# 1118 Fienemann Road, Farmington, CT. 06032 {'entities': [(0, 4, 'nr'), (37, 42, 'postal'), (33, 35, 'city')]}
# WARNING: could not find token "Fienemann road" in address "1118 Fienemann Road, Farmington, CT. 06032"
# WARNING: could not find token "farmington" in address "1118 Fienemann Road, Farmington, CT. 06032"
# Le Bellevue Les Balmettes, F-74290 Talloires {'entities': [(0, 25, 'co'), (27, 34, 'postal'), (35, 44, 'city')]}
# 1302 Walnut Bend, Houston, TX 77042 {'entities': [(0, 4, 'nr'), (5, 16, 'area'), (30, 35, 'postal'), (18, 25, 'city'), (27, 29, 'region')]}
# Herkommerstrasse 11, D-88250 Weingarten {'entities': [(0, 16, 'street'), (17, 19, 'nr'), (21, 28, 'postal'), (29, 39, 'city')]}
# Lohweg 1, D-35633 Lahnau/Dorlar {'entities': [(0, 6, 'street'), (7, 8, 'nr'), (25, 31, 'area'), (10, 17, 'postal'), (18, 24, 'city')]}
# Richard-Wagner-Strasse 14, D-35392 Giessen {'entities': [(0, 22, 'street'), (23, 25, 'nr'), (27, 34, 'postal'), (35, 42, 'city')]}
# 22 Bungalow Hill Road, Farmington, Connecticut 06032 {'entities': [(3, 21, 'street'), (0, 2, 'nr'), (47, 52, 'postal'), (23, 33, 'city'), (35, 46, 'region')]}
# 28, rue du Père Brottier, F-95110 Sannois {'entities': [(4, 24, 'street'), (0, 2, 'nr'), (26, 33, 'postal'), (34, 41, 'city')]}
# Rormosen 204, DK-2990 Niv {'entities': [(0, 8, 'street'), (9, 12, 'nr'), (14, 21, 'postal'), (22, 25, 'city')]}
# Augustenstrasse 120, D-70197 Stuttgart {'entities': [(0, 15, 'street'), (16, 19, 'nr'), (21, 28, 'postal'), (29, 38, 'city')]}
# 33-1, Tamagawadei 2-chome, Setagaya-ku, Tokyo 158 {'entities': [(0, 4, 'street'), (6, 25, 'street'), (27, 38, 'area'), (46, 49, 'postal'), (40, 45, 'city')]}
# P.O. Box 210, Newmarket, Ontario L3Y 4X3 {'entities': [(0, 12, 'street'), (33, 40, 'postal'), (14, 23, 'city'), (25, 32, 'region')]}
# 255 Archer's Mead, Williamsburg, VA 23185 {'entities': [(4, 17, 'street'), (0, 3, 'nr'), (36, 41, 'postal'), (19, 31, 'city'), (33, 35, 'region')]}
# 3-4, Hattori-nishimachi 3-chome, Toyonaka-shi, Osaka 561 {'entities': [(5, 31, 'building'), (0, 3, 'nr'), (33, 45, 'area'), (53, 56, 'postal'), (47, 52, 'city')]}
# Lehmikentäntie 236 C7, SF-90450 Kempele {'entities': [(0, 14, 'street'), (15, 21, 'nr'), (26, 31, 'postal'), (32, 39, 'city')]}
# WARNING: could not find token "Rte Maréchal de Lattre de Tassigny" in address "Route du Maréchal De Lattre De Tassigny, Barembach, 67130 Schirmeck"
# WARNING: could not find token "Schirmek" in address "Route du Maréchal De Lattre De Tassigny, Barembach, 67130 Schirmeck"
# Route du Maréchal De Lattre De Tassigny, Barembach, 67130 Schirmeck {'entities': [(52, 57, 'postal'), (41, 50, 'city')]}
# WARNING: could not find token "Rte Maréchal de Lattre de Tassigny" in address "Route du Maréchal De Lattre De Tassigny, Barembach, 67130 Schirmeck"
# WARNING: could not find token "Schirmek" in address "Route du Maréchal De Lattre De Tassigny, Barembach, 67130 Schirmeck"
# 77, Kitayoshida-cho, Matsuyama-shi, Ehime 7911 {'entities': [(0, 2, 'street'), (4, 19, 'street'), (42, 46, 'postal'), (21, 34, 'city'), (36, 41, 'region')]}
# P.O. Drawer 428, Donalsonville, GA 31745 {'entities': [(0, 15, 'nr'), (35, 40, 'postal'), (17, 30, 'city'), (32, 34, 'region')]}
# P.O. Box 6300, Columbia, Maryland 21045-6300 {'entities': [(0, 13, 'building'), (34, 44, 'postal'), (15, 23, 'city'), (25, 33, 'region')]}
# 81 Hanbury Road Dorridge, Solihull West Midlands B93 8DN {'entities': [(3, 15, 'street'), (0, 2, 'nr'), (49, 56, 'postal'), (16, 24, 'city'), (26, 34, 'region'), (35, 48, 'region')]}
# WARNING: could not find token "Forest Manor Ct" in address "2434 Forest Manor Court, Neenah, WI 54956"
# WARNING: could not find token "Neehah" in address "2434 Forest Manor Court, Neenah, WI 54956"
# 2434 Forest Manor Court, Neenah, WI 54956 {'entities': [(0, 4, 'nr'), (36, 41, 'postal'), (33, 35, 'region')]}
# WARNING: could not find token "Forest Manor Ct" in address "2434 Forest Manor Court, Neenah, WI 54956"
# WARNING: could not find token "Neehah" in address "2434 Forest Manor Court, Neenah, WI 54956"
# 28 Charles Garnier, Loretteville, Quebec G2A 2X8 {'entities': [(3, 18, 'street'), (0, 2, 'nr'), (20, 32, 'area'), (41, 48, 'postal'), (34, 40, 'city')]}
# Chuo Kenkyusho, 1150, Hazawa-cho, Kanagawa-ku, Yokohama-shi, Kanagawa {'entities': [(0, 14, 'street'), (16, 20, 'nr'), (47, 59, 'area'), (34, 42, 'city')]}
# 7-35, Kitashinagawa 6-chome, Shinagawa-ku, Tokyo {'entities': [(6, 27, 'street'), (0, 4, 'nr'), (29, 41, 'city'), (43, 48, 'region')]}
# UK House, Worthing Road, Horsham, W Sussex RH12 1SL {'entities': [(0, 8, 'building'), (10, 23, 'street'), (43, 51, 'postal'), (25, 32, 'city'), (34, 42, 'region')]}
# 4, Boulevard du Maréchal Leclerc, Aguado, 91000 Evry {'entities': [(34, 40, 'co'), (3, 32, 'street'), (0, 1, 'nr'), (42, 47, 'postal'), (48, 52, 'city')]}
# WARNING: could not find token "2021-08-07 00:00:00" in address "Langensalzastrasse 7 - 8, D-30169 Hannover"
# Langensalzastrasse 7 - 8, D-30169 Hannover {'entities': [(0, 18, 'street'), (28, 33, 'postal'), (34, 42, 'city')]}
# WARNING: could not find token "2021-08-07 00:00:00" in address "Langensalzastrasse 7 - 8, D-30169 Hannover"
# 18 Farguharson Road, Croydon, Surrey CR0 2UH {'entities': [(3, 19, 'street'), (0, 2, 'nr'), (21, 28, 'area'), (37, 44, 'postal'), (30, 36, 'city')]}
# 3397-12, Tokiwamachi Machida-shi, Tokyo 194-02 {'entities': [(0, 7, 'nr'), (9, 32, 'area'), (40, 46, 'postal'), (34, 39, 'city')]}
# Veenlanden 40, 3871 RD Hoevelaken {'entities': [(0, 10, 'street'), (11, 13, 'nr'), (15, 22, 'postal'), (23, 33, 'city')]}
# 92 Chemin de Fey, F-54470 MAMEY {'entities': [(3, 16, 'street'), (0, 2, 'nr'), (18, 25, 'postal'), (26, 31, 'city')]}
# Solberg, N-3180 Nykirke {'entities': [(9, 15, 'postal'), (16, 23, 'city')]}
# WARNING: could not find token "Tjernysjevsskij Square Apartment 41" in address "Apartment 41 Tjernysjevsskij Square, 8, St.Petersburg, 196070"
# Apartment 41 Tjernysjevsskij Square, 8, St.Petersburg, 196070 {'entities': [(37, 38, 'nr'), (40, 53, 'area'), (55, 61, 'postal')]}
# WARNING: could not find token "Tjernysjevsskij Square Apartment 41" in address "Apartment 41 Tjernysjevsskij Square, 8, St.Petersburg, 196070"
# pl. Kurchatova, 1-19, Obninsk, Kaluzhskaya obl., 249020 {'entities': [(18, 20, 'building'), (0, 14, 'street'), (16, 17, 'nr'), (31, 47, 'area'), (49, 55, 'postal'), (22, 29, 'city')]}
# 16503 Terrey Pine Drive, Eden Prairie, MN 55347 {'entities': [(6, 23, 'street'), (0, 5, 'nr'), (42, 47, 'postal'), (25, 37, 'city'), (39, 41, 'region')]}
# WARNING: could not find token "5656-AA" in address "Prof. Holstlaan 6, NL-5656 AA Eindhoven"
# Prof. Holstlaan 6, NL-5656 AA Eindhoven {'entities': [(0, 15, 'street'), (16, 17, 'nr'), (30, 39, 'city')]}
# WARNING: could not find token "5656-AA" in address "Prof. Holstlaan 6, NL-5656 AA Eindhoven"
# WARNING: could not find token "2-1-7 Meayumiminami" in address "2-1-7, Mayumiminami, Ikoma-shi, Nara 630-01"
# 2-1-7, Mayumiminami, Ikoma-shi, Nara 630-01 {'entities': [(37, 43, 'postal'), (21, 30, 'city'), (32, 36, 'region')]}
# WARNING: could not find token "2-1-7 Meayumiminami" in address "2-1-7, Mayumiminami, Ikoma-shi, Nara 630-01"
# 11, Beech Street, Maplewood, New Jersey 07040 {'entities': [(4, 16, 'street'), (0, 2, 'nr'), (40, 45, 'postal'), (18, 27, 'city')]}
# 105 Enchanted Way, San Ramon, CA 94583 {'entities': [(4, 17, 'street'), (0, 3, 'nr'), (33, 38, 'postal'), (19, 28, 'city'), (30, 32, 'region')]}
# 1061 Northcrest Drive, Akron, Ohio 44319 {'entities': [(5, 21, 'street'), (0, 4, 'nr'), (23, 28, 'area'), (35, 40, 'postal'), (30, 34, 'city')]}
# 120 Vanita Drive, Coraopolis, PA 15108 {'entities': [(4, 16, 'street'), (0, 3, 'nr'), (18, 28, 'area'), (33, 38, 'postal'), (30, 32, 'region')]}
# 136 Varsity Circle, Arlington, Texas 76013 {'entities': [(4, 18, 'street'), (0, 3, 'nr'), (37, 42, 'postal'), (20, 29, 'city'), (31, 36, 'region')]}
# 1112 27th Street, Vienna, West Virginia 26105 {'entities': [(5, 16, 'street'), (0, 4, 'nr'), (18, 24, 'city'), (26, 39, 'region')]}
# 13, avenue du Président Salvador Allende, F-94117 Arceuil Cedex {'entities': [(4, 40, 'street'), (0, 2, 'nr'), (50, 63, 'area'), (42, 49, 'postal')]}
# 33-18-1202 Hanakuma, Chuo-ku, Kobe-shi, Hyogo-ken {'entities': [(30, 38, 'area'), (0, 10, 'postal'), (11, 19, 'city'), (40, 49, 'region')]}
# NEC Corporation, 7-1, Shiba 5-chome, Minato-ku, Tokyo 108-01 {'entities': [(0, 15, 'co'), (17, 20, 'street'), (22, 35, 'street'), (37, 46, 'area'), (54, 60, 'postal'), (48, 53, 'city')]}
# 123-1, Kitanishi-cho, Yamatokoriyama-shi, Nara 639-1025 {'entities': [(0, 5, 'street'), (7, 20, 'area'), (47, 55, 'postal'), (22, 40, 'city'), (42, 46, 'region')]}
# 2 John McQuinn Circle, Framingham, MA 01701 {'entities': [(2, 21, 'street'), (0, 1, 'nr'), (35, 43, 'postal'), (23, 33, 'city')]}
# Habad Street 20/136, 75302 Rishon le Zion {'entities': [(0, 12, 'street'), (13, 19, 'nr'), (21, 26, 'postal'), (27, 41, 'city')]}
# 2-1-1 Nishi-Shinjuku, ,Shinjuku-ku, Tokyo 163-0428 {'entities': [(0, 20, 'street'), (42, 50, 'postal'), (36, 41, 'city'), (23, 34, 'region')]}
# Am Mayerling 3, D-87541 Hindelang {'entities': [(0, 12, 'street'), (13, 14, 'nr'), (16, 23, 'postal'), (24, 33, 'city')]}
# WARNING: could not find token "Vitry-sur-Seine" in address "13, quai Jules Guesde, Boîte postale 14, F-94403 Cedex Vitry-Sur-Seine"
# 13, quai Jules Guesde, Boîte postale 14, F-94403 Cedex Vitry-Sur-Seine {'entities': [(4, 21, 'street'), (0, 2, 'nr'), (41, 48, 'postal')]}
# WARNING: could not find token "Vitry-sur-Seine" in address "13, quai Jules Guesde, Boîte postale 14, F-94403 Cedex Vitry-Sur-Seine"
# Wirtembergstrasse 2, 71336 Waiblingen {'entities': [(0, 17, 'street'), (18, 19, 'nr'), (21, 26, 'postal'), (27, 37, 'city')]}
# WARNING: could not find token "Centro,Nova Prata - Rs" in address "Avenida Cônego Peres, n 530, apto. 03, Centro, Nova Prata - Rs"
# ...
# 129090, Moskva, ul. B. Spasskaja, 25, stroenie 3, OOO 'JUridicheskaja firma Gorodisskij i Partnery' {'entities': [(50, 99, 'co'), (38, 48, 'building'), (16, 32, 'street'), (34, 36, 'nr'), (0, 6, 'postal'), (8, 14, 'city')]}
# PO Box 11, V.le Pasteur 10, I-20014 Nerviano (MI) IT {'entities': [(0, 26, 'street'), (24, 26, 'nr'), (28, 35, 'postal'), (36, 44, 'city'), (45, 49, 'region'), (50, 52, 'country')]}
# Rue de l'Institut 89, B-1330 Rixensart BE {'entities': [(0, 17, 'street'), (18, 20, 'nr'), (22, 28, 'postal'), (29, 38, 'city'), (39, 41, 'country')]}
# 28 XIANGYUAN ROAD, GONGSHU DISTRICT HANGZHOU, ZHEJIANG 310015 {'entities': [(3, 18, 'street'), (0, 2, 'nr'), (19, 45, 'area'), (55, 61, 'postal'), (46, 54, 'city')]}
# 3264 S. SPRINGFIELD AVENUE MILWAUKEE, WI 53207 {'entities': [(5, 26, 'street'), (0, 4, 'nr'), (41, 46, 'postal'), (27, 36, 'city'), (38, 40, 'region')]}
# HUAWEI ADMINISTRATION BUILDING SHENZHEN, GUANGDONG 518129 BANTIAN, LONGGANG DISTRICT {'entities': [(0, 39, 'building'), (67, 84, 'area'), (51, 57, 'postal'), (41, 50, 'city'), (58, 65, 'region')]}
# 53, YEONGTONG-RO 27BEON-GIL GYEONGGI-DO 18376 HWASEONG-SI {'entities': [(4, 27, 'street'), (0, 2, 'nr'), (40, 45, 'postal'), (46, 57, 'city'), (28, 39, 'region')]}
# Peking University Campus, Xili University Town, Nanshan District, Shenzhen, Guangdong 518055 {'entities': [(0, 24, 'co'), (26, 46, 'area'), (48, 64, 'area'), (86, 92, 'postal'), (66, 74, 'city'), (76, 85, 'region')]}
# No.555 of Zuchongzhi Road, Zhangjiang, Pudong New Area, Shanghai 201203 {'entities': [(27, 37, 'co'), (0, 6, 'building'), (10, 25, 'street'), (39, 54, 'area'), (65, 71, 'postal'), (56, 64, 'city')]}
# 11 Riverview, Teh Embankment Business Park, Heaton Mersey, Stockport, Cheshire SK4 3GN {'entities': [(14, 42, 'building'), (3, 12, 'street'), (0, 2, 'nr'), (44, 57, 'area'), (79, 86, 'postal'), (59, 68, 'city'), (70, 78, 'region')]}
# Meritor Heavy Vehicle Braking Systems (UK) Limited, Grange Road, Cwmbran, Monmouthshire NP44 3XU {'entities': [(0, 50, 'co'), (52, 63, 'street'), (74, 87, 'postal'), (65, 72, 'city'), (74, 87, 'region')]}
# WARNING: could not find token "c/o IP Group,Mars Incorporated" in address "c/o IP Group, Mars Incorporated, Dunde Road, Slough Berkshire SL1 4JX"
# c/o IP Group, Mars Incorporated, Dunde Road, Slough Berkshire SL1 4JX {'entities': [(33, 43, 'street'), (62, 69, 'postal'), (45, 51, 'city'), (52, 61, 'region')]}
# WARNING: could not find token "c/o IP Group,Mars Incorporated" in address "c/o IP Group, Mars Incorporated, Dunde Road, Slough Berkshire SL1 4JX"
# WARNING: could not find token "3-17-6 Shinyokohama, Kohoku-ku,Yokohama" in address "c/o Autoliv Japan Ltd., 4F Innotech Bldg., 3-17-6 Shinyokohama, Kohoku-ku, Yokohama, Kanagawa 222-8580"
# c/o Autoliv Japan Ltd., 4F Innotech Bldg., 3-17-6 Shinyokohama, Kohoku-ku, Yokohama, Kanagawa 222-8580 {'entities': [(0, 22, 'co'), (27, 41, 'street'), (24, 26, 'nr'), (94, 102, 'postal'), (85, 93, 'city')]}
# WARNING: could not find token "3-17-6 Shinyokohama, Kohoku-ku,Yokohama" in address "c/o Autoliv Japan Ltd., 4F Innotech Bldg., 3-17-6 Shinyokohama, Kohoku-ku, Yokohama, Kanagawa 222-8580"
# 51 Britain Drive, New Britain, PA 18901 {'entities': [(3, 16, 'street'), (0, 2, 'nr'), (34, 39, 'postal'), (18, 29, 'city'), (31, 33, 'region')]}
# Nanjing {'entities': [(0, 7, 'city')]}
# Braunschweig {'entities': [(0, 12, 'street')]}
# Zhejiang {'entities': [(0, 8, 'city')]}
# Suwon-si {'entities': [(0, 8, 'city')]}
# Yamato {'entities': [(0, 6, 'city')]}
# Northport, AL {'entities': [(0, 9, 'city'), (11, 13, 'region')]}
# HSINCHU CITY {'entities': [(0, 12, 'city')]}
# Seminole, FL {'entities': [(0, 8, 'area'), (10, 12, 'region')]}
# 129226, Moskva, pr-t Mira, 171, pom. 19, Davidenko N.F. {'entities': [(16, 25, 'street'), (27, 30, 'nr'), (0, 6, 'postal'), (8, 14, 'city'), (41, 50, 'region')]}
# 142210, Moskovskaya obl., g. Serpukhov, B. Udarnyj per., 1a, Mezhregionalnoe obshchestvennoe uchrezhdenie 'Institut inzhenernoj fiziki' {'entities': [(61, 135, 'co'), (40, 55, 'street'), (57, 59, 'nr'), (0, 6, 'postal'), (26, 38, 'city'), (8, 24, 'region')]}
# 117997, Moskva, ul. Miklukho-Maklaya, 16/10, korp. 71, IBKH RAN, ZAO Nauchno-proizvodstvennaya kompaniya 'Kombiotekh', zav. laboratorii biotekhnologii Krymskij M.A. {'entities': [(16, 36, 'street'), (38, 43, 'nr'), (0, 6, 'postal'), (8, 14, 'city')]}
# POLÍGONO INDUSTRIAL DE QUART DE POBLET, C/ LA PINAETA S/N, 46930 QUART DE POBLET VALENCIA ES {'entities': [(40, 57, 'co'), (23, 38, 'area'), (0, 38, 'area'), (59, 64, 'postal'), (81, 89, 'city'), (90, 92, 'country')]}
# Janis-Joplin-Str. 4, 71711 Steinheim an der Murr {'entities': [(0, 17, 'street'), (18, 19, 'nr'), (21, 26, 'postal'), (27, 48, 'city')]}
# 3365 Mainway, Burlington, Ontario L7M 1A6 {'entities': [(5, 12, 'street'), (0, 4, 'nr'), (14, 24, 'area'), (34, 41, 'postal'), (26, 33, 'city')]}
# c/o Asahi Glass Company, Limited, 5-1 Marunouchi 1-chome, Chiyoda-ku, Tokyo 100-8405 {'entities': [(4, 23, 'co'), (38, 56, 'street'), (34, 37, 'nr'), (58, 68, 'area'), (76, 84, 'postal'), (70, 75, 'city')]}
# WARNING: could not find token "3-chome 30-2" in address "c/o CANON KABUSHIKI KAISHA, 30-2, Shimomaruko 3-chome, Ohta-ku, Tokyo 146-8501"
# c/o CANON KABUSHIKI KAISHA, 30-2, Shimomaruko 3-chome, Ohta-ku, Tokyo 146-8501 {'entities': [(0, 26, 'co'), (34, 45, 'area'), (55, 62, 'area'), (70, 78, 'postal'), (64, 69, 'city')]}
# WARNING: could not find token "3-chome 30-2" in address "c/o CANON KABUSHIKI KAISHA, 30-2, Shimomaruko 3-chome, Ohta-ku, Tokyo 146-8501"
# c/o Ricoh Company, Ltd., 3-6, Nakamagome 1-chome, Ohta-ku, Tokyo 143-8555 {'entities': [(0, 23, 'co'), (25, 48, 'street'), (50, 57, 'area'), (65, 73, 'postal'), (59, 64, 'city')]}
# 4200 Scotland St., Apt. 520, Houston, TX 77007 {'entities': [(19, 27, 'building'), (5, 17, 'street'), (41, 46, 'nr'), (0, 4, 'postal'), (29, 36, 'city'), (38, 40, 'region')]}
# Premiá de Mar {'entities': [(0, 13, 'city')]}
# WARNING: could not find token "NARA" in address "Nara"
# Nara {'entities': []}
# WARNING: could not find token "NARA" in address "Nara"
# Hwaseong-si {'entities': [(0, 11, 'city')]}
# Airport {'entities': []}
# Singapore {'entities': [(0, 9, 'country')]}
# Paris {'entities': [(0, 5, 'city')]}
# Tel Aviv, IL {'entities': [(0, 8, 'city'), (10, 12, 'region')]}
# Austin, TX {'entities': [(0, 6, 'city'), (8, 10, 'region')]}
# Yongin-si {'entities': [(0, 9, 'city')]}
# Andover, MN {'entities': [(0, 7, 'city'), (9, 11, 'region')]}
# Hudson, MA {'entities': [(0, 6, 'city'), (8, 10, 'region')]}
# Baton Rouge, LA {'entities': [(0, 11, 'city'), (13, 15, 'region')]}
# Ann Arbor, MI {'entities': [(0, 9, 'city'), (11, 13, 'region')]}
# WARNING: could not find token "Paris" in address "PARIS 75017 FR"
# PARIS 75017 FR {'entities': [(6, 11, 'postal'), (12, 14, 'country')]}
# WARNING: could not find token "Paris" in address "PARIS 75017 FR"
# STR. TANGANULUI NR. 7, SECTOR 6 BUCUREŞTI, B RO {'entities': [(0, 15, 'street'), (20, 21, 'nr'), (23, 31, 'area'), (32, 41, 'city'), (45, 47, 'country')]}
# NA {'entities': [(0, 2, 'region')]}
# STR.ÎNVOIRII NR.23, SECTOR 5 BUCUREŞTI, B RO {'entities': [(0, 12, 'street'), (16, 18, 'nr'), (20, 28, 'area'), (29, 38, 'city'), (42, 44, 'country')]}
# ALEEA BAIA DE ARIEŞ NR. 3, BL. 3, SC. 7, ET. 3, AP. 87, SECTOR 6 BUCUREŞTI, B RO {'entities': [(78, 80, 'country')]}
# Ernst-Grein-Straße 33, 5026 Salzburg-Aigen {'entities': [(0, 18, 'street'), (19, 21, 'nr'), (23, 27, 'postal'), (28, 42, 'city')]}
# 420-403 Jugong Apt., ,189 Gaepo-dong, Gangnam-gu, Seoul {'entities': [(8, 18, 'building'), (26, 36, 'street'), (22, 25, 'nr'), (50, 55, 'city'), (38, 48, 'region')]}
# H. Lundbeck A/S Ottiliavej 9, 2500 Valby {'entities': [(0, 15, 'co'), (16, 26, 'street'), (27, 28, 'nr'), (35, 40, 'area'), (30, 34, 'postal')]}
# WARNING: could not find token "38 Flat no 103,SLV Nilya 15th Main" in address "38 Flat no 103, SLV Nilya 15th Main, 17th Cross, Nangundeswara Lt, JP Nagar5th Ph, Bangalore 560078"
# 38 Flat no 103, SLV Nilya 15th Main, 17th Cross, Nangundeswara Lt, JP Nagar5th Ph, Bangalore 560078 {'entities': [(49, 65, 'street'), (37, 47, 'nr'), (67, 81, 'area'), (93, 99, 'postal'), (83, 92, 'city')]}
# WARNING: could not find token "38 Flat no 103,SLV Nilya 15th Main" in address "38 Flat no 103, SLV Nilya 15th Main, 17th Cross, Nangundeswara Lt, JP Nagar5th Ph, Bangalore 560078"
# c/o Dompé farmaceutici S.p.A., Via Campo Di Pile, I-67100 L'Aquila (AQ) {'entities': [(0, 29, 'co'), (31, 48, 'area'), (50, 57, 'postal'), (58, 66, 'city'), (68, 70, 'region')]}
# 333 Lakeside Drive, Foster City, CA 94404 {'entities': [(4, 18, 'street'), (0, 3, 'nr'), (36, 41, 'postal'), (20, 31, 'city'), (33, 35, 'region')]}
# WARNING: could not find token "77550 Cedex" in address "c/o Snecma PI (AJI), Rond-Point René Ravaud Réau, 77550 Moissy-cramayel Cedex"
# c/o Snecma PI (AJI), Rond-Point René Ravaud Réau, 77550 Moissy-cramayel Cedex {'entities': [(0, 19, 'co'), (21, 48, 'street'), (56, 71, 'city')]}
# WARNING: could not find token "77550 Cedex" in address "c/o Snecma PI (AJI), Rond-Point René Ravaud Réau, 77550 Moissy-cramayel Cedex"
# HARUS S.R.L., Viale I Maggio, 156, 00046 Grottaferrata {'entities': [(0, 12, 'building'), (14, 28, 'street'), (30, 33, 'nr'), (35, 40, 'postal'), (41, 54, 'city')]}
# 135 Marlborough Street, Unit 5, Boston, Massachusetts 02216 {'entities': [(24, 30, 'building'), (4, 22, 'street'), (0, 3, 'nr'), (54, 59, 'postal'), (32, 38, 'city'), (40, 53, 'region')]}
# c/o Graco Minnesota Inc., 88 11th Avenue NE, Minneapolis, MN Minnesota 55413 {'entities': [(0, 24, 'co'), (29, 40, 'street'), (26, 28, 'nr'), (41, 43, 'area'), (71, 76, 'postal'), (45, 56, 'city'), (58, 70, 'region')]}
# c/o Taiki Corp., Ltd., 3-41 Nishiawaji 6-chome, Higashiyodogawa-ku, Osaka-shi Osaka 533-0031 {'entities': [(0, 15, 'co'), (28, 46, 'street'), (23, 27, 'nr'), (68, 77, 'area'), (84, 92, 'postal'), (68, 73, 'city')]}
# 6-7-8, Fujisaki, Narashino-shi Chiba 275-0017 {'entities': [(0, 5, 'nr'), (7, 15, 'area'), (37, 45, 'postal'), (17, 30, 'city'), (31, 36, 'region')]}
# Ashigarakami-gun {'entities': [(0, 16, 'area')]}
# Morgan Hill, CA {'entities': [(0, 11, 'city'), (13, 15, 'region')]}
# WARNING: could not find token "Colombus" in address "Columbus, OH"
# Columbus, OH {'entities': [(10, 12, 'region')]}
# WARNING: could not find token "Colombus" in address "Columbus, OH"
# Higashihiroshima {'entities': [(0, 16, 'city')]}
# WARNING: could not find token "California" in address "Mountain View, CA"
# Mountain View, CA {'entities': [(0, 13, 'city')]}
# WARNING: could not find token "California" in address "Mountain View, CA"
# CROLLES {'entities': [(0, 7, 'city')]}
# Daejeon {'entities': [(0, 7, 'city')]}
# Playa Vista, CA {'entities': [(0, 11, 'city'), (13, 15, 'region')]}
# Sunnyvale, CA {'entities': [(0, 9, 'city'), (11, 13, 'region')]}
# DE {'entities': [(0, 2, 'country')]}
# 9 rue Robert Marchand, 92260 Fontenay aux Roses {'entities': [(2, 21, 'street'), (0, 1, 'nr'), (29, 47, 'area'), (23, 28, 'postal')]}
# c/o Huawei Technologies Duesseldorf GmbH, Riesstr.25, 80992 Munich {'entities': [(0, 40, 'co'), (42, 50, 'street'), (50, 52, 'nr'), (54, 59, 'postal'), (60, 66, 'city')]}
# 9977 N 90th St., Scottsdale, AZ Arizona 85258 {'entities': [(0, 15, 'street'), (40, 45, 'postal'), (17, 27, 'city'), (29, 39, 'region')]}
# CEJN AB, P.O. Box 245, Rattvägen 1, 541 25 Skövde {'entities': [(0, 7, 'co'), (9, 21, 'building'), (23, 32, 'street'), (33, 34, 'nr'), (36, 42, 'postal'), (43, 49, 'city')]}
# 123 Nova Scotia Drive, RD 2, Waipu 0582 {'entities': [(4, 21, 'street'), (0, 3, 'nr'), (36, 39, 'postal'), (29, 34, 'city')]}
# c/o Technicolor USA Inc, 175 South San Antonio Rd, Los Altos, California 94022 {'entities': [(0, 23, 'co'), (29, 49, 'street'), (25, 28, 'nr'), (51, 60, 'area'), (73, 78, 'postal'), (62, 72, 'city')]}
# 28 Fayette Street, G-Unit, Cambrige MA 02139 {'entities': [(3, 17, 'street'), (0, 2, 'nr'), (19, 25, 'area'), (39, 44, 'postal'), (27, 35, 'city'), (36, 38, 'region')]}
# St John's {'entities': [(0, 9, 'city')]}
# Hsinchu County {'entities': [(0, 14, 'area')]}
# Andhra Pradesh {'entities': [(0, 14, 'city')]}
# Hyderabad {'entities': [(0, 9, 'city')]}
# Edison, NJ {'entities': [(0, 6, 'city'), (8, 10, 'region')]}
# Milpitas, CA {'entities': [(0, 8, 'area'), (10, 12, 'region')]}
# Wolfsburg {'entities': [(0, 9, 'city')]}
# WARNING: could not find token "Lünen" in address "Lüne"
# Lüne {'entities': []}
# WARNING: could not find token "Lünen" in address "Lüne"
# Palo Alto, CA {'entities': [(0, 9, 'city'), (11, 13, 'region')]}
# Cupertino, CA {'entities': [(0, 9, 'city'), (11, 13, 'region')]}
# Woodridge, IL {'entities': [(0, 9, 'city'), (11, 13, 'region')]}
# Ndabeni {'entities': [(0, 7, 'area')]}
# 5F, CHANGZHOU HIGH-TECH RESEARCH INSTITUTE OF NANJING UNIVERSITY CHANGZHOU, JIANGSU 213164 CHANGZHOU SCIENCE & EDUCATION TOWN, NO.801 MIDDLE CHANGWU ROAD {'entities': [(4, 74, 'co'), (0, 2, 'building'), (127, 153, 'street'), (84, 90, 'postal'), (4, 13, 'city'), (76, 83, 'region')]}
# C/O GWANGYANG IRON & STEEL WORKS GWANGYANG-SI, JEOLLANAM-DO 57807 20-26, POKPOSARANG-GIL {'entities': [(4, 32, 'co'), (47, 59, 'street'), (66, 71, 'nr'), (73, 88, 'area'), (60, 65, 'postal'), (33, 45, 'city')]}
# POST BOX 100084 BRANCH 82, TSINGHUA UNIVERISTY PATENT OFFICE, HAIDIAN DISTRICT BEIJING 100084 {'entities': [(27, 60, 'co'), (0, 22, 'street'), (23, 25, 'nr'), (62, 78, 'area'), (9, 15, 'postal'), (79, 86, 'city')]}
# C/O MITSUBISHI ELECTRIC CORPORATION, 7-3, MARUNOUCHI 2-CHOME, CHIYODA-KU, TOKYO 1008310 〒1008310 {'entities': [(0, 35, 'co'), (37, 60, 'street'), (62, 72, 'area'), (80, 96, 'postal'), (74, 79, 'city')]}
# C/O YAMADA BEE COMPANY, INC, 194 ICHIBA, KAGAMINO-CHO, TOMATA-GUN, OKAYAMA 7080393 〒7080393 {'entities': [(0, 22, 'co'), (29, 39, 'street'), (41, 53, 'street'), (55, 65, 'area'), (75, 82, 'postal'), (67, 74, 'region')]}
# 156013, g. Kostroma, ul. Lenina, 19a, kv. 9, OOO 'Brend Agentstvo Zvezda' {'entities': [(21, 31, 'street'), (33, 36, 'nr'), (0, 6, 'postal'), (8, 19, 'city'), (45, 73, 'region')]}
# 440028, g. Penza, ul. Germana Titova, 28, FGBOU VO 'Penzenskij gosudarstvennyj universitet arkhitektury i stroitelstva' {'entities': [(18, 36, 'street'), (4, 6, 'nr'), (0, 6, 'postal'), (8, 16, 'city')]}
# C/O DENSO CORPORATION, 1-1, SHOWA-CHO, KARIYA-CITY AICHI 4488661 〒4488661 {'entities': [(0, 21, 'co'), (23, 26, 'street'), (28, 37, 'street'), (57, 64, 'postal'), (39, 50, 'city'), (51, 56, 'region')]}
# NO. 16 MEIHUA ROAD, ZHONGLOU ECONOMIC DEVELOPMENT DISTRICT CHANGZHOU, JIANGSU 213023 {'entities': [(20, 58, 'area'), (78, 84, 'postal'), (59, 68, 'city'), (70, 77, 'region')]}
# WARNING: could not find token "Tokyo" in address "C/O ALPS ELECTRIC CO., LTD., 1-7, YUKIGAYA-OTSUKAMACHI, OTA-KU, TOKYO 1458501 〒1458501"
# C/O ALPS ELECTRIC CO., LTD., 1-7, YUKIGAYA-OTSUKAMACHI, OTA-KU, TOKYO 1458501 〒1458501 {'entities': [(4, 21, 'co'), (34, 54, 'street'), (29, 32, 'nr'), (56, 62, 'area'), (70, 77, 'postal')]}
# WARNING: could not find token "Tokyo" in address "C/O ALPS ELECTRIC CO., LTD., 1-7, YUKIGAYA-OTSUKAMACHI, OTA-KU, TOKYO 1458501 〒1458501"
# C/O ZTE CORPORATION ZTE PLAZA, KEJI ROAD SOUTH, HI-TECH INDUSTRIAL PARK NANSHAN SHENZHEN, GUANGDONG 518057 {'entities': [(0, 29, 'co'), (31, 46, 'street'), (48, 79, 'area'), (100, 106, 'postal'), (80, 88, 'city'), (90, 99, 'region')]}
# 129090, Moskva, ul. B. Spasskaja, 25, stroenie 3, OOO 'JUridicheskaja firma Gorodisskij i Partnery' {'entities': [(55, 98, 'co'), (16, 32, 'street'), (34, 36, 'nr'), (38, 48, 'area'), (0, 6, 'postal'), (8, 14, 'city')]}
# WARNING: could not find token "Movska" in address "Standartizatsii i Sertifikatsii Veterinarnôh Preparatov, Zvenigorodskoje u. 5 , Moskva, RUSSIAN FEDERATION"
# Standartizatsii i Sertifikatsii Veterinarnôh Preparatov, Zvenigorodskoje u. 5 , Moskva, RUSSIAN FEDERATION {'entities': [(0, 55, 'building'), (57, 72, 'street'), (76, 77, 'nr'), (88, 106, 'country')]}
# WARNING: could not find token "Movska" in address "Standartizatsii i Sertifikatsii Veterinarnôh Preparatov, Zvenigorodskoje u. 5 , Moskva, RUSSIAN FEDERATION"

# %%
def entities_overlap(entry):
    entities = entry[1]['entities']
    for first in entities:
        for second in entities:
            if (first == second): continue
            if (first[0] < second[0] and first[1] > second[0]) or (first[0] > second[0] and first[1] < second[0]) or (first[0]==second[0] or first[1]==second[1]):
                print('Entities {} and {} overlap in "{}"'.format(first, second, entry[0]))
                return True
    return False

train_data = list(filter(lambda entry: not entities_overlap(entry), train_data))
# Out:
# Entities (25, 33, 'area') and (25, 30, 'region') overlap in "2-15, Meiwadori 3-chome, Hyogo-ku, Kobe-shi, Hyogo 652-0882"
# Entities (35, 44, 'area') and (35, 40, 'city') overlap in "1-201, Fukuzaki 3-chome, Minato-ku Osaka-shi, Osaka 552-0013"
# Entities (26, 38, 'street') and (26, 38, 'area') overlap in "Yamaha Corporation, 10-1, Nakazawa-cho, Hamamatsu-shi, Shizuoka-ken"
# Entities (81, 84, 'nr') and (81, 84, 'postal') overlap in "c/o Toshiba Corporation, Intellectual Prop. Div., 1-1-1 Shibaura Minato-ku Tokyo 105"
# Entities (23, 31, 'postal') and (23, 25, 'region') overlap in "803 Kirts Blvd., Troy, MI 48084"
# Entities (24, 32, 'postal') and (24, 26, 'region') overlap in "2 Sconsett Bluff, Avon, CT 06001"
# Entities (36, 45, 'city') and (36, 41, 'region') overlap in "12-4, Sagisu 5-chome, Fukushima-ku, Osaka-shi, Osaka; 5530 002"
# Entities (50, 60, 'city') and (50, 56, 'region') overlap in "c/o Shinko El. Ind. Co., Ltd. 80, Oshimada-machi, Nagano-shi Nagano 381-2287"
# Entities (0, 19, 'street') and (0, 2, 'nr') overlap in "14 Duntrune Terrace West Ferry, Dundee DD5 1LF Scotland"
# Entities (44, 57, 'city') and (44, 53, 'city') overlap in "c/o JMS CO. LTD., 12-17 Kakomachi, Naka-ku, Hiroshima-shi, Hiroshima 730-8652"
# Entities (0, 7, 'area') and (0, 7, 'city') overlap in "Enskede"
# Entities (14, 34, 'area') and (14, 18, 'area') overlap in "4 NORMAN WAY, OVER INDUSTRIAL PARK, OVER, CAMBRIDGESHIRE"
# Entities (34, 43, 'area') and (34, 39, 'city') overlap in "5-1-4-611, Shiginonishi, Joto-ku, Osaka-shi, Osaka 536-0014"
# Entities (111, 116, 'city') and (111, 116, 'region') overlap in "c/o Intellectual Property Department, NTT DoCoMo, Inc., Sanno Park Tower, 11-1, Nagatacho 2 chome, Chiyoda-ku, Tokyo Tokyo 100-6150"
# Entities (18, 31, 'area') and (18, 25, 'city') overlap in "48 Karewa parade, Papamoa Beach, Papamoa, 3118"
# Entities (0, 21, 'street') and (8, 10, 'region') overlap in "Rodovia SP 101, Km 08, CEP:13186-901 Hortolândia - SP"
# Entities (43, 56, 'street') and (43, 55, 'area') overlap in "c/o SUMITOMO CHEMICAL COMPANY LIMITED, 5-1 Sobiraki-cho, Niihama-shi Ehime 792-8521"
# Entities (5, 13, 'street') and (5, 13, 'nr') overlap in "5710 Dumfries, Houston, TX Texas 77096"
# Entities (51, 58, 'city') and (51, 58, 'region') overlap in "c/o HITACHI APPLIANCES INC. 800 Tomida Ohira machi Tochigi shi Tochigi 3294493"
# Entities (58, 67, 'city') and (58, 63, 'region') overlap in "A/C SHARP KABUSHIKI KAISHA, 22-22, NAGAIKE-CHO, ABENO-KU, OSAKA-SHI, OSAKA 545-8522 JP"
# Entities (0, 26, 'street') and (24, 26, 'nr') overlap in "PO Box 11, V.le Pasteur 10, I-20014 Nerviano (MI) IT"
# Entities (74, 87, 'postal') and (74, 87, 'region') overlap in "Meritor Heavy Vehicle Braking Systems (UK) Limited, Grange Road, Cwmbran, Monmouthshire NP44 3XU"
# Entities (23, 38, 'area') and (0, 38, 'area') overlap in "POLÍGONO INDUSTRIAL DE QUART DE POBLET, C/ LA PINAETA S/N, 46930 QUART DE POBLET VALENCIA ES"
# Entities (68, 77, 'area') and (68, 73, 'city') overlap in "c/o Taiki Corp., Ltd., 3-41 Nishiawaji 6-chome, Higashiyodogawa-ku, Osaka-shi Osaka 533-0031"
# Entities (4, 74, 'co') and (4, 13, 'city') overlap in "5F, CHANGZHOU HIGH-TECH RESEARCH INSTITUTE OF NANJING UNIVERSITY CHANGZHOU, JIANGSU 213164 CHANGZHOU SCIENCE & EDUCATION TOWN, NO.801 MIDDLE CHANGWU ROAD"
# Entities (0, 22, 'street') and (9, 15, 'postal') overlap in "POST BOX 100084 BRANCH 82, TSINGHUA UNIVERISTY PATENT OFFICE, HAIDIAN DISTRICT BEIJING 100084"
# Entities (4, 6, 'nr') and (0, 6, 'postal') overlap in "440028, g. Penza, ul. Germana Titova, 28, FGBOU VO 'Penzenskij gosudarstvennyj universitet arkhitektury i stroitelstva'"

# %%
import spacy
import random

nlp = spacy.blank('en')
ner = nlp.create_pipe('ner')
nlp.add_pipe(ner)

for token in token_types:
    ner.add_label(token)

optimizer = nlp.begin_training()
for itn in range(20):
    random.shuffle(train_data)
    losses = {}

    batches = spacy.util.minibatch(train_data, size=spacy.util.compounding(4, 32, 1.001))
    for batch in batches:
        texts, annotations = zip(*batch)
        nlp.update(
            texts,  
            annotations,  
            drop=0.5,  
            sgd=optimizer,
            losses=losses)
# Out:
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:635: UserWarning: [W033] Training a new parser or NER using a model with an empty lexeme normalization table. This may degrade the performance to some degree. If this is intentional or this language doesn't have a normalization table, please ignore this warning.
#   proc.begin_training(
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "No. 66, Lane 642, Tung Wan Shou Rd. Gueishan Hsian..." with entities "[(18, 34, 'building'), (7, 16, 'street'), (0, 6, '...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "MEDIZINISCHE UNIVERSITÄT WIEN, KILM, Leitstelle 5H..." with entities "[(31, 35, 'co'), (0, 29, 'building'), (52, 69, 'st...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "11 Hamitzpe Street, P.O. Box 4467, Shoham 73142" with entities "[(20, 33, 'building'), (3, 18, 'street'), (0, 2, '...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "87 Sopwith Crescent Merley, Wimbourne, Dorset BH21..." with entities "[(3, 19, 'street'), (0, 2, 'nr'), (20, 26, 'area')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "H. Lundbeck A/S Ottiliavej 9, 2500 Valby" with entities "[(0, 15, 'co'), (16, 26, 'street'), (27, 28, 'nr')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Lange Koepoortstraat 49 B-2000 Antwerpen BE" with entities "[(0, 20, 'street'), (21, 23, 'nr'), (23, 30, 'post...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Canon K.K., 3-30-2 Shimomaruko, Ohta-ku, Tokyo" with entities "[(4, 13, 'co'), (16, 34, 'street'), (36, 43, 'area...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "6528 Morgan Ave. S., Richfield Minnesota 55423" with entities "[(5, 18, 'street'), (0, 4, 'nr'), (21, 30, 'city')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Prof. Holstlaan 6, NL-5656 AA Eindhoven" with entities "[(3, 19, 'street'), (20, 21, 'nr'), (26, 30, 'post...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "102-1505 POSCO Sup. Apt., Yucheon-dong" with entities "[(9, 15, 'co'), (15, 23, 'building'), (0, 8, 'nr')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "84 PITT STREET SYDNEY, NEW SOUTH WALES 2000" with entities "[(3, 14, 'street'), (0, 2, 'nr'), (39, 43, 'postal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Kymab Limited, Meditrina (B260), Babraham Rese..." with entities "[(0, 17, 'co'), (18, 35, 'building'), (36, 61, 'st...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Mitsubishi Gas Chemical Company Inc., Tokyo Te..." with entities "[(0, 40, 'co'), (64, 80, 'street'), (61, 64, 'nr')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Merikulmantie 553, FI-25570 Teijo" with entities "[(0, 14, 'street'), (14, 17, 'nr'), (28, 33, 'city...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "203 101 (Deokso DooSan Weve Apt.) 180 Deokso ro Wa..." with entities "[(8, 34, 'building'), (34, 38, 'street'), (0, 8, '...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Augustenstrasse 120, D-70197 Stuttgart" with entities "[(0, 15, 'street'), (16, 19, 'nr'), (21, 29, 'post...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Toppan Printing Co., Ltd., 5-1 Taito 1-chome, ..." with entities "[(0, 29, 'co'), (35, 40, 'area'), (50, 58, 'area')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "409 Seville Drive, Red Lion, PA 17356" with entities "[(3, 17, 'street'), (0, 3, 'nr'), (32, 37, 'postal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Habad Street 20/136, 75302 Rishon le Zion" with entities "[(0, 12, 'street'), (12, 19, 'nr'), (21, 26, 'post...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "GONELLASTRASSE 24;D-4005 MEERBUSCH 3" with entities "[(0, 14, 'street'), (15, 17, 'nr'), (18, 24, 'post...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "81N. Park Avenue, Fond du Lac WI 54935" with entities "[(2, 16, 'street'), (0, 2, 'nr'), (33, 38, 'postal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "24 Ir-Shemesh, 69086 Tel Aviv" with entities "[(2, 13, 'street'), (0, 2, 'nr'), (15, 20, 'postal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "3264 S. SPRINGFIELD AVENUE MILWAUKEE, WI 53207" with entities "[(4, 26, 'street'), (0, 4, 'nr'), (41, 46, 'postal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Center for iPS Cell Research and Application, ..." with entities "[(0, 47, 'co'), (99, 101, 'country')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Asahi Glass Company, Limited, 5-1, Marunouchi ..." with entities "[(0, 23, 'co'), (25, 32, 'co'), (34, 57, 'street')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Postiljooninkatu 3, FIN-05800 Hyvinkää" with entities "[(0, 16, 'street'), (17, 18, 'nr'), (24, 29, 'post...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "9977 N 90th St., Scottsdale, AZ Arizona 85258" with entities "[(0, 15, 'street'), (40, 45, 'postal'), (17, 27, '...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "428 HUCKLEBERRY;LAKE JACKSON, TX 77566" with entities "[(4, 15, 'street'), (0, 3, 'nr'), (33, 38, 'postal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "28, rue du Père Brottier, F-95110 Sannois" with entities "[(4, 24, 'street'), (0, 2, 'nr'), (26, 34, 'postal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "No.555 of Zuchongzhi Road, Zhangjiang, Pudong New ..." with entities "[(27, 37, 'co'), (0, 6, 'building'), (9, 25, 'stre...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Intell. Prop. Center, 20, Igadera, Shimo-Kaiinji, ..." with entities "[(0, 20, 'building'), (22, 48, 'street'), (73, 76,...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Orcam Technologies Ltd., 13 Hartom St., 91450 ..." with entities "[(0, 26, 'co'), (32, 42, 'street'), (29, 31, 'nr')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Honda R&D Co., Ltd., 4-1, Chuo 1-chome, Wako-s..." with entities "[(4, 23, 'co'), (25, 42, 'street'), (62, 70, 'post...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Intellectual Property Department NTT, DoCoMo. ..." with entities "[(0, 40, 'co'), (42, 53, 'building'), (74, 88, 'st...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "117997, Moskva, ul. Miklukho-Maklaya, 16/10, korp...." with entities "[(15, 36, 'street'), (38, 43, 'nr'), (0, 6, 'posta...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "163 INGRAM ROAD;ACACIA RIDGE, QLD 4110" with entities "[(4, 15, 'street'), (0, 3, 'nr'), (16, 28, 'area')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "C/O Nice, Inc., One Bowerman Drive, Beaverton, OR ..." with entities "[(0, 13, 'co'), (16, 34, 'street'), (50, 60, 'post...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "22 Bungalow Hill Road, Farmington, Connecticut 060..." with entities "[(3, 21, 'street'), (0, 2, 'nr'), (47, 52, 'postal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Ricoh Company, Ltd., 3-6, Nakamagome 1-chome, ..." with entities "[(0, 23, 'co'), (25, 48, 'street'), (50, 57, 'area...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "ROOM 403, EAST BLOCK 2, SEG PARK, ZHENXING ROAD, F..." with entities "[(24, 32, 'co'), (0, 22, 'building'), (34, 47, 'st...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Murata Manufacturing Co, Ltd, 26-10, Tenjin 2-chom..." with entities "[(0, 28, 'co'), (36, 51, 'street'), (53, 67, 'area...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "109-604, Geonyoung APT., 1094, Jisan-dong, Pyeongt..." with entities "[(9, 23, 'building'), (0, 7, 'street'), (25, 29, '...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Via Garibaldi, 29, Zola Predosa I-40069 Bologna" with entities "[(0, 12, 'street'), (15, 17, 'nr'), (19, 31, 'area...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Kilianstrasse 18, 33142 Büren" with entities "[(0, 14, 'street'), (14, 16, 'nr'), (18, 23, 'post...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "50-6, Ipponmatsu, Menjyo, Yamato-cho, Ichinomiya-s..." with entities "[(6, 16, 'street'), (0, 4, 'nr'), (18, 24, 'area')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "21118 Commerce Pointe Drive Walnut, CA 91789 US" with entities "[(5, 27, 'street'), (0, 5, 'nr'), (39, 44, 'postal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Autoliv Japan Ltd., 4F Innotech Bldg., 3-17-6 ..." with entities "[(0, 22, 'co'), (26, 41, 'street'), (24, 26, 'nr')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Samsung Electronics Co., Ltd. 416, Maetan-dong, Ye..." with entities "[(0, 30, 'co'), (30, 33, 'street'), (35, 46, 'area...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "123 Nova Scotia Drive, RD 2, Waipu 0582" with entities "[(4, 21, 'street'), (0, 3, 'nr'), (36, 39, 'postal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Vlitingerbank 6, NL-6213KB Maastricht" with entities "[(0, 13, 'street'), (14, 15, 'nr'), (20, 26, 'post...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "'Chez d'Jou' Brightwell-cum-Sotwell, Wallingford O..." with entities "[(0, 12, 'co'), (12, 35, 'street'), (37, 60, 'city...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "234 Route de Sesigny, 74350 Cruseilles" with entities "[(4, 20, 'street'), (0, 3, 'nr'), (22, 28, 'postal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "35 Carter Street, South Portland, Maine 04106" with entities "[(3, 16, 'street'), (0, 2, 'nr'), (18, 32, 'area')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Verseny u.21c, H-8360 Keszthely" with entities "[(0, 10, 'street'), (10, 13, 'nr'), (15, 21, 'post...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "183-2, 5/5 Bokcheon-dong Dongrae-gu, Busan 607-020" with entities "[(0, 5, 'street'), (6, 10, 'nr'), (11, 24, 'area')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "400 rue St-Jacques Bureau 200, Montréal, Québec H2..." with entities "[(18, 29, 'building'), (4, 18, 'street'), (0, 3, '...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Hitachi Research Laboratory, HITACHI LTD., 1-1..." with entities "[(33, 45, 'co'), (5, 31, 'building'), (69, 88, 'st...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Kawasaki Steel Corporation 1, Kawasakicho Chuo-ku,..." with entities "[(0, 26, 'co'), (27, 28, 'nr'), (30, 49, 'area'), ...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "101 Gould Street, St. Simons Island Georgia 31522" with entities "[(3, 16, 'street'), (0, 3, 'nr'), (18, 35, 'area')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "2207 Pine Ridge Court, Niskayuna New York 12309" with entities "[(5, 21, 'street'), (0, 4, 'nr'), (23, 33, 'area')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "375 Patton Avenue San Jose, CA 95128 US" with entities "[(4, 14, 'street'), (0, 3, 'nr'), (31, 36, 'postal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Langensalzastrasse 7 - 8, D-30169 Hannover" with entities "[(0, 18, 'street'), (28, 33, 'postal'), (34, 42, '...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Prof. Holstlaan 6, NL-5656 AA Eindhoven" with entities "[(0, 16, 'street'), (16, 17, 'nr'), (22, 29, 'post...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "126 East Lincoln Avenue, Rahway New Jersey 07065-0..." with entities "[(4, 23, 'street'), (0, 3, 'nr'), (32, 43, 'area')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Hitachi. Ltd., Intellectual Property Office, 1..." with entities "[(0, 16, 'co'), (19, 47, 'building'), (87, 105, 's...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "STR.ÎNVOIRII NR.23, SECTOR 5 BUCUREŞTI, B RO" with entities "[(0, 13, 'street'), (16, 18, 'nr'), (20, 28, 'area...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Ravensburger Strasse 28, 88279 Amtzell" with entities "[(21, 23, 'nr'), (25, 30, 'postal'), (31, 37, 'cit...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "79-19 269th Street, New Hyde Park New York" with entities "[(6, 18, 'street'), (0, 6, 'nr'), (20, 33, 'area')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Amakem NV, Life Sciences Incubator, Agoralaan A bi..." with entities "[(0, 9, 'co'), (11, 34, 'building'), (36, 47, 'str...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "10100 Bay Area Boulevard~Pasadena~Texas~77507 US" with entities "[(6, 24, 'street'), (0, 5, 'nr'), (40, 45, 'postal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Legal & IP Team, Samsung SDI Co., Ltd., 428-5, Gon..." with entities "[(40, 45, 'street'), (47, 56, 'area'), (58, 69, 'a...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "9302 Hallsboro Circle, Apartment 302, Parkville Ma..." with entities "[(22, 36, 'building'), (5, 21, 'street'), (0, 4, '...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Huawei Technologies Duesseldorf GmbH, Riesstr...." with entities "[(0, 40, 'co'), (42, 50, 'street'), (50, 52, 'nr')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Nippon Light Metal Co., Ltd. 2-20, Higashi-, S..." with entities "[(0, 31, 'co'), (32, 37, 'street'), (39, 47, 'area...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "New Marunouchi Bldg., 5-1, Marunouchi 1-chome, Chi..." with entities "[(0, 20, 'street'), (21, 25, 'nr'), (65, 73, 'post...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Lehmikentäntie 236 C7, SF-90450 Kempele" with entities "[(0, 14, 'street'), (15, 21, 'nr'), (26, 31, 'post...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Route du Monteliza, CH-1806 St-Légier" with entities "[(0, 18, 'street'), (23, 27, 'postal')]". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "7041 East Edgemont Street, Tucson, AZ 85710" with entities "[(5, 25, 'street'), (0, 4, 'nr'), (38, 43, 'postal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "4-105 City House, 3440-1, Nishikata, Koshigaya-shi..." with entities "[(0, 16, 'street'), (26, 35, 'area'), (17, 24, 'po...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "Avenue Slegers, 207, B-1200 Bruxelles" with entities "[(16, 19, 'nr'), (23, 27, 'postal'), (28, 37, 'cit...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Hitachi Appliances, Inc. 390 Muramatsu, Shimiz..." with entities "[(0, 27, 'co'), (70, 82, 'area'), (83, 91, 'postal...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o FUJITSU LIMITED, 1-1, Kamikodanaka 4-chome, Na..." with entities "[(0, 19, 'co'), (21, 46, 'street'), (48, 59, 'area...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "TOTO LTD. CHIGASAKI PLANT;8-1, HONSON 2-CHOME;CHIG..." with entities "[(0, 9, 'co'), (10, 25, 'building'), (26, 45, 'str...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "c/o Qualcomm Incorporated T-160D 5775 Morehouse Dr..." with entities "[(0, 33, 'co'), (38, 53, 'street'), (33, 37, 'nr')...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)
# C:\Users\Home\anaconda3\envs\nlp-deps\lib\site-packages\spacy\language.py:482: UserWarning: [W030] Some entities could not be aligned in the text "601 Ansel Road, Apt. 212, Burlingame CA 94010" with entities "[(15, 24, 'building'), (4, 14, 'street'), (0, 3, '...". Use `spacy.gold.biluo_tags_from_offsets(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities (with BILUO tag '-') will be ignored during training.
#   gold = GoldParse(doc, **gold)

# %%
nlp.to_disk('trained_model_0')
nlp2 = spacy.load('./trained_model_0')

for text, _ in train_data:
    doc = nlp2(text)
    print('{} Entities'.format(text), [(ent.text, ent.label_) for ent in doc.ents])
# Out:
# [('ner', <spacy.pipeline.pipes.EntityRecognizer object at 0x0000014F4F46C9A0>)]
# [('ner', <spacy.pipeline.pipes.EntityRecognizer object at 0x0000014F58651AC0>)]
# HSINCHU CITY Entities [('HSINCHU CITY', 'city')]
# c/o Asahi Glass Company, Limited, 5-1, Marunouchi 1-chome, Chiyoda-ku, Tokyo 100-8405 Entities [('c/o Asahi Glass Company', 'co'), ('Limited', 'city'), ('5-1', 'street'), ('Marunouchi 1-chome', 'street'), ('Chiyoda-ku', 'area'), ('Tokyo', 'city'), ('100-8405', 'postal')]
# 920 EAST CREEK DRIVE, DRIPPING SPRINS, TEXAS 78620, E.U.A. US Entities [('920', 'nr'), ('EAST CREEK DRIVE', 'street'), ('DRIPPING SPRINS', 'city'), ('TEXAS', 'region'), ('78620', 'postal')]
# Standartizatsii i Sertifikatsii Veterinarnôh Preparatov, Zvenigorodskoje u. 5 , Moskva, RUSSIAN FEDERATION Entities [('Standartizatsii i Sertifikatsii Veterinarnôh Preparatov', 'co'), ('Zvenigorodskoje u.', 'street'), ('5', 'nr'), ('Moskva', 'city'), ('RUSSIAN FEDERATION', 'region')]
# 2-2, MINAMIDAMACHI-2-CHOME, TOYAMA-SHI Entities [('2-2', 'street'), ('MINAMIDAMACHI-2-CHOME', 'city'), ('TOYAMA-SHI', 'city')]
# Wirral Entities [('Wirral', 'region')]
# Austin Entities [('Austin', 'city')]
# Cagayan de Oro Entities [('Cagayan de Oro', 'city')]
# Gebze-Kocaeli Entities [('Gebze', 'city'), ('Kocaeli', 'region')]
# 1-28-5-302, Ozu-cho, Iwakuni-shi Yamaguchi-ken Entities [('Ozu-cho', 'area'), ('Iwakuni-shi', 'city'), ('Yamaguchi-ken', 'region')]
# 51 Britain Drive, New Britain, PA 18901 Entities [('51', 'nr'), ('Britain Drive', 'street'), ('New Britain', 'city'), ('PA', 'region'), ('18901', 'postal')]
# Seattle Entities [('Seattle', 'city')]
# 11 Elias Court, The Gardens, Manakau Entities [('11', 'nr'), ('Elias Court', 'street'), ('The Gardens', 'area'), ('Manakau', 'city')]
# 219-24, Gasan-Dong, Geumcheon-Gu Seoul Entities [('219-24', 'street'), ('Gasan-Dong', 'area'), ('Geumcheon-Gu', 'area'), ('Seoul', 'city')]
# Epfenhausen Entities [('Epfenhausen', 'city')]
# Ritto-shi Entities [('Ritto-shi', 'city')]
# 7041 East Edgemont Street, Tucson, AZ 85710 Entities [('7041', 'nr'), ('East Edgemont Street', 'street'), ('Tucson', 'city'), ('AZ', 'region'), ('85710', 'postal')]
# 2-1816-201, Ohashi-cho, Ashikaga-shi, Tochigi 326-0051 Entities [('2-1816-201', 'street'), ('Ohashi-cho', 'area'), ('Ashikaga-shi', 'city'), ('Tochigi', 'region'), ('326-0051', 'postal')]
# Im Schaffner 3, 69123 Heidelberg Entities [('Im Schaffner', 'street'), ('3', 'nr'), ('69123', 'postal'), ('Heidelberg', 'city')]
# 306-1904 Samsan Jugong Mirae Town Apt. 390-6 Samsan-dong Bupyeong-gu, Incheon 403-090 Entities [('306-1904', 'nr'), ('Samsan Jugong Mirae Town', 'street'), ('Samsan-dong Bupyeong-gu', 'area'), ('Incheon', 'city'), ('403-090', 'postal')]
# Itami Seisakusho 1-1, Tsukaguchihonmachi 8-chome, Amagasaki-shi Hyogo 661 Entities [('Itami Seisakusho 1-1', 'co'), ('Tsukaguchihonmachi', 'city'), ('Amagasaki-shi', 'city'), ('Hyogo', 'region'), ('661', 'postal')]
# TAOYUAN CITY Entities [('TAOYUAN CITY', 'city')]
# 255 Archer's Mead, Williamsburg, VA 23185 Entities [('255', 'nr'), ("Archer's Mead", 'street'), ('Williamsburg', 'city'), ('VA', 'region'), ('23185', 'postal')]
# P.O. Drawer 428, Donalsonville, GA 31745 Entities [('P.O. Drawer 428', 'street'), ('Donalsonville', 'city'), ('GA', 'region'), ('31745', 'postal')]
# Daejeon Entities [('Daejeon', 'city')]
# Huilongguan Entities [('Huilongguan', 'city')]
# 11 Riverview, Teh Embankment Business Park, Heaton Mersey, Stockport, Cheshire SK4 3GN Entities [('11', 'nr'), ('Riverview', 'street'), ('Teh Embankment Business Park', 'area'), ('Heaton Mersey', 'area'), ('Stockport', 'city'), ('Cheshire', 'region'), ('SK4 3GN', 'postal')]
# C/O GWANGYANG IRON & STEEL WORKS GWANGYANG-SI, JEOLLANAM-DO 57807 20-26, POKPOSARANG-GIL Entities [('JEOLLANAM-DO', 'area'), ('57807', 'postal'), ('POKPOSARANG-GIL', 'area')]
# Kiryu Entities [('Kiryu', 'city')]
# Maple Grove Entities [('Maple Grove', 'city')]
# Inzai Entities [('Inzai', 'city')]
# c/o Orcam Technologies Ltd., 13 Hartom St., 91450 Jerusalem Entities [('c/o Orcam Technologies Ltd.', 'co'), ('13', 'nr'), ('Hartom St.', 'street'), ('91450', 'postal'), ('Jerusalem', 'city')]
# 3264 S. SPRINGFIELD AVENUE MILWAUKEE, WI 53207 Entities [('3264', 'nr'), ('S. SPRINGFIELD AVENUE MILWAUKEE', 'street'), ('WI', 'region'), ('53207', 'postal')]
# c/o NGK INSULATORS LTD., 2-56, Suda-cho, Mizuho-ku, Nagoya-shi Aichi 467-8530 Entities [('c/o NGK INSULATORS LTD.', 'co'), ('2-56', 'street'), ('Suda-cho', 'area'), ('Mizuho-ku', 'area'), ('Nagoya-shi', 'city'), ('Aichi', 'region'), ('467-8530', 'postal')]
# Bellwood Entities [('Bellwood', 'city')]
# c/o Mitsui Chemicals, Inc. 1144, Togo, Mobara-shi, Chiba 297-0017 Entities [('c/o Mitsui Chemicals, Inc.', 'co'), ('Togo', 'city'), ('Mobara-shi', 'city'), ('Chiba', 'region'), ('297-0017', 'postal')]
# Nachtigallenweg 1a, D-6233 Kalkheim (Taunus) Entities [('Nachtigallenweg', 'street'), ('1a', 'nr'), ('D-6233', 'postal'), ('Kalkheim', 'city'), ('(Taunus', 'city')]
# Vlitingerbank 6, NL-6213KB Maastricht Entities [('Vlitingerbank', 'street'), ('6', 'nr'), ('NL-6213', 'postal'), ('KB', 'city'), ('Maastricht', 'city')]
# 16 Skehan Street, Somerville, MA 02143 Entities [('16', 'nr'), ('Skehan Street', 'street'), ('Somerville', 'city'), ('MA', 'region'), ('02143', 'postal')]
# 4005 Meerbusch 1 Entities [('4005', 'postal'), ('Meerbusch', 'city'), ('1', 'nr')]
# Nanjing Entities [('Nanjing', 'city')]
# 1682 Rue de la Valsière, Cap Sigma-Zac Euromedecine II, 34790 Grabels Entities [('1682', 'nr'), ('Rue de la Valsière', 'street'), ('Cap Sigma-Zac Euromedecine II', 'area'), ('34790', 'postal'), ('Grabels', 'city')]
# Murata Manufacturing Co, Ltd, 26-10, Tenjin 2-chome, Nagaokakyo-shi, Kyoto-fu 617-8555 Entities [('Murata Manufacturing Co, Ltd', 'co'), ('Tenjin', 'area'), ('2-chome', 'area'), ('Nagaokakyo-shi', 'city'), ('Kyoto-fu', 'city'), ('617-8555', 'postal')]
# Kawasaki Steel Corporation 1, Kawasakicho Chuo-ku, Chiba-shi Chiba, 260-0835 Entities [('Kawasaki Steel Corporation', 'co'), ('1', 'nr'), ('Kawasakicho Chuo-ku', 'area'), ('Chiba-shi Chiba', 'city'), ('260-0835', 'postal')]
# Tubizerstrasse 62, D-7015 Korntal Entities [('62', 'nr'), ('D-7015', 'postal'), ('Korntal', 'city')]
# Madrid Entities [('Madrid', 'city')]
# Industrielaan 17, 3925 BD Scherpenzeel Entities [('Industrielaan', 'street'), ('17', 'nr'), ('3925', 'postal'), ('BD Scherpenzeel', 'city')]
# Hayward Entities [('Hayward', 'city')]
# SCHONBLICK 17, 73635 RUDERSBERG, GERMANY Entities [('SCHONBLICK', 'street'), ('17', 'nr'), ('73635', 'postal'), ('RUDERSBERG', 'city'), ('GERMANY', 'region')]
# 13, quai Jules Guesde, Boîte postale 14, F-94403 Cedex Vitry-Sur-Seine Entities [('13', 'nr'), ('quai Jules Guesde', 'street'), ('14', 'nr'), ('F-94403', 'postal')]
# 28 Fayette Street, G-Unit, Cambrige MA 02139 Entities [('28', 'nr'), ('Fayette Street', 'street'), ('G-Unit', 'area'), ('Cambrige', 'city'), ('MA', 'region'), ('02139', 'postal')]
# West Olive Entities [('West Olive', 'city')]
# Knoxville Entities [('Knoxville', 'city')]
# 9, Coronation Drive, 269564, Singapore Entities [('9', 'nr'), ('Coronation Drive', 'street'), ('269564', 'postal'), ('Singapore', 'city')]
# 1302 Walnut Bend, Houston, TX 77042 Entities [('1302', 'nr'), ('Walnut Bend', 'area'), ('Houston', 'city'), ('TX', 'region'), ('77042', 'postal')]
# Brea, CA Entities [('Brea', 'area'), ('CA', 'region')]
# 365 San Antonio Rd. Mountain View CA 94040 Entities [('365', 'nr'), ('San Antonio Rd.', 'street'), ('Mountain View', 'city'), ('CA', 'region'), ('94040', 'postal')]
# P.O Box 189, 147 Ashley Hill Road, Old Chatham, New York, NY 12136 Entities [('P.O Box 189', 'street'), ('147', 'nr'), ('Ashley Hill Road', 'street'), ('Old Chatham', 'area'), ('New York', 'city'), ('NY', 'region'), ('12136', 'postal')]
# RUA HENRIQUE MIERS, 427, APTO 402, COSTA E SILVA 89218600 JOINVILLE BR Entities [('RUA HENRIQUE MIERS', 'street'), ('427', 'nr'), ('APTO 402', 'area'), ('COSTA E SILVA', 'area'), ('89218600', 'postal'), ('JOINVILLE', 'city'), ('BR', 'country')]
# Ndabeni Entities [('Ndabeni', 'area')]
# Alameda Entities [('Alameda', 'city')]
# Portland Entities [('Portland', 'city')]
# Vingalandsgatan 8, 417 63 Göteborg Entities [('Vingalandsgatan', 'street'), ('8', 'nr'), ('417 63', 'postal'), ('Göteborg', 'city')]
# 120 Vanita Drive, Coraopolis, PA 15108 Entities [('120', 'nr'), ('Vanita Drive', 'street'), ('Coraopolis', 'city'), ('PA', 'region'), ('15108', 'postal')]
# TOTO LTD. CHIGASAKI PLANT;8-1, HONSON 2-CHOME;CHIGASAKI-SHI KANAGAWA 253 Entities [('TOTO LTD. CHIGASAKI', 'co'), ('HONSON', 'area'), ('KANAGAWA', 'city'), ('253', 'postal')]
# 45 Harrison Avenue, apt. 1B, Branford, CT 06405 Entities [('45', 'nr'), ('Harrison Avenue', 'street'), ('Branford', 'city'), ('CT', 'region'), ('06405', 'postal')]
# 1917 Trixie Lane, Houston, Texas 77042 Entities [('1917', 'nr'), ('Trixie Lane', 'street'), ('Houston', 'city'), ('Texas', 'region'), ('77042', 'postal')]
# Windsor Entities [('Windsor', 'city')]
# Kanagawa Entities [('Kanagawa', 'region')]
# Tokyo Entities [('Tokyo', 'city')]
# Encinitas, CA Entities [('Encinitas', 'city'), ('CA', 'region')]
# Am Breitenberg 14, 37534 Badenhaussen Entities [('Am Breitenberg', 'street'), ('14', 'nr'), ('37534', 'postal'), ('Badenhaussen', 'city')]
# Edison, NJ Entities [('Edison', 'city'), ('NJ', 'region')]
# Milpitas, CA Entities [('Milpitas', 'area'), ('CA', 'region')]
# 428 HUCKLEBERRY;LAKE JACKSON, TX 77566 Entities [('428', 'nr'), ('HUCKLEBERRY;LAKE JACKSON', 'street'), ('TX', 'region'), ('77566', 'postal')]
# Isesaki-shi Entities []
# 2167 Parkplace Drive, Walled Lake Michigan 48088 Entities [('2167', 'nr'), ('Parkplace Drive', 'street'), ('Walled Lake', 'city'), ('48088', 'postal')]
# Mountain View Entities [('Mountain View', 'city')]
# Pueblo West Entities [('Pueblo West', 'city')]
# 555 PAPER MILL ROAD, P.O.BOX 9329, NEWARK, DELAWARE Entities [('555', 'nr'), ('PAPER MILL ROAD', 'street'), ('NEWARK', 'city'), ('DELAWARE', 'region')]
# Tenri Entities [('Tenri', 'city')]
# 101 Gould Street, St. Simons Island Georgia 31522 Entities [('101', 'nr'), ('Gould Street', 'street'), ('St. Simons Island Georgia', 'area'), ('31522', 'postal')]
# Ottawa Entities [('Ottawa', 'city')]
# c/o FUJITSU LIMITED, 1-1, Kamikodanaka 4-chome, Nakahara-ku, Kawasaki-shi Kanagawa 211-8588 Entities [('c/o FUJITSU LIMITED', 'co'), ('1-1', 'street'), ('Kamikodanaka 4-chome', 'street'), ('Nakahara-ku', 'area'), ('Kawasaki-shi', 'city'), ('Kanagawa', 'region'), ('211-8588', 'postal')]
# Baton Rouge, LA Entities [('Baton Rouge', 'city'), ('LA', 'region')]
# Renergon International AG, Holzäckerlistrasse 6, 8280 Kreuzlingen Entities [('Renergon International AG', 'co'), ('Holzäckerlistrasse', 'street'), ('6', 'nr'), ('8280', 'postal'), ('Kreuzlingen', 'city')]
# Great Falls, VA Entities [('Great Falls', 'city'), ('VA', 'region')]
# Patentabteilung, Eisenhüttenstrasse 22, 57074 Siegen Entities [('Eisenhüttenstrasse', 'street'), ('22', 'nr'), ('57074', 'postal'), ('Siegen', 'city')]
# Stafford Entities [('Stafford', 'city')]
# Clevedon Entities [('Clevedon', 'city')]
# Yongin Entities [('Yongin', 'city')]
# C/O ALPS ELECTRIC CO., LTD., 1-7, YUKIGAYA-OTSUKAMACHI, OTA-KU, TOKYO 1458501 〒1458501 Entities [('YUKIGAYA-OTSUKAMACHI', 'street'), ('OTA-KU', 'area'), ('TOKYO', 'city'), ('1458501 〒1458501', 'postal')]
# Matsue-shi Entities [('Matsue-shi', 'city')]
# c/o Huawei Technologies Duesseldorf GmbH, Riesstr.25, 80992 Munich Entities [('c/o Huawei Technologies Duesseldorf GmbH,', 'co'), ('80992', 'postal'), ('Munich', 'city')]
# Ottweilerstr. 12, 51375 Leverkusen Entities [('Ottweilerstr.', 'street'), ('12', 'nr'), ('51375', 'postal'), ('Leverkusen', 'city')]
# Baltimore Entities [('Baltimore', 'city')]
# 11 Bis Avenue Guy de Collongue, F-69130 Ecully Entities [('11', 'nr'), ('Avenue Guy de Collongue', 'street'), ('F-69130', 'postal'), ('Ecully', 'city')]
# Victoria Entities [('Victoria', 'city')]
# 123 Nova Scotia Drive, RD 2, Waipu 0582 Entities [('123', 'nr'), ('Nova Scotia Drive', 'street'), ('Waipu', 'city'), ('0582', 'postal')]
# Via Trinita 17/A, I-10026 Santena Torino Entities [('Via Trinita', 'street'), ('17', 'nr'), ('I-10026', 'postal'), ('Santena Torino', 'city')]
# 15 résidence Guillaume de voisin, 91190 Gif-sur-Yvette FR Entities [('15', 'nr'), ('résidence Guillaume de voisin', 'street'), ('91190', 'postal'), ('Gif-sur-Yvette', 'city'), ('FR', 'region')]
# 11527 Gallant Ridge Lane, Houston 77082 Entities [('11527', 'nr'), ('Gallant Ridge Lane', 'street'), ('Houston', 'city'), ('77082', 'postal')]
# Arkelsedijk 46, 4206 AC Gorinchem Entities [('Arkelsedijk', 'street'), ('46', 'nr'), ('4206 AC', 'postal'), ('Gorinchem', 'city')]
# Tel Aviv, IL Entities [('Tel Aviv', 'city'), ('IL', 'region')]
# Nara Entities [('Nara', 'region')]
# Eagle, ID Entities [('Eagle', 'city'), ('ID', 'region')]
# Kokubunji Entities [('Kokubunji', 'city')]
# McDonald, TN Entities [('McDonald', 'area'), ('TN', 'region')]
# 333 Lakeside Drive, Foster City, CA 94404 Entities [('333', 'nr'), ('Lakeside Drive', 'street'), ('Foster City', 'city'), ('CA', 'region'), ('94404', 'postal')]
# Belleville, NJ Entities [('Belleville', 'city'), ('NJ', 'region')]
# 3365 Mainway, Burlington, Ontario L7M 1A6 Entities [('3365', 'nr'), ('Mainway', 'street'), ('Burlington', 'area'), ('Ontario', 'city'), ('L7M 1A6', 'postal')]
# Tokyo Entities [('Tokyo', 'city')]
# Woodridge, IL Entities [('Woodridge', 'city'), ('IL', 'region')]
# 1 Kimball Court, 504, Woburn, MA 01801 Entities [('504', 'nr'), ('MA', 'region'), ('01801', 'postal')]
# Bleicherode Entities [('Bleicherode', 'city')]
# Apartment 41 Tjernysjevsskij Square, 8, St.Petersburg, 196070 Entities [('8', 'nr'), ('St.Petersburg', 'street'), ('196070', 'postal')]
# 9E, Laiguangying Road Chao Yang District, Beijing, CN Entities [('9E', 'nr'), ('Laiguangying Road Chao Yang District', 'area'), ('Beijing', 'city'), ('CN', 'region')]
# Kadoma Entities [('Kadoma', 'city')]
# Rormosen 204, DK-2990 Niv Entities [('Rormosen', 'street'), ('204', 'nr'), ('DK-2990', 'postal'), ('Niv', 'city')]
# Toronto, Ontario Entities [('Toronto', 'city'), ('Ontario', 'region')]
# 1152 E. Cottonwood, Ln., Phoenix, AZ, 85048 Entities [('1152', 'nr'), ('E. Cottonwood, Ln.', 'street'), ('Phoenix', 'city'), ('AZ', 'region'), ('85048', 'postal')]
# Williston Entities [('Williston', 'city')]
# Shizuoka Entities [('Shizuoka', 'city')]
# Pasadena, CA Entities [('Pasadena', 'city'), ('CA', 'region')]
# Kanagawa Entities [('Kanagawa', 'region')]
# HARUS S.R.L., Viale I Maggio, 156, 00046 Grottaferrata Entities [('HARUS S.R.L.,', 'co'), ('Viale I Maggio', 'street'), ('156', 'nr'), ('00046', 'postal'), ('Grottaferrata', 'city')]
# 156013, g. Kostroma, ul. Lenina, 19a, kv. 9, OOO 'Brend Agentstvo Zvezda' Entities [('156013', 'nr'), ('g. Kostroma', 'city'), ('ul. Lenina', 'street'), ('19a', 'nr'), ("OOO 'Brend", 'region'), ("Agentstvo Zvezda'", 'region')]
# Narashino Entities [('Narashino', 'city')]
# Mountain View, CA Entities [('Mountain View', 'city'), ('CA', 'region')]
# Otsu-shi Entities [('Otsu-shi', 'city')]
# Playa Vista, CA Entities [('Playa Vista', 'city'), ('CA', 'region')]
# Via San Giovanni Bosco 16, I-20028 San Vittore Olona MI Entities [('Via San Giovanni Bosco', 'street'), ('16', 'nr'), ('I-20028', 'postal'), ('San Vittore Olona', 'city'), ('MI', 'region')]
# Tokyo Entities [('Tokyo', 'city')]
# Munchen Entities [('Munchen', 'city')]
# Munich Entities [('Munich', 'city')]
# San Jose, CA Entities [('San Jose', 'city'), ('CA', 'region')]
# Foster City, CA Entities [('Foster City', 'city'), ('CA', 'region')]
# Sunnyvale Entities [('Sunnyvale', 'city')]
# Kortrijk Marke Entities [('Kortrijk Marke', 'city')]
# Airport Entities []
# 1077 Kamitoyoura, Azuchi cho, Gamougun, Shiga Entities [('1077', 'nr'), ('Kamitoyoura', 'street'), ('Gamougun', 'area'), ('Shiga', 'city')]
# Sunnyvale, CA Entities [('Sunnyvale', 'city'), ('CA', 'region')]
# Paris Entities [('Paris', 'city')]
# 8213 OLD MILL LANE, WILLIAMSBURG VA 23188 US US Entities [('8213', 'nr'), ('OLD MILL LANE', 'street'), ('WILLIAMSBURG', 'city'), ('VA', 'region'), ('23188', 'postal')]
# Pylkönmäki, Soijinmäentie 75 A 1, Mahlu Entities [('Pylkönmäki', 'city'), ('Soijinmäentie', 'city'), ('75', 'nr')]
# 2 John McQuinn Circle, Framingham, MA 01701 Entities [('2', 'nr'), ('John McQuinn Circle', 'street'), ('Framingham', 'city'), ('MA', 'region'), ('01701', 'postal')]
# Remsenburg Entities [('Remsenburg', 'city')]
# 1000 Holland Drive, Crete, IL 60417-2120 Entities [('1000', 'nr'), ('Holland Drive', 'street'), ('Crete', 'city'), ('IL', 'region'), ('60417-2120', 'postal')]
# Ebersteinstrasse 35, 75177 Pforzheim Entities [('Ebersteinstrasse', 'street'), ('35', 'nr'), ('75177', 'postal'), ('Pforzheim', 'city')]
# Postiljooninkatu 3, FIN-05800 Hyvinkää Entities [('Postiljooninkatu', 'street'), ('3', 'nr'), ('FIN-05800', 'postal'), ('Hyvinkää', 'city')]
# 117997, Moskva, ul. Miklukho-Maklaya, 16/10, korp. 71, IBKH RAN, ZAO Nauchno-proizvodstvennaya kompaniya 'Kombiotekh', zav. laboratorii biotekhnologii Krymskij M.A. Entities [('117997', 'postal'), ('Moskva', 'city'), ('ul. Miklukho-Maklaya', 'street'), ('16/10', 'nr')]
# Dedham, MA Entities [('Dedham', 'city'), ('MA', 'region')]
# Amakem NV, Life Sciences Incubator, Agoralaan A bis, B-3590 Diepenbeek Entities [('Amakem NV,', 'co'), ('Life Sciences Incubator', 'building'), ('Agoralaan A bis', 'street'), ('B-3590', 'postal'), ('Diepenbeek', 'city')]
# Toyota Entities [('Toyota', 'area')]
# Knoxville Entities [('Knoxville', 'city')]
# Burkittsville Entities [('Burkittsville', 'city')]
# Shizuoka Entities [('Shizuoka', 'city')]
# Neuherberg Entities [('Neuherberg', 'city')]
# 28, rue du Père Brottier, F-95110 Sannois Entities [('28', 'nr'), ('rue du Père Brottier', 'street'), ('F-95110', 'postal'), ('Sannois', 'city')]
# SIGMA-TAU Industrie Farmaceutiche Riunite S.p.A., Via Pontina, km 30, 400 00040, Pomezia Entities [('Via Pontina', 'street'), ('400 00040', 'postal'), ('Pomezia', 'city')]
# Cedar Rapids, IA Entities [('Cedar Rapids', 'city'), ('IA', 'region')]
# Sunnyvale Entities [('Sunnyvale', 'city')]
# 4-8, Minamisenba 2-chome, Chuo-ku, Osaka Entities [('4-8', 'street'), ('Minamisenba 2-chome', 'building'), ('Chuo-ku', 'area'), ('Osaka', 'city')]
# WEENDER LANDSTRASSE 94 TO 108, 3400 GOTTINGEN Entities [('WEENDER LANDSTRASSE', 'street'), ('108', 'nr'), ('GOTTINGEN', 'city')]
# St. Lucia Entities [('St. Lucia', 'city')]
# Yokohama-shi Entities [('Yokohama-shi', 'city')]
# Kirkland, WA Entities [('Kirkland', 'city'), ('WA', 'region')]
# Pre Marétan 4, 1274 Grens Entities [('Pre Marétan', 'street'), ('4', 'nr'), ('1274', 'postal'), ('Grens', 'city')]
# Bloomington Entities [('Bloomington', 'city')]
# Chicago, IL Entities [('Chicago', 'city'), ('IL', 'region')]
# 2711 Centerville Road 400, Wilmington, DE 19808 Entities [('2711', 'nr'), ('Centerville Road', 'street'), ('400', 'nr'), ('Wilmington', 'city'), ('DE', 'region'), ('19808', 'postal')]
# c/o MITSUBISHI TANABE PHARMA CORPORATION, 2-6-18 Kitahama, Chuo-ku, Osaka-shi Osaka 541-8505 Entities [('c/o MITSUBISHI TANABE PHARMA CORPORATION', 'co'), ('2-6-18 Kitahama', 'street'), ('Chuo-ku', 'area'), ('Osaka-shi Osaka', 'city'), ('541-8505', 'postal')]
# Kaohsiung Entities [('Kaohsiung', 'city')]
# Dallas, TX Entities [('Dallas', 'city'), ('TX', 'region')]
# Hamburg Entities [('Hamburg', 'city')]
# 8332 Querbes, Montréal, Québec H3N 2C5 Entities [('8332', 'nr'), ('Querbes', 'street'), ('Montréal', 'city'), ('Québec', 'region'), ('H3N 2C5', 'postal')]
# Commack, NY Entities [('Commack', 'area'), ('NY', 'region')]
# Malmö Entities [('Malmö', 'city')]
# Tokorozawa Entities [('Tokorozawa', 'city')]
# STR.ÎNVOIRII NR.23, SECTOR 5 BUCUREŞTI, B RO Entities [('STR.ÎNVOIRII', 'nr'), ('SECTOR 5', 'street'), ('BUCUREŞTI', 'city'), ('RO', 'region')]
# 33-1, Tamagawadei 2-chome, Setagaya-ku, Tokyo 158 Entities [('33-1', 'street'), ('Tamagawadei 2-chome', 'street'), ('Setagaya-ku', 'area'), ('Tokyo', 'city'), ('158', 'postal')]
# Kiryat Ata Entities [('Kiryat Ata', 'city')]
# Hull Entities [('Hull', 'city')]
# Steinkamp 3a, 48165 Münster Entities [('Steinkamp', 'street'), ('3a', 'nr'), ('48165', 'postal'), ('Münster', 'city')]
# 5555 Oakbrook Parkway Suite 200, Norcross, GA 30093 Entities [('5555', 'nr'), ('Oakbrook Parkway', 'street'), ('200', 'nr'), ('Norcross', 'city'), ('GA', 'region'), ('30093', 'postal')]
# 23149 Los Alison Blvd., Mission Viejo, California 92691 Entities [('23149', 'nr'), ('Los Alison Blvd.', 'street'), ('Mission Viejo', 'city'), ('California', 'city'), ('92691', 'postal')]
# Hiratsuka Entities [('Hiratsuka', 'city')]
# Schillerstr. 18, 85139 Wettstetten Entities [('Schillerstr.', 'street'), ('18', 'nr'), ('85139', 'postal'), ('Wettstetten', 'city')]
# 50 Pinsker Street, 46490 Herzelia Entities [('50', 'nr'), ('Pinsker Street', 'street'), ('46490', 'postal'), ('Herzelia', 'city')]
# East Sussex Entities [('East Sussex', 'city')]
# Warwick, RI Entities [('Warwick', 'city'), ('RI', 'region')]
# South Pasadena Entities [('South Pasadena', 'city')]
# 4140 S.W. Greenhills Way, Portland, OR 97221 Entities [('4140', 'nr'), ('S.W. Greenhills Way', 'street'), ('Portland', 'city'), ('OR', 'region'), ('97221', 'postal')]
# ARMIDALE AU Entities [('ARMIDALE', 'city'), ('AU', 'region')]
# Bochum Entities [('Bochum', 'city')]
# 1370, Onna, Atsugi-shi, Kanagawa 243-8510 Entities [('1370', 'nr'), ('Onna', 'area'), ('Atsugi-shi', 'city'), ('Kanagawa', 'region'), ('243-8510', 'postal')]
# Odawara Entities [('Odawara', 'city')]
# Via Garibaldi, 29, Zola Predosa I-40069 Bologna Entities [('Via Garibaldi', 'street'), ('29', 'nr'), ('Zola Predosa', 'city'), ('I-40069', 'postal'), ('Bologna', 'city')]
# Asveien 21, N-4817 HIS Entities [('Asveien', 'street'), ('21', 'nr'), ('N-4817', 'postal'), ('HIS', 'city')]
# Kabushiki Kaisha Toshiba, 1-1 Shibaura 1-chome, Minato-ku, Tokyo 105 Entities [('Tokyo', 'city'), ('105', 'nr')]
# Yokohama-shi Entities [('Yokohama-shi', 'city')]
# KRAKÓW PL Entities [('KRAKÓW', 'city'), ('PL', 'country')]
# No. 66, Lane 642, Tung Wan Shou Rd. Gueishan Hsiang, Taoyuan Hsien Entities [('Lane', 'street'), ('642', 'nr'), ('Tung Wan Shou Rd. Gueishan Hsiang', 'area'), ('Taoyuan Hsien', 'city')]
# Shenzhen Entities [('Shenzhen', 'city')]
# Eatontown Entities [('Eatontown', 'city')]
# Clarksville, MD Entities [('Clarksville', 'city'), ('MD', 'region')]
# Pfizer Global Research & Development, 201 Tabor Road Morris Plains, NJ 07950 Entities [('Pfizer Global Research & Development', 'co'), ('201', 'nr'), ('Tabor Road Morris Plains', 'street'), ('NJ', 'region'), ('07950', 'postal')]
# Saint-Cloud Entities [('Saint-Cloud', 'city')]
# Kampstrasse 97, 45772 Marl Entities [('Kampstrasse', 'street'), ('97', 'nr'), ('45772', 'postal'), ('Marl', 'city')]
# Kodaira Entities [('Kodaira', 'city')]
# 4, Boulevard du Maréchal Leclerc, Aguado, 91000 Evry Entities [('4', 'nr'), ('Boulevard du Maréchal Leclerc', 'street'), ('Aguado', 'city'), ('91000', 'postal'), ('Evry', 'city')]
# C/O MORPHOSYS AG, Lena-Christ-Strasse 48, 82152 Martinsried/Planegg GERMANY Entities [('Lena-Christ-Strasse', 'street'), ('48', 'nr'), ('82152', 'postal'), ('Martinsried', 'city'), ('Planegg', 'region'), ('GERMANY', 'region')]
# 9302 Hallsboro Circle, Apartment 302, Parkville Maryland 21234 Entities [('9302', 'nr'), ('Hallsboro Circle', 'street'), ('Parkville', 'city'), ('Maryland', 'city'), ('21234', 'postal')]
# Taipei Entities [('Taipei', 'city')]
# GONELLASTRASSE 24;D-4005 MEERBUSCH 3 Entities [('GONELLASTRASSE', 'city'), ('24;D-4005', 'nr'), ('MEERBUSCH 3', 'city')]
# Lerchtensternstrasse 6A, 50937 Köln Entities [('Lerchtensternstrasse', 'street'), ('6A', 'nr'), ('50937', 'postal'), ('Köln', 'city')]
# Madrid Entities [('Madrid', 'city')]
# 13, avenue du Président Salvador Allende, F-94117 Arceuil Cedex Entities [('13', 'nr'), ('avenue du Président Salvador Allende', 'street'), ('F-94117', 'postal'), ('Arceuil Cedex', 'city')]
# Zofingen Entities [('Zofingen', 'city')]
# 6837 S. Fredericksburg, Sylvania, OH 43560 Entities [('6837', 'nr'), ('S. Fredericksburg', 'street'), ('Sylvania', 'city'), ('OH', 'region'), ('43560', 'postal')]
# 35 Carter Street, South Portland, Maine 04106 Entities [('35', 'nr'), ('Carter Street', 'street'), ('South Portland', 'area'), ('Maine', 'city')]
# 2434 Forest Manor Court, Neenah, WI 54956 Entities [('2434', 'nr'), ('WI', 'region'), ('54956', 'postal')]
# Hsinchu County Entities [('Hsinchu County', 'city')]
# Northport, AL Entities [('Northport', 'city'), ('AL', 'region')]
# Shrewsbury Entities [('Shrewsbury', 'city')]
# Braunschweig Entities [('Braunschweig', 'city')]
# c/o Meiji Seika Pharma Co. Ltd., 760 Morooka-cho, Kohoku-ku, Yokohama-shi Kanagawa 222-8567 Entities [('c/o Meiji Seika Pharma Co. Ltd.', 'co'), ('760', 'nr'), ('Morooka-cho', 'street'), ('Kohoku-ku', 'area'), ('Yokohama-shi', 'city'), ('Kanagawa', 'city'), ('222-8567', 'postal')]
# Heathbank, Newmachar, Aberdeen Aberdeenshire AB21 7PP Entities [('Heathbank', 'street'), ('Newmachar', 'area'), ('Aberdeenshire', 'city'), ('AB21 7PP', 'postal')]
# Bay City Entities [('Bay City', 'city')]
# Samsung Electronics Co., Ltd. 416, Maetan-dong, Yeongtong-gu Suwon-si Gyeonggi-do Entities [('Maetan-dong', 'area'), ('Yeongtong-gu', 'city'), ('Suwon-si', 'city'), ('Gyeonggi-do', 'region')]
# Catalysts & Chem. Ind., 13-2, Kitaminatomachi Entities [('Catalysts & Chem. Ind.', 'co'), ('13-2', 'street'), ('Kitaminatomachi', 'city')]
# Peter-Henlein-Stra e 24, D-8562 Hersbruck Entities [('Peter-Henlein-Stra', 'street'), ('24', 'nr'), ('D-8562', 'postal'), ('Hersbruck', 'city')]
# 106 Crane Street, Charlton, New York 12302 Entities [('106', 'nr'), ('Crane Street', 'street'), ('Charlton', 'city'), ('New York', 'city'), ('12302', 'postal')]
# ZTE CORPORATION ZTE Plaza, Keji Road South, Hi-Tech Industrial Park, Nanshan, Shenzhen, Guangdong 518057 Entities [('ZTE CORPORATION ZTE Plaza', 'co'), ('Keji Road South', 'street'), ('Shenzhen', 'city'), ('Guangdong', 'region'), ('518057', 'postal')]
# Andover, MN Entities [('Andover', 'city'), ('MN', 'region')]
# Seocho-Gu Entities [('Seocho-Gu', 'street')]
# H. Lundbeck A/S Ottiliavej 9, 2500 Valby Entities [('H. Lundbeck A/S', 'co'), ('Ottiliavej', 'street'), ('9', 'nr'), ('2500', 'postal'), ('Valby', 'city')]
# Edwards, IL Entities [('Edwards', 'city'), ('IL', 'region')]
# 2000-1 Iwai, Iwata-Shi, Shizuoka-ken Entities [('Iwai', 'area'), ('Iwata-Shi', 'city'), ('Shizuoka-ken', 'region')]
# New York, ,NY Entities [('New York', 'city'), ('NY', 'region')]
# Keilaranta 6, 02150 Espoo Entities [('Keilaranta', 'street'), ('6', 'nr'), ('02150', 'postal'), ('Espoo', 'city')]
# 19/21 New Road, Willenhall, West Midlands WV13 2BG Entities [('19/21', 'nr'), ('New Road', 'street'), ('Willenhall', 'city'), ('West Midlands', 'region'), ('WV13 2BG', 'postal')]
# Idstein Entities [('Idstein', 'city')]
# Thermi Entities [('Thermi', 'city')]
# Merikulmantie 553, FI-25570 Teijo Entities [('Merikulmantie', 'street'), ('553', 'nr'), ('Teijo', 'city')]
# Higashi-yamato Entities [('Higashi-yamato', 'city')]
# 300-18, Aza Toyohara, Oaza Motohara, Kamikawamachi, ,Kodama-gun Saitama Entities [('300-18', 'street'), ('Aza Toyohara', 'area'), ('Kamikawamachi', 'city'), ('Kodama-gun', 'city'), ('Saitama', 'region')]
# Sparks, NV Entities [('Sparks', 'city'), ('NV', 'region')]
# 2-1-7, Mayumiminami, Ikoma-shi, Nara 630-01 Entities [('2-1-7', 'street'), ('Mayumiminami', 'area'), ('Ikoma-shi', 'city'), ('Nara', 'region'), ('630-01', 'postal')]
# Mars Drinks UK Ltd., Armstrong Road, Basingstoke, Hampshire RG24 8NU Entities [('Armstrong Road', 'street'), ('Basingstoke', 'city'), ('Hampshire', 'region'), ('RG24 8NU', 'postal')]
# Malans Entities [('Malans', 'area')]
# Niigata, 943-0834 Entities [('Niigata', 'city'), ('943-0834', 'postal')]
# 61118 Bad Vilbel Entities [('61118', 'postal'), ('Bad Vilbel', 'city')]
# 420-403 Jugong Apt., ,189 Gaepo-dong, Gangnam-gu, Seoul Entities [('189', 'nr'), ('Gaepo-dong', 'street'), ('Gangnam-gu', 'area'), ('Seoul', 'city')]
# KREFELD DE Entities [('KREFELD', 'city'), ('DE', 'country')]
# Luxembourg Entities [('Luxembourg', 'city')]
# Leesburg, VA Entities [('Leesburg', 'city'), ('VA', 'region')]
# Detroit Entities [('Detroit', 'city')]
# Frankenthal Entities [('Frankenthal', 'city')]
# 1 Bioscience Park Drive, Farmingdale, NY 11735 Entities [('1', 'nr'), ('Bioscience Park Drive', 'street'), ('Farmingdale', 'area'), ('NY', 'region'), ('11735', 'postal')]
# Las Cruces, NM Entities [('Las Cruces', 'city'), ('NM', 'region')]
# Kurt-Schumacher-Ring 140, Leverkusen 51377 Entities [('Kurt-Schumacher-Ring', 'street'), ('140', 'nr'), ('Leverkusen', 'city'), ('51377', 'postal')]
# Prof. Holstlaan 6, NL-5656 AA Eindhoven Entities [('Prof. Holstlaan', 'street'), ('6', 'nr'), ('Eindhoven', 'city')]
# Monksland Entities [('Monksland', 'area')]
# Redwood City, CA Entities [('Redwood City', 'city'), ('CA', 'region')]
# Boulogne Entities [('Boulogne', 'city')]
# 183-2, 5/5 Bokcheon-dong Dongrae-gu, Busan 607-020 Entities [('183-2', 'street'), ('Bokcheon-dong', 'area'), ('Dongrae-gu', 'city'), ('Busan', 'region'), ('607-020', 'postal')]
# 18 Farguharson Road, Croydon, Surrey CR0 2UH Entities [('18', 'nr'), ('Farguharson Road', 'street'), ('Croydon', 'city'), ('Surrey', 'city'), ('CR0 2UH', 'postal')]
# Atlanta, GA Entities [('Atlanta', 'city'), ('GA', 'region')]
# La Grange Entities [('La Grange', 'city')]
# Nisshin Entities [('Nisshin', 'city')]
# Chiyoda-ku Entities [('Chiyoda-ku', 'area')]
# 3-30-2, Shimomaruko, Ohta-ku, Tokyo Entities [('3-30-2', 'street'), ('Shimomaruko', 'area'), ('Ohta-ku', 'area'), ('Tokyo', 'city')]
# Kanagawa Entities [('Kanagawa', 'region')]
# Avenue Slegers, 207, B-1200 Bruxelles Entities [('Avenue Slegers', 'street'), ('207', 'nr'), ('B-1200', 'postal'), ('Bruxelles', 'city')]
# NO.936 ZHANG HENG ROAD, ZHANGJIANG HI-TECH PARK SHANGHAI 201203 Entities [('NO.936', 'nr'), ('ZHANG HENG ROAD', 'street'), ('ZHANGJIANG HI-TECH PARK', 'area'), ('SHANGHAI', 'city'), ('201203', 'postal')]
# Tokyo Entities [('Tokyo', 'city')]
# NA Entities [('NA', 'region')]
# 87 Sopwith Crescent Merley, Wimbourne, Dorset BH21 35W Entities [('87', 'nr'), ('Sopwith Crescent', 'street'), ('Merley', 'area'), ('Dorset BH21 35W', 'area')]
# Weston, FL Entities [('Weston', 'city'), ('FL', 'region')]
# Worcester, MA Entities [('Worcester', 'city'), ('MA', 'region')]
# Crofton Entities [('Crofton', 'city')]
# 735 Braewood Drive, Algonquin, Illinois 60102 Entities [('735', 'nr'), ('Braewood Drive', 'street'), ('Algonquin', 'city'), ('Illinois', 'region'), ('60102', 'postal')]
# 202-1803 Hanshin Apt, Imae-dong, Bundang-gu, Seongnam-si, Gyeonggi-do Entities [('202-1803', 'nr'), ('Bundang-gu', 'area'), ('Seongnam-si', 'area'), ('Gyeonggi-do', 'region')]
# Mokryun Apt. 1241-1005 1091-1, Sanbon-Dong, Gunpo Gyeonggi-Do Entities [('Mokryun Apt. 1241', 'co'), ('Sanbon-Dong', 'area'), ('Gunpo', 'city'), ('Gyeonggi-Do', 'region')]
# High Tech Campus Building 44, 5656 AE Eindhoven Entities [('High Tech Campus Building 44', 'co'), ('5656', 'postal'), ('AE', 'city'), ('Eindhoven', 'city')]
# c/o Hitachi. Ltd., Intellectual Property Office, 12F, Marunouchi Center Building, 6-1, Marunouchi 1-chome, Chiyoda-ku, Tokyo 100-8220 Entities [('c/o Hitachi. Ltd.', 'co'), ('Intellectual Property Office', 'street'), ('Marunouchi Center Building', 'area'), ('6-1', 'street'), ('Marunouchi 1-chome', 'street'), ('Chiyoda-ku', 'area'), ('Tokyo', 'city'), ('100-8220', 'postal')]
# 1-21-2, Dohgenzaka Shibuya-ku, Tokyo 150 Entities [('Dohgenzaka Shibuya-ku', 'area'), ('Tokyo', 'city'), ('150', 'nr')]
# Tigard, OR Entities [('Tigard', 'area'), ('OR', 'region')]
# Mölnlycke Entities [('Mölnlycke', 'city')]
# Shibukawa Kojo, 1135 Nakamura, Shibukawa-shi, Gunma 377-0002 Entities [('Shibukawa Kojo', 'building'), ('1135', 'nr'), ('Nakamura', 'city'), ('Shibukawa-shi', 'city'), ('Gunma', 'region'), ('377-0002', 'postal')]
# Auburn Hills Entities [('Auburn Hills', 'city')]
# 10 The Courtyard, Castleredmond, Midleton Entities [('10', 'nr'), ('The Courtyard', 'street'), ('Castleredmond', 'city'), ('Midleton', 'city')]
# 123-1, Kitanishi-cho, Yamatokoriyama-shi, Nara 639-1025 Entities [('123-1', 'street'), ('Kitanishi-cho', 'area'), ('Yamatokoriyama-shi', 'city'), ('Nara', 'region'), ('639-1025', 'postal')]
# 219 Locust Rd., Fort Washington, PA, 19034 Entities [('219', 'nr'), ('Locust Rd.', 'street'), ('Fort Washington', 'city'), ('PA', 'region'), ('19034', 'postal')]
# c/o School of Pharmacy, RCSI, 122 St Stephens Green, Dublin, D2 Entities [('c/o School of Pharmacy', 'co'), ('RCSI', 'city'), ('122', 'nr'), ('St Stephens Green', 'street'), ('Dublin', 'city'), ('D2', 'postal')]
# Route de Thouars, F-79700 Mauleon Entities [('Route de Thouars', 'street'), ('F-79700', 'postal'), ('Mauleon', 'city')]
# Barrington Entities [('Barrington', 'area')]
# 180 Ang Mo Kio Avenue 8, Singapore, 569830 Entities [('180', 'nr'), ('Ang Mo Kio Avenue', 'street'), ('8', 'nr'), ('Singapore', 'city'), ('569830', 'postal')]
# Östra Björnvägen 2, S-429 30 Kullavik Entities [('Östra Björnvägen', 'street'), ('2', 'nr'), ('S-429 30', 'postal'), ('Kullavik', 'city')]
# 24, rue des Cerisiers, F-78420 Carrières sur Seine Entities [('24', 'nr'), ('rue des Cerisiers', 'street'), ('F-78420', 'postal'), ('Carrières sur Seine', 'city')]
# 1514 Titania Road, Tobyhanna, PA 18466 Entities [('1514', 'nr'), ('Titania Road', 'street'), ('Tobyhanna', 'city'), ('PA', 'region'), ('18466', 'postal')]
# Kyoto Entities [('Kyoto', 'city')]
# Chandigarm Entities [('Chandigarm', 'city')]
# Ravensburger Strasse 28, 88279 Amtzell Entities [('Ravensburger Strasse', 'street'), ('28', 'nr'), ('88279', 'postal'), ('Amtzell', 'city')]
# Bloomington, IL Entities [('Bloomington', 'city'), ('IL', 'region')]
# Avda. Valladolid N°21 B Bajo, E-28008 Madrid Entities [('Avda. Valladolid', 'street'), ('N°21', 'nr'), ('Bajo', 'city'), ('E-28008', 'postal'), ('Madrid', 'city')]
# 22 Bungalow Hill Road, Farmington, Connecticut 06032 Entities [('22', 'nr'), ('Bungalow Hill Road', 'street'), ('Farmington', 'city'), ('Connecticut', 'region'), ('06032', 'postal')]
# Kobe-city Entities [('Kobe-city', 'city')]
# Tustin Entities [('Tustin', 'city')]
# Nagaokakyo Entities [('Nagaokakyo', 'city')]
# c/o Hitachi Appliances, Inc. 390 Muramatsu, Shimizu-ku, Shizuoka-shi, Shizuoka-ken 424-0926 Entities [('c/o Hitachi Appliances,', 'co'), ('Muramatsu', 'city'), ('Shimizu-ku', 'area'), ('Shizuoka-shi', 'city'), ('Shizuoka-ken', 'region'), ('424-0926', 'postal')]
# c/o Prof. Holstlaan 6, NL-5656 AA Eindhoven Entities [('c/o Prof. Holstlaan', 'co'), ('6', 'nr'), ('Eindhoven', 'city')]
# Mountainside, NJ Entities [('Mountainside', 'area'), ('NJ', 'region')]
# Zhejiang Entities [('Zhejiang', 'city')]
# Jarreitsulle, MD Entities [('Jarreitsulle', 'city'), ('MD', 'region')]
# 21-1-507 Kamiooka-higashi 1-chome, Yokohama city, Kanagawa Entities [('Yokohama city', 'city'), ('Kanagawa', 'region')]
# / Sony Deutschland Gmbh, Hedelfinger Strasse 61 / Entities [('Hedelfinger Strasse', 'street'), ('61', 'nr')]
# Berkeley Entities [('Berkeley', 'city')]
# Yamato Entities [('Yamato', 'city')]
# Horsham Entities [('Horsham', 'city')]
# 22069 W.Milestone Street, Santa Clarita, CA California 91390 Entities [('22069', 'nr'), ('W.Milestone Street', 'street'), ('Santa Clarita', 'city'), ('CA', 'region'), ('California', 'city'), ('91390', 'postal')]
# No.1, West Beichen Road, Chaoyang District, Beijing 100101 Entities [('No.1', 'nr'), ('West Beichen Road', 'street'), ('Chaoyang District', 'area'), ('Beijing', 'city'), ('100101', 'postal')]
# 2-1006, Jangmi Apt., Sincheon-dong, ,Songpa-gu, Seoul Entities [('2-1006', 'street'), ('Jangmi Apt.', 'building'), ('Sincheon-dong', 'area'), ('Songpa-gu', 'city'), ('Seoul', 'city')]
# Langenhainer Weg 14 6234 Hattersheim am Main Germany Entities [('Langenhainer Weg', 'street'), ('14', 'nr'), ('6234', 'postal'), ('Hattersheim am Main', 'city'), ('Germany', 'region')]
# Wangen Entities [('Wangen', 'city')]
# c/o MITSUBISHI ENGINEERING-PLASTICS CORPORATION, 6-2 Higashiyawata 5-chome, Hiratsuka-shi Kanagawa 254-0016 Entities [('c/o MITSUBISHI ENGINEERING-PLASTICS CORPORATION', 'co'), ('6-2 Higashiyawata 5-chome', 'street'), ('Hiratsuka-shi', 'city'), ('Kanagawa', 'region'), ('254-0016', 'postal')]
# Charleston Entities [('Charleston', 'city')]
# 10 Yehuda St., 52504, Ramat Gan Entities [('10', 'nr'), ('Yehuda St.', 'street'), ('52504', 'postal'), ('Ramat Gan', 'city')]
# 26 W. Torrence Road, Columbus, OH 43214 Entities [('26', 'nr'), ('W. Torrence Road', 'street'), ('Columbus', 'city'), ('OH', 'region'), ('43214', 'postal')]
# Chennai Entities [('Chennai', 'city')]
# Else-Lang-Strasse 14, 50858 Köln Entities [('Else-Lang-Strasse', 'street'), ('14', 'nr'), ('50858', 'postal'), ('Köln', 'city')]
# Chicago Heights Entities [('Chicago Heights', 'city')]
# Stamplast S.A.S., Strada Pilastro 10/A, Torrechiara Langhirano, 43010 Parma Entities [('Stamplast S.A.S.', 'co'), ('Strada Pilastro', 'street'), ('10', 'nr'), ('Torrechiara Langhirano', 'area'), ('43010', 'postal'), ('Parma', 'city')]
# 2, Annette's Croft, Church Crookham, Fleet, Hampshire GU13 OXN Entities [('2', 'nr'), ("Annette's Croft", 'street'), ('Church Crookham', 'city'), ('Hampshire', 'region'), ('GU13 OXN', 'postal')]
# Easton Entities [('Easton', 'city')]
# Annapolis, MD Entities [('Annapolis', 'city'), ('MD', 'region')]
# C/O HITACHI HIGH-TECHNOLOGIES CORPORATION, 24-14, NISHI SHIMBASHI 1-CHOME, MINATO-KU, TOKYO 1058717 〒1058717 Entities [('C/O HITACHI HIGH-TECHNOLOGIES CORPORATION', 'co'), ('24-14', 'street'), ('MINATO-KU', 'area'), ('TOKYO', 'city'), ('〒1058717', 'postal')]
# Atlanta, GA Entities [('Atlanta', 'city'), ('GA', 'region')]
# Veenlanden 40, 3871 RD Hoevelaken Entities [('Veenlanden', 'street'), ('40', 'nr'), ('3871 RD', 'postal'), ('Hoevelaken', 'city')]
# New Canaan Entities [('New Canaan', 'city')]
# Scarborough, ME Entities [('Scarborough', 'city'), ('ME', 'region')]
# Greenwood Entities [('Greenwood', 'city')]
# STR. TANGANULUI NR. 7, SECTOR 6 BUCUREŞTI, B RO Entities [('STR. TANGANULUI', 'street'), ('7', 'nr'), ('SECTOR 6', 'area'), ('BUCUREŞTI', 'city'), ('RO', 'region')]
# Berlin Entities [('Berlin', 'city')]
# Moscow Entities [('Moscow', 'city')]
# Palo Alto, CA Entities [('Palo Alto', 'city'), ('CA', 'region')]
# Warwich Entities [('Warwich', 'city')]
# 605, 5-Cha, 493 Daerung-tchno Town, Seoul City, 153-023 Entities [('605', 'nr'), ('493 Daerung-tchno Town', 'area'), ('Seoul City', 'city'), ('153-023', 'postal')]
# 2-56, Suda-cho, Mizuho-ku, Nagoya-shi, Aichi 467-8530 Entities [('2-56', 'street'), ('Suda-cho', 'area'), ('Mizuho-ku', 'area'), ('Nagoya-shi', 'city'), ('Aichi', 'region'), ('467-8530', 'postal')]
# Kurashiki Entities [('Kurashiki', 'city')]
# Emslandstrasse 3, D-4370 Marl Entities [('Emslandstrasse', 'street'), ('3', 'nr'), ('D-4370', 'postal'), ('Marl', 'city')]
# Donetsk Entities [('Donetsk', 'city')]
# Apt. 1, 790 Court of Birch, Vernon Hills IL 60061 Entities [('790', 'nr'), ('Court of Birch', 'street'), ('Vernon Hills', 'city'), ('IL', 'region'), ('60061', 'postal')]
# C/O DENSO CORPORATION, 1-1 Showa-cho, Kariya-city Aichi 448-8661 Entities [('Showa-cho', 'street'), ('Kariya-city', 'city'), ('Aichi', 'region'), ('448-8661', 'postal')]
# 1537 SANDPIPER DRIVE LONDON, ONTARIO N5X 0G4 Entities [('1537', 'nr'), ('SANDPIPER DRIVE', 'street'), ('ONTARIO', 'city'), ('N5X 0G4', 'postal')]
# Somerset Entities [('Somerset', 'region')]
# 601 Ansel Road, Apt. 212, Burlingame CA 94010 Entities [('601', 'nr'), ('Ansel Road', 'street'), ('Burlingame', 'city'), ('CA', 'region'), ('94010', 'postal')]
# Aberdeen Entities []
# Starting Industrial Co., Ltd. 4-4, Momoi 4-chome Suginami-ku, Tokyo 167 Entities [('Starting Industrial Co.', 'co'), ('Momoi 4-chome Suginami-ku', 'area'), ('Tokyo', 'city')]
# Bossier City Entities [('Bossier City', 'city')]
# Nivelles Entities [('Nivelles', 'city')]
# Bad Voelsau Entities [('Bad Voelsau', 'city')]
# ROOM 403, EAST BLOCK 2, SEG PARK, ZHENXING ROAD, FUTIAN DISTRICTSHENZHEN, GUANGDONG 518000 CN Entities [('ROOM 403, EAST BLOCK 2', 'co'), ('SEG PARK', 'building'), ('ZHENXING ROAD', 'street'), ('FUTIAN DISTRICTSHENZHEN', 'area'), ('GUANGDONG', 'city'), ('518000', 'postal'), ('CN', 'country')]
# Shanghai, 201203 Entities [('Shanghai', 'city'), ('201203', 'postal')]
# Jackson Entities [('Jackson', 'city')]
# 81N. Park Avenue, Fond du Lac WI 54935 Entities [('81N. Park Avenue', 'co'), ('Fond du Lac', 'street'), ('WI', 'region'), ('54935', 'postal')]
# 43 Wilderness Lane, Valatie, NY 12184 Entities [('43', 'nr'), ('Wilderness Lane', 'street'), ('Valatie', 'city'), ('NY', 'region'), ('12184', 'postal')]
# Ferrara Entities [('Ferrara', 'city')]
# Elkhart Entities [('Elkhart', 'city')]
# Escondido, CA Entities [('Escondido', 'city'), ('CA', 'region')]
# 34361 Innovation Drive, Ronan, MT 59864 Entities [('34361', 'nr'), ('Innovation Drive', 'street'), ('Ronan', 'city'), ('MT', 'region'), ('59864', 'postal')]
# Goldshöfe im Forst, D-7095 Rainau/Württ Entities [('Goldshöfe im Forst', 'co'), ('Rainau', 'city'), ('Württ', 'region')]
# Yono Entities [('Yono', 'city')]
# Ashigarakami-gun Entities [('Ashigarakami-gun', 'area')]
# Ebina Entities [('Ebina', 'city')]
# 4808 Winton Road, Cincinnati, Ohio 45232 Entities [('4808', 'nr'), ('Winton Road', 'street'), ('Cincinnati', 'area'), ('Ohio', 'city'), ('45232', 'postal')]
# Christchurch Entities [('Christchurch', 'city')]
# 72, route de Bellegarde, 1284 Chancy Entities [('72', 'nr'), ('route de Bellegarde', 'street'), ('1284', 'postal'), ('Chancy', 'city')]
# Goshen, IN Entities [('Goshen', 'city'), ('IN', 'region')]
# Morgan Hill, CA Entities [('Morgan Hill', 'city'), ('CA', 'region')]
# Qingdao Entities [('Qingdao', 'city')]
# Jeddah Entities [('Jeddah', 'city')]
# Miami, FL Entities [('Miami', 'city'), ('FL', 'region')]
# Tananger Entities []
# Tsurugashima-shi Entities [('Tsurugashima-shi', 'street')]
# Baltrumstrasse 12, D-4000 Düsseldorf 30 Entities [('Baltrumstrasse', 'street'), ('12', 'nr')]
# 84 PITT STREET SYDNEY, NEW SOUTH WALES 2000 Entities [('84', 'nr'), ('PITT STREET', 'street'), ('SYDNEY', 'area'), ('NEW SOUTH WALES', 'area'), ('2000', 'postal')]
# 'Chez d'Jou' Brightwell-cum-Sotwell, Wallingford Oxfordshire Entities [("'Chez d'Jou' Brightwell-cum-Sotwell", 'co'), ('Wallingford Oxfordshire', 'city')]
# c/o Rakuten, Inc., 4-12-3 Higashishinagawa Entities [('c/o Rakuten', 'co'), ('4-12-3', 'street'), ('Higashishinagawa', 'city')]
# c/o Center for iPS Cell Research and Application, Institute for Integrated Cell-Material Sciences, JP Entities [('c/o Center for iPS Cell Research and Application', 'co'), ('Sciences', 'city'), ('JP', 'region')]
# 24 WEST CICOTTE STREET, RIVER ROUTE, MICHIGAN 48218 Entities [('24', 'nr'), ('48218', 'postal')]
# Great Neck Entities [('Great Neck', 'city')]
# Rullstorf Entities [('Rullstorf', 'city')]
# 111-201, Nonhyun-dong, Gangnam-gu, Seoul Entities [('111-201', 'nr'), ('Gangnam-gu', 'area'), ('Seoul', 'city')]
# Ravello, Delmondo Office Park, 169 Garstfontein Road, Ashlea Gardens, 0081 Pretoria Entities [('Delmondo Office Park', 'street'), ('169', 'nr'), ('Garstfontein Road', 'street'), ('Ashlea Gardens', 'area'), ('0081', 'postal'), ('Pretoria', 'city')]
# 53, YEONGTONG-RO 27BEON-GIL GYEONGGI-DO 18376 HWASEONG-SI Entities [('53', 'nr'), ('YEONGTONG-RO 27BEON-GIL', 'street'), ('GYEONGGI-DO', 'area'), ('18376', 'postal'), ('HWASEONG-SI', 'city')]
# Elmshorn Entities [('Elmshorn', 'city')]
# Am Dornenbusch 12, B-4700 Eupen Entities [('Am Dornenbusch', 'street'), ('12', 'nr'), ('B-4700', 'postal'), ('Eupen', 'city')]
# Columbia, MD Entities [('Columbia', 'city'), ('MD', 'region')]
# A501 Picasso Villa, 79-5 Banpo-dong, Seocho-gu Seoul 137-040 Entities [('A501 Picasso Villa', 'co'), ('Banpo-dong', 'street'), ('Seocho-gu', 'area'), ('Seoul', 'city'), ('137-040', 'postal')]
# Hudson, MA Entities [('Hudson', 'city'), ('MA', 'region')]
# C/O YAMADA BEE COMPANY, INC, 194 ICHIBA, KAGAMINO-CHO, TOMATA-GUN, OKAYAMA 7080393 〒7080393 Entities [('TOMATA-GUN', 'area'), ('OKAYAMA', 'region'), ('7080393', 'postal')]
# Tokyo Entities [('Tokyo', 'city')]
# UNIVERSAL CITY PLAZA UNIVERSAL CITY, CA 91608 (US) US Entities [('UNIVERSAL', 'city'), ('PLAZA UNIVERSAL CITY', 'region'), ('CA', 'region'), ('91608', 'postal')]
# Neusäss Entities [('Neusäss', 'city')]
# Sunnyvale, CA Entities [('Sunnyvale', 'city'), ('CA', 'region')]
# c/o Prof.Holstlaan 6, NL-5656 AA Eindhoven Entities [('c/o Prof.Holstlaan', 'co'), ('6', 'nr'), ('Eindhoven', 'city')]
# Loimaa Entities [('Loimaa', 'city')]
# Kiryat Weizmann, P.O. Box 150, 76101 Rehovot Entities [('Kiryat Weizmann', 'city'), ('P.O. Box 150', 'street'), ('76101', 'postal'), ('Rehovot', 'city')]
# Bruckmuhl Entities [('Bruckmuhl', 'city')]
# 7-35, Kitashinagawa 6-chome, Shinagawa-ku, Tokyo Entities [('7-35', 'street'), ('Kitashinagawa 6-chome', 'street'), ('Shinagawa-ku', 'city'), ('Tokyo', 'city')]
# Loganville, GA Entities [('Loganville', 'city'), ('GA', 'region')]
# Rue de l'Institut 89, B-1330 Rixensart BE Entities [("Rue de l'Institut", 'street'), ('89', 'nr'), ('B-1330', 'postal'), ('Rixensart', 'city'), ('BE', 'country')]
# Portland, OR Entities [('Portland', 'city'), ('OR', 'region')]
# Napoli Entities [('Napoli', 'city')]
# Bellville Entities [('Bellville', 'city')]
# 11, Beech Street, Maplewood, New Jersey 07040 Entities [('11', 'nr'), ('Beech Street', 'street'), ('Maplewood', 'city'), ('New Jersey', 'region'), ('07040', 'postal')]
# 11937 Basswood Avenue, Uniontown, OH 44685 Entities [('11937', 'nr'), ('Basswood Avenue', 'street'), ('Uniontown', 'city'), ('OH', 'region'), ('44685', 'postal')]
# Chalon-sur-Saone Entities []
# c/o Graco Minnesota Inc., 88 11th Avenue NE, Minneapolis, MN Minnesota 55413 Entities [('c/o Graco Minnesota Inc.', 'co'), ('88', 'nr'), ('11th Avenue NE', 'street'), ('Minneapolis', 'city'), ('MN Minnesota', 'region'), ('55413', 'postal')]
# GE Global Research, One Research Circle Entities [('GE Global Research', 'co'), ('One Research Circle', 'street')]
# Düsseldorf Entities [('Düsseldorf', 'city')]
# Santa Paula Entities [('Santa Paula', 'city')]
# 4200 Scotland St., Apt. 520, Houston, TX 77007 Entities [('4200', 'nr'), ('Scotland St.', 'street'), ('Apt. 520', 'building'), ('Houston', 'city'), ('TX', 'region'), ('77007', 'postal')]
# 1715 North Umberland Way, Monmouth Junction, New Jersey 08852 Entities [('1715', 'nr'), ('North Umberland Way', 'street'), ('Monmouth Junction', 'city'), ('New Jersey', 'region'), ('08852', 'postal')]
# C/O MITSUBISHI ELECTRIC CORPORATION, 7-3, MARUNOUCHI 2-CHOME, CHIYODA-KU, TOKYO 1008310 〒1008310 Entities [('7-3, MARUNOUCHI 2-CHOME', 'street'), ('CHIYODA-KU', 'area'), ('TOKYO', 'city'), ('1008310 〒1008310', 'postal')]
# Connenweilerstrasse 21/1, 74597 Rechenberg Entities [('Connenweilerstrasse', 'street'), ('74597', 'postal'), ('Rechenberg', 'city')]
# Chicago, IL Entities [('Chicago', 'city'), ('IL', 'region')]
# Beijing Entities [('Beijing', 'city')]
# c/o NTT DoCoMo, Inc., SANNO PARK TOWER, Tokyo Entities [('c/o NTT DoCoMo, Inc.', 'co'), ('SANNO PARK TOWER', 'building'), ('Tokyo', 'city')]
# West Roxbury, MA Entities [('West Roxbury', 'area'), ('MA', 'region')]
# c/o DAIKAN INDUSTRIES, LTD., Umeda Center Building Entities [('c/o DAIKAN INDUSTRIES', 'co'), ('Umeda Center Building', 'area')]
# c/o Snecma PI (AJI), Rond-Point René Ravaud Réau, 77550 Moissy-cramayel Cedex Entities [('c/o Snecma PI (AJI)', 'co'), ('Rond-Point René Ravaud Réau', 'street'), ('Moissy-cramayel', 'city')]
# 1 Gwihyun-dong, Changwon, Kyungsangnam-do Entities [('1', 'nr'), ('Gwihyun-dong', 'street'), ('Changwon', 'city'), ('Kyungsangnam-do', 'region')]
# Building A, Raycom Info Tech Park Tower 2 Kexueyuan Nanlu, zhongguancun 100081 CN Entities [('Building A', 'street'), ('Raycom Info Tech Park Tower', 'co'), ('2', 'nr'), ('Kexueyuan Nanlu', 'street'), ('100081', 'postal')]
# Hwaseong-si Entities [('Hwaseong-si', 'city')]
# Les Raffards, 42600 Precieux Entities [('Les Raffards', 'street'), ('42600', 'postal'), ('Precieux', 'city')]
# Temecula Entities [('Temecula', 'city')]
# c/o Mitsuboshi Diamond Industrial Co., Ltd. 2-12-12, Minami-Kaneden, Suita-city, Osaka Entities [('c/o Mitsuboshi Diamond Industrial Co.', 'co'), ('Minami-Kaneden', 'area'), ('Suita-city', 'city'), ('Osaka', 'region')]
# 61 rue de Roth, 57910 Neufgrange Entities [('61', 'nr'), ('rue de Roth', 'street'), ('57910', 'postal'), ('Neufgrange', 'city')]
# Davie, FL Entities [('Davie', 'city'), ('FL', 'region')]
# 16503 Terrey Pine Drive, Eden Prairie, MN 55347 Entities [('16503', 'nr'), ('Terrey Pine Drive', 'street'), ('Eden Prairie', 'city'), ('MN', 'region'), ('55347', 'postal')]
# ...
# Norra Skeppspromenaden 6, 41763 Göteborg Entities [('Norra Skeppspromenaden', 'street'), ('6', 'nr'), ('41763', 'postal'), ('Göteborg', 'city')]
# 412 E. Kenilworth Ave., Royal Oak MI 48067 Entities [('412 E. Kenilworth Ave.', 'street'), ('Royal Oak', 'city'), ('MI', 'region'), ('48067', 'postal')]
# Sagamihara Entities [('Sagamihara', 'city')]
# Takasago Entities [('Takasago', 'city')]
# Port Sunlight Lab., Quarry Road East, Bebington, Wirral, Merseyside L63 3JW Entities [('Port Sunlight Lab.', 'co'), ('Quarry Road East', 'street'), ('Bebington', 'city'), ('Wirral', 'region'), ('Merseyside', 'region'), ('L63 3JW', 'postal')]
# Premiá de Mar Entities [('Premiá de Mar', 'city')]
# 800 North Lindbergh Blvd., St. Louis, MO 63167 Entities [('800', 'nr'), ('North Lindbergh Blvd.', 'street'), ('St. Louis', 'city'), ('MO', 'region'), ('63167', 'postal')]
# Morgan Hill, CA Entities [('Morgan Hill', 'city'), ('CA', 'region')]
# c/o Microbial Chemistry Research Foundation, 14-23 Kamiosaki 3-chome Entities [('c/o Microbial Chemistry Research Foundation', 'co'), ('14-23 Kamiosaki 3-chome', 'street')]
# 300 Garlington Road, Greenville, SC 29615 Entities [('300', 'nr'), ('Garlington Road', 'street'), ('Greenville', 'city'), ('SC', 'region'), ('29615', 'postal')]
# Sodegaura Entities [('Sodegaura', 'city')]
# Yongin-si Entities [('Yongin-si', 'city')]
# Lange Koepoortstraat 49 B-2000 Antwerpen BE Entities [('Lange Koepoortstraat', 'street'), ('49', 'nr'), ('Antwerpen', 'city'), ('BE', 'region')]
# 3, rue de l'Isly, F-75008 PARIS Entities [('3', 'nr'), ("rue de l'Isly", 'street'), ('F-75008', 'postal'), ('PARIS', 'city')]
# Baldwin Park, CA Entities [('Baldwin Park', 'area'), ('CA', 'region')]
# Yoncalla, OR Entities [('Yoncalla', 'city'), ('OR', 'region')]
# Calgary Entities [('Calgary', 'city')]
# Meguro-ku Entities []
# Kanagawa Entities [('Kanagawa', 'region')]
# C/O Nice, Inc., One Bowerman Drive, Beaverton, OR 97005-6453 Entities [('One Bowerman Drive', 'street'), ('Beaverton', 'city'), ('OR', 'region'), ('97005-6453', 'postal')]
# Gyeonggi-do Entities [('Gyeonggi-do', 'region')]
# 135 Marlborough Street, Unit 5, Boston, Massachusetts 02216 Entities [('135', 'nr'), ('Marlborough Street', 'street'), ('Unit 5', 'building'), ('Boston', 'city'), ('Massachusetts', 'region'), ('02216', 'postal')]
# 9Fl., No. 786, Chung-Cheng Rd., Chung-Ho City, Taipei Hsien Entities [('9Fl.,', 'co'), ('Chung-Cheng Rd.', 'area'), ('Chung-Ho City', 'area'), ('Taipei Hsien', 'city')]
# 36 Wildcat Branch Road, Sicklerville, NJ 08081 Entities [('36', 'nr'), ('Wildcat Branch Road', 'street'), ('Sicklerville', 'city'), ('NJ', 'region'), ('08081', 'postal')]
# 129 Blay Ridge Parkway, Apt. 3, Brooklyn, NY 11209 Entities [('129', 'nr'), ('Blay Ridge Parkway', 'street'), ('Brooklyn', 'city'), ('NY', 'region'), ('11209', 'postal')]
# 11, rue Amédée Dailly, F-78220 Viroflay Entities [('11', 'nr'), ('rue Amédée Dailly', 'street'), ('F-78220', 'postal'), ('Viroflay', 'city')]
# Louvain-la-Neuve Entities [('Louvain-la-Neuve', 'city')]
# Madison, CT Entities [('Madison', 'city'), ('CT', 'region')]
# Sanno Park Tower, 11-1, Nagatacho 2-chome, Chiyoda-ku, Tokyo Entities [('Sanno Park Tower', 'co'), ('Chiyoda-ku', 'area'), ('Tokyo', 'city')]
# Yokohama Entities [('Yokohama', 'city')]
# 1708 Bluff Court, Garden City, KS 67846 Entities [('1708', 'nr'), ('Bluff Court', 'street'), ('Garden City', 'city'), ('KS', 'region'), ('67846', 'postal')]
# 1, rue Henri Dunant, 1340 Aubagne Entities [('1', 'nr'), ('rue Henri Dunant', 'street'), ('1340', 'postal'), ('Aubagne', 'city')]
# 1 River Road, Schenectady, New York 12345 Entities [('1', 'nr'), ('River Road', 'street'), ('Schenectady', 'area'), ('New York', 'city'), ('12345', 'postal')]
# Turin Entities [('Turin', 'city')]
# La Priauraz, 1807 Blonay, Vaud Entities [('La Priauraz', 'street'), ('1807', 'nr'), ('Blonay', 'city'), ('Vaud', 'region')]
# Tsu-shi, Mie-ken Entities [('Tsu-shi', 'city'), ('Mie-ken', 'region')]
# Mitsubishi Denki K.K. 2-3 Marunouchi 2-chome, Chiyoda-ku Tokyo 100 Entities [('Mitsubishi Denki K.K.', 'co'), ('Chiyoda-ku', 'area'), ('Tokyo', 'city'), ('100', 'postal')]
# Tokyo Entities [('Tokyo', 'city')]
# Berkshire Entities [('Berkshire', 'city')]
# Maharashtra Entities [('Maharashtra', 'region')]
# Hanmer Entities []
# c/o Astellas Pharma Inc., 3-11 Nihonbashi-Honcho2-chome, Chuo-ku, Tokyo 103-8411 Entities [('c/o Astellas Pharma Inc.', 'co'), ('3-11 Nihonbashi-Honcho2-chome', 'street'), ('Chuo-ku', 'area'), ('Tokyo', 'city'), ('103-8411', 'postal')]
# Howell, MI Entities [('Howell', 'city'), ('MI', 'region')]
# 1112 27th Street, Vienna, West Virginia 26105 Entities [('1112', 'nr'), ('27th Street', 'street'), ('Vienna', 'city'), ('West Virginia', 'region')]
# San Francisco, CA Entities [('San Francisco', 'city'), ('CA', 'region')]
# 3105 Honey Tree Lane, Austin, TX 78746 Entities [('3105', 'nr'), ('Honey Tree Lane', 'street'), ('Austin', 'city'), ('TX', 'region'), ('78746', 'postal')]
# Disco Corporation 13-11, Omori-Kita 2-chome Ota-ku, Tokyo 143-8580 Entities []
# Portland, OR Entities [('Portland', 'city'), ('OR', 'region')]
# St. Petersburg Entities [('St. Petersburg', 'city')]
# P.O. Box 34244 Station D Vancouver, British Columbia V6J 4N8 Entities [('P.O. Box 34244', 'street'), ('Station D', 'building'), ('Vancouver', 'city'), ('British Columbia', 'region'), ('V6J 4N8', 'postal')]
# 3-4-8, Suehiro-cho, Kawagoe-shi, Saitama-ken Entities [('3-4-8', 'street'), ('Suehiro-cho', 'area'), ('Kawagoe-shi', 'city'), ('Saitama-ken', 'city')]
# Chino-shi Entities [('Chino-shi', 'city')]
# Bangalore Entities [('Bangalore', 'city')]
# Pomfret Entities [('Pomfret', 'city')]
# 33-18-1202 Hanakuma, Chuo-ku, Kobe-shi, Hyogo-ken Entities [('33-18-1202', 'street'), ('Hanakuma', 'city'), ('Chuo-ku', 'area'), ('Kobe-shi', 'city'), ('Hyogo-ken', 'region')]
# 123-1206 Mokdong Apt., Mok6-dong, Yangcheon-gu, Seoul, 158-050 Entities [('123-1206', 'nr'), ('Mokdong Apt.', 'building'), ('Mok6-dong', 'city'), ('Yangcheon-gu', 'area'), ('Seoul', 'city'), ('158-050', 'postal')]
# 10100 Bay Area Boulevard~Pasadena~Texas~77507 US Entities [('10100', 'nr'), ('Bay Area Boulevard', 'street'), ('Pasadena', 'city'), ('Texas~77507', 'postal'), ('US', 'country')]
# 129090, Moskva, ul. B. Spasskaja, 25, stroenie 3, OOO 'JUridicheskaja firma Gorodisskij i Partnery' Entities [('129090', 'postal'), ('Moskva', 'city'), ('ul. B. Spasskaja', 'street'), ('25', 'nr'), ('stroenie 3', 'street'), ("OOO 'JUridicheskaja firma Gorodisskij i Partnery'", 'co')]
# 6 New Chester Road, New Ferry, Wirral L62 5AA Entities [('6', 'nr'), ('New Chester Road', 'street'), ('New Ferry', 'city'), ('Wirral', 'region'), ('L62 5AA', 'postal')]
# Chesterfield, VA Entities [('Chesterfield', 'city'), ('VA', 'region')]
# Friedberg Entities [('Friedberg', 'city')]
# Apartment 2, 2520 Van Horne Street, Montreal, Quebec H3S 1P1 Entities [('2520', 'nr'), ('Van Horne Street', 'street'), ('Montreal', 'city'), ('Quebec', 'region'), ('H3S 1P1', 'postal')]
# Pine Bluff, AR Entities [('Pine Bluff', 'city'), ('AR', 'region')]
# MIAOLI COUNTY Entities [('MIAOLI COUNTY', 'city')]
# Columbus, OH Entities [('Columbus', 'city'), ('OH', 'region')]
# 129226, Moskva, pr-t Mira, 171, pom. 19, Davidenko N.F. Entities [('129226', 'postal'), ('Moskva', 'city'), ('pr-t Mira', 'street'), ('171', 'nr'), ('Davidenko', 'city')]
# Portola Valley Entities [('Portola Valley', 'city')]
# Denver Entities [('Denver', 'city')]
# PO Box 6321, Loughborough LE11 3XZ Entities [('Loughborough', 'city'), ('LE11 3XZ', 'postal')]
# 88 APPLEGARTH AVENUE, GUILDFORD, SURREY, GU2 6LR Entities [('88', 'nr'), ('GU2 6LR', 'postal')]
# BR Entities [('BR', 'region')]
# Daejeon Entities [('Daejeon', 'city')]
# West Melbourne Entities [('West Melbourne', 'city')]
# Provo, UT Entities [('Provo', 'city'), ('UT', 'region')]
# Camarillo Entities [('Camarillo', 'city')]
# St. Charles Entities [('St. Charles', 'city')]
# Melbourne Entities [('Melbourne', 'city')]
# Pennsauken Entities [('Pennsauken', 'city')]
# 6-7-8, Fujisaki, Narashino-shi Chiba 275-0017 Entities [('6-7-8', 'street'), ('Fujisaki', 'area'), ('Narashino-shi', 'city'), ('Chiba', 'region'), ('275-0017', 'postal')]
# 422B West Street, Fort Lee, NJ 07024 Entities [('422B', 'nr'), ('West Street', 'street'), ('Fort Lee', 'city'), ('NJ', 'region'), ('07024', 'postal')]
# 16635 SW Ivy Glenn St, Beaverton, Oregon 97007 Entities [('16635', 'nr'), ('SW Ivy Glenn St', 'street'), ('Beaverton', 'city'), ('Oregon', 'region'), ('97007', 'postal')]
# Les Escouradières, F-83230 Le Beausset Entities [('Les Escouradières', 'street'), ('F-83230', 'postal'), ('Le Beausset', 'city')]
# Herndon, VA Entities [('Herndon', 'city'), ('VA', 'region')]
# Kleine Stadenstraat 97c, 8830 Hooglede/Gits Entities [('97c', 'nr'), ('8830', 'postal'), ('Hooglede', 'city'), ('/Gits', 'city')]
# Naperville, IL Entities [('Naperville', 'city'), ('IL', 'region')]
# SOCIETE CIVILE S.P.I.D., 156 Bd Haussmann, F-75008 Paris Entities [('SOCIETE CIVILE S.P.I.D.', 'co'), ('156', 'nr'), ('Bd Haussmann', 'street'), ('F-75008', 'postal'), ('Paris', 'city')]
# Kabushiki Kaisha Communication Systems Dev. Lab., 1-1, Ofuna 5-chome Kamakura-shi Kanagawa Entities []
# Tokyo Entities [('Tokyo', 'city')]
# Hsin-Chu City Entities [('Hsin-Chu City', 'city')]
# 77, ALLÉE DES GRANDES COMBES, ZI QUEST BEYNOST, 01708 MIRIBEL CEDEX FR Entities [('77', 'nr'), ('ALLÉE DES GRANDES COMBES', 'street'), ('ZI QUEST BEYNOST', 'area'), ('01708', 'postal'), ('MIRIBEL CEDEX', 'city'), ('FR', 'region')]
# San Diego, CA Entities [('San Diego', 'city'), ('CA', 'region')]
# 21-1102 Sampoong Apt. 1685 Seocho-dong Seocho-ku, Seoul 137-070 Entities [('1685', 'nr'), ('Seocho-dong', 'street'), ('Seocho-ku', 'area'), ('Seoul', 'city'), ('137-070', 'postal')]
# P.O. Box 6300, Columbia, Maryland 21045-6300 Entities [('P.O. Box 6300', 'street'), ('Columbia', 'city'), ('Maryland', 'region'), ('21045-6300', 'postal')]
# Kobe Entities [('Kobe', 'city')]
# Amherst, NY Entities [('Amherst', 'city'), ('NY', 'region')]
# Cockeysville Entities [('Cockeysville', 'city')]
# 126 East Lincoln Avenue, Rahway New Jersey 07065-0907 Entities [('126', 'nr'), ('East Lincoln Avenue', 'street'), ('Rahway', 'city'), ('New Jersey', 'region'), ('07065-0907', 'postal')]
# Janis-Joplin-Str. 4, 71711 Steinheim an der Murr Entities [('Janis-Joplin-Str.', 'street'), ('4', 'nr'), ('71711', 'postal'), ('Steinheim an der Murr', 'city')]
# Loveland, CO Entities [('Loveland', 'city'), ('CO', 'region')]
# P.O. Box 826, Unionville, PA 19375 Entities [('P.O. Box 826', 'street'), ('Unionville', 'city'), ('PA', 'region'), ('19375', 'postal')]
# Tuscaloosa, AL Entities [('Tuscaloosa', 'city'), ('AL', 'region')]
# An Australian Company of Level 3, Legal & General, Perth, 6000 Entities [('Legal & General', 'building'), ('Perth', 'city'), ('6000', 'postal')]
# Dublin Entities [('Dublin', 'city')]
# Bierbeek Entities [('Bierbeek', 'city')]
# c/o Nippon Light Metal Co., Ltd. 2-20, Higashi-, Shinagawa 2-chome Shinagawa-ku Tokyo Entities [('c/o Nippon Light Metal Co.,', 'co'), ('Higashi-', 'city'), ('Shinagawa 2-chome Shinagawa-ku', 'area'), ('Tokyo', 'city')]
# Wilmington, DE Entities [('Wilmington', 'city'), ('DE', 'region')]
# Therwil/BL Entities [('Therwil', 'city'), ('BL', 'region')]
# 5141 South Kimbark, Chicago, IL 60615 Entities [('5141', 'nr'), ('South Kimbark', 'area'), ('Chicago', 'city'), ('IL', 'region'), ('60615', 'postal')]
# Seattle Entities [('Seattle', 'city')]
# Minneapolis, MN Entities [('Minneapolis', 'city'), ('MN', 'region')]
# Kilianstrasse 18, 33142 Büren Entities [('Kilianstrasse', 'street'), ('18', 'nr'), ('33142', 'postal'), ('Büren', 'city')]
# Chino Hills Entities [('Chino Hills', 'city')]
# Osaka Entities [('Osaka', 'city')]
# Richard-Wagner-Strasse 14, D-35392 Giessen Entities [('Richard-Wagner-Strasse', 'street'), ('14', 'nr'), ('D-35392', 'postal'), ('Giessen', 'city')]
# Via L. Russo, 7, 93012 Gela (CL) Entities [('Via L. Russo', 'street'), ('7', 'nr'), ('93012', 'postal'), ('Gela', 'city'), ('(CL)', 'region')]
# Daedong Apt. 104-303, Osan-si, Kyungki-do, 447-010 Entities [('Daedong', 'street'), ('Osan-si', 'area'), ('Kyungki-do', 'city'), ('447-010', 'postal')]
# Kanagawa Entities [('Kanagawa', 'region')]
# c/o Dolby Laboratories, Inc., 100 Potrero Avenue, San Francisco, California 94103-4813 Entities [('c/o Dolby Laboratories,', 'co'), ('100', 'nr'), ('Potrero Avenue', 'street'), ('San Francisco', 'city'), ('California', 'region'), ('94103-4813', 'postal')]
# Elizabethtown Entities [('Elizabethtown', 'city')]
# 5601 Paris Road, Columbia, MO 65201 Entities [('5601', 'nr'), ('Paris Road', 'street'), ('Columbia', 'city'), ('MO', 'region'), ('65201', 'postal')]
# 238 S Eagle Glen Trail, Columbia City, IN 46725 Entities [('238', 'nr'), ('S Eagle Glen Trail', 'street'), ('Columbia City', 'city'), ('IN', 'region'), ('46725', 'postal')]
# 375 Patton Avenue San Jose, CA 95128 US Entities [('375', 'nr'), ('Patton Avenue San Jose', 'street'), ('CA', 'region'), ('95128', 'postal'), ('US', 'country')]
# Lindenstrasse 47, 14548 Caputh Entities [('Lindenstrasse', 'street'), ('47', 'nr'), ('14548', 'postal'), ('Caputh', 'city')]
# Orlando, FL Entities [('Orlando', 'city'), ('FL', 'region')]
# Longmont, CO Entities [('Longmont', 'city'), ('CO', 'region')]
# Dälavägen 87, S-437 36 Torslanda Entities [('Dälavägen', 'street'), ('87', 'nr'), ('S-437 36', 'postal'), ('Torslanda', 'city')]
# Taipei Hsien Entities [('Taipei Hsien', 'city')]
# Santa Monica Entities [('Santa Monica', 'city')]
# Annandale, VA Entities [('Annandale', 'city'), ('VA', 'region')]
# Highland Park Entities [('Highland Park', 'city')]
# New Prague, MN Entities [('New Prague', 'city'), ('MN', 'region')]
# Hsinchu City Entities [('Hsinchu City', 'city')]
# Taegu Entities [('Taegu', 'city')]
# Eastsound, WA Entities [('Eastsound', 'city'), ('WA', 'region')]
# Wolfsburg Entities [('Wolfsburg', 'city')]
# Matsumoto Entities [('Matsumoto', 'city')]
# Charleston Entities [('Charleston', 'city')]
# 102-1505 POSCO Sup. Apt., Yucheon-dong Entities [('102-1505', 'nr'), ('POSCO Sup.', 'street'), ('Yucheon-dong', 'area')]
# 975 West County Road I, Shoreview, MN 55126 Entities [('975', 'nr'), ('West County Road I', 'street'), ('Shoreview', 'city'), ('MN', 'region'), ('55126', 'postal')]
# Hwaseong-si Entities [('Hwaseong-si', 'city')]
# c/o Mani, Inc., 743, Naka Akutsu, Takanezawa-machi, Shioya-gun, Tochigi-ken Entities [('c/o Mani,', 'co'), ('743', 'nr'), ('Naka Akutsu', 'area'), ('Takanezawa-machi', 'city'), ('Shioya-gun', 'city'), ('Tochigi-ken', 'region')]
# Newport Coast Entities [('Newport Coast', 'area')]
# Brookfield, CT Entities [('Brookfield', 'city'), ('CT', 'region')]
# Wirtembergstrasse 2, 71336 Waiblingen Entities [('Wirtembergstrasse', 'street'), ('2', 'nr'), ('71336', 'postal'), ('Waiblingen', 'city')]
# 2-3, Marunouchi 2-chome, Chiyoda-ku, Tokyo 100-8310 Entities [('2-3', 'street'), ('Marunouchi 2-chome', 'building'), ('Chiyoda-ku', 'area'), ('Tokyo', 'city'), ('100-8310', 'postal')]
# Kawasaki Entities [('Kawasaki', 'city')]
# San Jose, CA Entities [('San Jose', 'city'), ('CA', 'region')]
# Cambridgeshire Entities [('Cambridgeshire', 'region')]
# 1-27, Hirakata-cho Kanazawa-ku, Yokohama-shi Kanagawa 236-0023 Entities [('Yokohama-shi', 'area'), ('Kanagawa', 'region'), ('236-0023', 'postal')]
# Oxon Entities [('Oxon', 'city')]
# Hiratsuka Entities [('Hiratsuka', 'city')]
# 109-604, Geonyoung APT., 1094, Jisan-dong, Pyeongtaek, Kyunggi-do, 459-110, Korea Entities [('109-604', 'street'), ('Geonyoung APT.', 'building'), ('1094', 'nr'), ('Jisan-dong', 'area'), ('Pyeongtaek', 'city'), ('Kyunggi-do', 'region'), ('459-110', 'postal'), ('Korea', 'region')]
# Milford, PA Entities [('Milford', 'city'), ('PA', 'region')]
# Legal & IP Team, Samsung SDI Co., Ltd., 428-5, Gongse-ri, Kiheung-eup, Yongin-si, Gyeonggi-do Entities [('Legal & IP Team', 'co'), ('428-5', 'street'), ('Gongse-ri', 'area'), ('Kiheung-eup', 'area'), ('Yongin-si', 'city'), ('Gyeonggi-do', 'region')]
# Heilongjiang Entities [('Heilongjiang', 'region')]

# %%
from spacy.gold import GoldParse
from spacy.scorer import Scorer

def map_to_evaluation_model(entry: tuple):
    return (entry[0], entry[1]['entities'])


def evaluate(ner_model, examples):
    scorer = Scorer()
    for input_, annot in examples:
        doc_gold_text = ner_model.make_doc(input_)
        gold = GoldParse(doc_gold_text, entities=annot)
        pred_value = ner_model(input_)
        scorer.score(pred_value, gold)
    return scorer.scores

results = evaluate(nlp, map(map_to_evaluation_model, train_data))
print(results)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0ea6697685ae> in <module>
# ----> 1 from spacy.gold import GoldParse
#       2 from spacy.scorer import Scorer
#       3
#       4 def map_to_evaluation_model(entry: tuple):
#       5     return (entry[0], entry[1]['entities'])
#
# ModuleNotFoundError: No module named 'spacy.gold'
